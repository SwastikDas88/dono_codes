# %% [markdown]
# ## What is NLP (Natural Language Processing)?
#
# NLP is a branch of data science that consists of systematic processes for analyzing, understanding, and deriving information from the text data in a smart and efficient manner. By utilizing NLP and its components, one can organize the massive chunks of text data, perform numerous automated tasks and solve a wide range of problems such as – automatic summarization, machine translation, named entity recognition, relationship extraction, sentiment analysis, speech recognition, topic segmentation etc.
#
# Nowadays, most of us have smartphones that have speech recognition. These smartphones use NLP to understand what is said. Also, many people use laptops whose operating system has a built-in speech recognition.
#
# Example:
# **Cortana**
# ![title](https://miro.medium.com/max/700/1*TXj0kr4jVrtLtmvxZFu8Lw.png)
#
# The Microsoft OS has a virtual assistant called Cortana that can recognize a natural voice. You can use it to set up reminders, open apps, send emails, play games, track flights and packages, check the weather and so on.
#
# **Siri**
# ![title](https://miro.medium.com/max/700/1*-AuKCZbXIVOhI-AgX4J8PQ.jpeg)
#
# Siri is a virtual assistant of the Apple Inc.’s iOS, watchOS, macOS, HomePod, and tvOS operating systems. Again, you can do a lot of things with voice commands: start a call, text someone, send an email, set a timer, take a picture, open an app, set an alarm, use navigation and so on.
#
# ### Applications of NLP:
# **Machine Translation**
#     It is the process by which computer software is used to translate a text from one natural language (such as English) to another (such as Spanish).
#
#
# **Speech Recognition:**
#     Speech recognition is the process by which a computer (or other type of machine) identifies spoken words. Basically, it means talking to your computer, AND having it correctly recognize what you are saying.
#
# **Sentiment Analysis:**
#     Sentiment analysis is the process of detecting positive or negative sentiment in text. It’s often used by businesses to detect sentiment in social data, gauge brand reputation, and understand customers.
#
# **Question Answering:**
#     Question answering (QA) is a computer science discipline within the fields of information retrieval and natural language processing (NLP), which is concerned with building systems that automatically answer questions posed by humans in a natural language.
#
# **Text Summarization:**
#     Text summarization is the process of distilling the most important information from a source (or sources) to produce an abridged version for a particular user (or users) and task (or tasks).
#
# **Chatbot:**
#     A chatbot is a software application used to conduct an on-line chat conversation via text or text-to-speech, in lieu of providing direct contact with a live human agent.
#
# **Text Classifications:**
#     Text clarification is the process of categorizing the text into a group of words. By using NLP, text classification can automatically analyze text and then assign a set of predefined tags or categories based on its context.
#
# **Optical Character Recognition:**
#     Optical Character Recognition (OCR) is an electronic conversion of the typed, handwritten or printed text images into machine-encoded text
#
# **Spell Checking:**
#     Spell Checking is a sequence to sequence mapping problem. Given an input sequence, potentially containing a certain number of errors, ContextSpellChecker will rank correction sequences according to three things, Different correction candidates for each word — word level.
#
# **Spam Detection:**
#     Spam Detection detect unsolicited, unwanted, and virus-infested email (called spam) and stop it from getting into email inboxes.
#
# **Named Entity Recognition:**
#     Named entity recognition (NER) — sometimes referred to as entity chunking, extraction, or identification — is the task of identifying and categorizing key information (entities) in text. An entity can be any word or series of words that consistently refers to the same thing. Every detected entity is classified into a predetermined category. For example, an NER machine learning (ML) model might detect the word “Bdec” in a text and classify it as a “Company”.
#
#
#
# ### Understanding Natural Language Processing (NLP)
#
#    ![title](https://miro.medium.com/max/581/0*YovzfkM8Ld1LO-87.png)
#
#
# As humans, perform natural language processing (NLP) considerably well, but even then, we are not perfect. We often misunderstand one thing for another, and we often interpret the same sentences or words differently.
#
# consider the following sentence,
#
# `I saw a man on hill with a telescope.`
#
# These are some interpretations of the sentence shown above.
#    - There is a man on the hill, and I watched him with my telescope.
#    - There is a man on the hill, and he has a telescope.
#    - I’m on a hill, and I saw a man using my telescope.
#    - I’m on a hill, and I saw a man who has a telescope.
#    - There is a man on a hill, and I saw him something with my telescope.
#
# From the examples above, we can see that language processing is not “deterministic” (the same language has the same interpretations), and something suitable to one person might not be suitable to another.
#
# Therefore, Natural Language Processing (NLP) has a non-deterministic approach. In other words, Natural Language Processing can be used to create a new intelligent system that can understand how humans understand and interpret language in different situations.
#
# ### Components of Natural Language Processing
# ![title](https://miro.medium.com/max/455/0*9aT_MdjuT9xXGUdU.png)
#
# **Lexical Analysis:**
# With lexical analysis, we divide a whole chunk of text into paragraphs, sentences, and words. It involves identifying and analyzing words’ structure.
#
# **Syntactic Analysis:**
# Syntactic analysis involves the analysis of words in a sentence for grammar and arranging words in a manner that shows the relationship among the words. For instance, the sentence “The shop goes to the house” does not pass.
#
# **Semantic Analysis:**
# Semantic analysis draws the exact meaning for the words, and it analyzes the text meaningfulness. Sentences such as “hot ice-cream” do not pass.
#
# **Disclosure Integration:**
# Disclosure integration takes into account the context of the text. It considers the meaning of the sentence before it ends. For example: “He works at Google.” In this sentence, “he” must be referenced in the sentence before it.
#
# **Pragmatic Analysis:**
# Pragmatic analysis deals with overall communication and interpretation of language. It deals with deriving meaningful use of language in various situations.
#
#
# Banks are using natural language processing (NLP) to automate certain document processing, analysis and customer service activities. Three applications include:
#
# - **Intelligent document search:** finding relevant information in large volumes of scanned documents.
# - **Investment analysis:** automating routine analysis of earnings reports and news so that analysts can focus on alpha generation.
# - **Customer service & insights:** deploying chatbots to answer customer queries and understand customer needs.
#
# ![title](https://miro.medium.com/max/2560/1*BqX1wu57y5ApVE-5G-EC4w.png)

# %% [markdown]
# ### Handling Text Files in python
#
# #### Python provides inbuilt functions for creating, writing and reading files.
#
# **How to Open a Text File in Python**
# To open a file, you need to use the built-in `open` function. The Python file open function returns a file object that contains methods and attributes to perform various operations for opening files in Python.
#
# **Close the file instance**
# To open a file, you need to use the built-in `close()` function.
#
# **How to Read a File line by line in Python**
# You can also read your .txt file line by line if your data is too big to read. `readlines()` code will segregate your data in easy to read mode.

# %%
my_file=open('skills_set.txt','r') #open the file
print(my_file.readline())# reading first line of the document.
print('--------------')
print(my_file.readline())# reading second line of the document.
my_file.close()#close the file.
# Out:
# skill_set
#
# --------------
# SAP

# %%
my_file=open('skills_set.txt','r') #open the file
print(my_file.read(20))# reading 20 word of the document.
my_file.close()
# Out:
# skill_set
# SAP
# SQL
# Ma

# %%
# Reading each line of document
my_file=open('skills_set.txt','r')
for line in my_file:
    print(line)
my_file.close()
# Out:
# skill_set
#
# SAP
#
# SQL
#
# Machine Learning
#
# R
#
# SAS
#
# Python
#
# Data Mining
#
# Data Management
#
# STATA
#
# SPSS
#
# Data Analysis
#
# Certified Internal Auditor
#
# Statistical Software
#
# Time Management
#
# Microsoft Office
#
# Excel
#
# Tableau
#
# Data Science
#
# AI
#
# Quantitative Analysis
#
# Analysis Skills
#
# CSS
#
# Image Processing
#
# Cloud Computing
#
# ArcGIS
#
# GIS
#
# AWS
#
# Linux
#
# C/C++
#
# JavaScript
#
# TS/SCI Clearance
#
# TensorFlow
#
# Project Planning
#
# Jira
#
# Statisical Analysis
#
# Scala
#
# Java
#
# """Drivers License"""
#
# Microsoft SQL Server
#
# Visual Basic
#
# Microsoft Access
#
# LMRT
#
# Natural Language Processing
#
# IIS
#
# Power BI
#
# CAD Software
#
# SharePoint
#
# nan
#
# Git
#
# SVN
#
# React
#
# Adobe Photoshop
#
# HTML5
#
# Scripting
#
# Perl
#
# MATLAB
#
# Splunk
#
# Grant Writing
#
# Hive
#
# Spark
#
# Microsoft Powerpoint
#
# Hadoop
#
# Qualitative Research
#
# .Net
#
# C#
#
# Big Data
#
# Software Development
#
# Signal Processing
#
# Design Experience
#
# Pentaho
#
# Oracle
#
# DB2
#
# Next Generation Sequencing
#
# Bioinformatics
#
# Data Warehouse
#
# Alteryx
#
# Ruby
#
# Marketing
#
# Customer Service
#
# Predictive Analytics
#
# Business Intelligence
#
# Sentiment Analytics
#
# XML
#
# Shell Scripting
#
# Project Management
#
# Azure
#
# Google Cloud Platform
#
# MySQL
#
# Salesforce CRM
#
# Pardot
#
# Marketing Automation
#
# UI
#
# Six Sigma Certification
#
# Six Sigma
#
# Google Suite
#
# Troubleshooting
#
# Teradata
#
# Minitab
#
# ACH
#
# NoSQL
#
# JSON
#
# REST
#
# PostgreSQL
#
# Google Analytics
#
# Cell Biology
#
# Node.js
#
# Immunoassays
#
# Military Experience
#
# RMF
#
# T-SQL
#
# PL/SQL
#
# Lean
#
# OOP
#
# Managed Care
#
# Business Analysis
#
# HBase
#
# MongoDB
#
# Pig
#
# Weka
#
# Microsoft Word
#
# QlikView
#
# PHP
#
# S3
#
# Network
#
# Haskell
#
# CI
#
# Unit Testing
#
# System Design
#
# Survival Analysis
#
# Database Administration
#
# Drupal
#
# Software Testing
#
# Content Management Systems
#
# WordPress
#
# Microsoft Project
#
# Visio
#
# Red Hat Enterprise Linux
#
# CompTIA Security+
#
# MCSD
#
# Kafka
#
# Elasticsearch
#
# Solr
#
# Threading
#
# Docker
#
# IAT
#
# IDS
#
# IAT Level II
#
# Clinical Trials
#
# SDLC
#
# SSL
#
# DNS
#
# TCP/IP
#
# TCP
#
# Medical Imaging
#
# Customer Segmentation
#
# Digital Marketing
#
# Information Security
#
# Quantitative Research
#
# SaaS
#
# Go
#
# FTP
#
# Redis
#
# Leadership Experience
#
# Cassandra
#
# Eclipse
#
# Telecommunication
#
# UX
#
# Visual Studio
#
# Financial Modeling
#
# DynamoDB
#
# Supervising Experience
#
# Service-Oriented Architecture
#
# Kubernetes
#
# Strategic Planning
#
# Clojure
#
# Epic
#
# Technical Writing
#
# CI/CD
#
# SOAP
#
# Windows
#
# Intelligence Experience
#
# Intelligence Community Experience
#
# Tomcat
#
# JBoss
#
# Apache
#
# Kanban
#
# Mac OS
#
# Web Development
#
# Jenkins
#
# Control-M
#
# iWork
#
# Experimental Design
#
# Android
#
# Audits
#
# Adobe Creative Suite
#
# Adobe Marketing
#
# 4G/LTE
#
# Angular
#
# Confluence
#
# Quality Control
#
# Social Media Management
#
# Facebook Advertising
#
# PostGIS
#
# Management Consulting
#
# Informatica
#
# PMP
#
# Distributed Control Systems
#
# Marketing Mix Modeling
#
# Multichannel Marketing
#
# Continuous Improvement
#
# Embedded Software
#
# CAD
#
# Akka
#
# ZooKeeper
#
# Doubleclick
#
# Supply Chain Experience
#
# ICD-10
#
# ICD-9
#
# Conversion Optimization
#
# Learning Technology
#
# Responsive Web Design
#
# Spring
#
# GraphQL
#
# Ubuntu
#
# CentOS
#
# Lucene
#
# Survey Design
#
# Qualtrics
#
# Management Experience
#
# Build Automation
#
# NIST
#
# Bootstrap
#
# Database Marketing
#
# IT Experience
#
# Accounting
#
# Attribution Modeling
#
# Epic Certification
#
# Process Mapping
#
# Retail Link
#
# Salesforce Marketing Cloud
#
# Omniture
#
# ERP Systems
#
# Clinical Research
#
# CDISC Standards
#
# Test Automation
#
# Maven
#
# Crystal Reports
#
# Laboratory Experience
#
# FPGA
#
# HDI Certification
#
# Teaching Experience
#
# Molecular Biology
#
# LDAP
#
# iOS
#
# Cash Flow Analysis
#
# Swift
#
# DoD 8570
#
# IAT Level I
#
# Email Marketing
#
# Fortran
#
# NGINX
#
# Lean Manufacturing
#
# Martech
#
# LAMP Stack
#
# InVision
#
# SSH
#
# Design Patterns
#
# Performance Marketing
#
# Malware Analysis
#
# Cybersecurity
#
# WebSphere
#
# PaaS
#
# Google AdWords
#
# NFS
#
# Lua
#
# Sales Experience
#
# Mesos
#
# Adobe InDesign
#
# Rust
#
# New Relic
#
# Biostatistics
#
# Oracle EBS
#
# Operations Research
#
# Genetics
#
# SPARQL
#
# Project Engineering
#
# Process Engineering
#
# Chef
#
# VMWare
#
# OpenStack
#
# Software Troubleshooting
#
# Change Management
#
# Project Leadership
#
# Agriculture
#
# IaaS
#
# Technical Support
#
# Ember
#
# HP ALM
#
# Project Implementation
#
# Calculus
#
# CPA
#
# Certified Management Accountant
#
# Acquisition Strategy
#
# PCI
#
# FINRA License
#
# CISSP
#
# Internal Audits
#
# Certified Scrum Master
#
# Research Laboratory Experience
#
# Front-End Development
#
# SOX
#
# Aviation Experience
#
# ADAS
#
# Computer Graphics
#
# Network Security
#
# E-Commerce
#
# OBIEE
#
# Technical Project Management
#
# Business Process Reengineering
#
# XSLT
#
# Compliance Management
#
# Project Management Methodology
#
# CEH
#
# GSEC
#
# Design Controls
#
# Quality Management
#
# Wireframing
#
# Program Management
#
# ICD Coding
#
# Hibernate
#
# Workday
#
# Remote Access Software
#
# GPEN
#
# Unity
#
# Identity And Access Management
#
# Selenium
#
# TestNG
#
# Firewall
#
# Active Directory
#
# Project / Program Management
#
# LMS
#
# Financial Accounting
#
# MicroStation
#
# Basic Computer Skills
#
# ITIL
#
# Cerner
#
# Regulatory Reporting
#
# Medical Terminology
#
# Magento
#
# Sybase
#
# Integrated Library System
#
# Bilingual
#
# CPT Coding
#
# Marketo
#
# PeopleSoft
#
# JD Edwards
#
# Process Management
#
# openSUSE
#
# APICS Certification
#
# RHIA
#
# CPHQ
#
# Hyperion
#
# Coaching Experience
#
# Medical Coding
#
# Epidemiology
#
# Employee Evaluation
#
# Clean Driving Record
#
# RN
#
# ICU
#
# Nursing Experience
#
# UltiPro
#
# Professional In Human Resources
#
# SHRM Certified Professional
#
# RHIT
#
# NCQA Standards
#
# Adobe Acrobat
#
# Medical Insurance
#
# CFE
#
# Certified Compliance And Ethics Professional
#
# Legal Research
#
# Process Improvement
#
# Media Buying
#
# PPC Campaign Management
#
# Transportation Management
#
# Google Search Console
#
# Programmable Logic Controllers
#
# PowerShell
#
# HubSpot
#
# Calibration
#
# Conflict Management
#
# Certified Compensation Professional
#
# IVR
#
# Application Support
#
# ISO 9001
#
# GAAP
#
# IFRS
#
# Affiliate Marketing
#
# Microsoft Windows Server
#
# TFS
#
# Cordova
#
# Omnigraffle
#
# MCSA
#
# MCSE
#
# Objective-C
#
# Routing Protocols
#
# HTTPS
#
# IPsec
#
# Payroll
#
# CISM
#
# Certified Information Systems Auditor
#
# Business Management
#
# Product Demos
#
# Public Relations
#
# Chartered Financial Analyst
#
# B2B Sales
#
# BC/BE
#
# Pharmacy Residency
#
# CSSLP
#
# Certified Project Manager
#
# Enrolled Agent
#
# Public Speaking
#
# 3G
#
# MPLS
#
# OSPF
#
# JNCIA
#
# Juniper
#
# BGP
#
# CCDA
#
# Cisco Routers
#
# CCNA Security
#
# CCNA
#
# SSCP
#
# Load Balancing
#
# MCTS
#
# MCITP
#
# Network Engineering
#
# Ansible
#
# FedRAMP
#
# FIPS
#
# FISMA
#
# Puppet
#
# System Administration
#
# Network Infrastructure
#
# CGMP
#
# XQuery
#
# SQLite
#
# AJAX
#
# FileMaker
#
# Ellucian
#
# Sailpoint
#
# RHCE
#
# DHCP
#
# Struts
#
# MCP
#
# Perforce
#
# Heroku
#
# SEO
#
# CompTIA Network+
#
# Solarwinds
#
# CCNP
#
# Ant
#
# VersionOne
#
# Xero
#
# Erlang
#
# Maya

# %% [markdown]
# ### Handling json files in python
#
# *JSON (JavaScript Object Notation) is a popular data format used for representing structured data. It's common to transmit and receive data between a server and web application in JSON format.*
#
# **How to read JSON file in python**
#   - You can use json.load() method to read a file containing JSON object.

# %%
import json #import json module

# %%
file=open('college.json','r') #opening the json file
data = json.load(file)# returns JSON object as a dictionary
data
# Out:
# [{'domains': ['marywood.edu'],
#   'web_pages': ['http://www.marywood.edu'],
#   'name': 'Marywood University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lindenwood.edu'],
#   'web_pages': ['http://www.lindenwood.edu/'],
#   'name': 'Lindenwood University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['sullivan.edu'],
#   'web_pages': ['https://sullivan.edu/'],
#   'name': 'Sullivan University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['fscj.edu'],
#   'web_pages': ['https://www.fscj.edu/'],
#   'name': 'Florida State College at Jacksonville',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['xavier.edu'],
#   'web_pages': ['https://www.xavier.edu/'],
#   'name': 'Xavier University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tusculum.edu'],
#   'web_pages': ['https://home.tusculum.edu/'],
#   'name': 'Tusculum College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cst.edu'],
#   'web_pages': ['https://cst.edu/'],
#   'name': 'Claremont School of Theology',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['columbiasc.edu'],
#   'web_pages': ['https://www.columbiasc.edu/'],
#   'name': 'Columbia College (SC)',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['clpccd.edu'],
#   'web_pages': ['http://www.clpccd.edu/'],
#   'name': 'Chabot-Las Positas Community College District',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['keller.edu'],
#   'web_pages': ['https://www.keller.edu/'],
#   'name': 'Keller Graduate School of Management',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['monroecollege.edu'],
#   'web_pages': ['https://monroecollege.edu/'],
#   'name': 'Monroe College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['smccd.edu'],
#   'web_pages': ['https://smccd.edu/'],
#   'name': 'San Mateo County Community College District',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['losrios.edu'],
#   'web_pages': ['http://losrios.edu/'],
#   'name': 'Los Rios Community College District',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['digipen.edu'],
#   'web_pages': ['https://www.digipen.edu/'],
#   'name': 'DigiPen Institute of Technology',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['upmc.edu', 'upmc.com'],
#   'web_pages': ['https://www.upmc.com/'],
#   'name': 'University of Pittsburgh Medical Center',
#   'alpha_two_code': 'US',
#   'state-province': 'Pennsylvania',
#   'country': 'United States'},
#  {'domains': ['cgu.edu'],
#   'web_pages': ['https://www.cgu.edu/'],
#   'name': 'Claremont Graduate University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['utrgv.edu'],
#   'web_pages': ['http://www.utrgv.edu/'],
#   'name': 'University of Texas Rio Grande Valley',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['mountsaintvincent.edu'],
#   'web_pages': ['https://mountsaintvincent.edu/'],
#   'name': 'College of Mount Saint Vincent',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uasys.edu'],
#   'web_pages': ['https://www.uasys.edu/'],
#   'name': 'University of Arkansas System eVersity',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ecpi.edu'],
#   'web_pages': ['https://www.ecpi.edu/'],
#   'name': 'ECPI University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['umw.edu'],
#   'web_pages': ['https://www.umw.edu/'],
#   'name': 'University of Mary Washington',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bw.edu'],
#   'web_pages': ['https://www.bw.edu/'],
#   'name': 'Baldwin Wallace University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csuci.edu'],
#   'web_pages': ['https://www.csuci.edu/'],
#   'name': 'California State University Channel Islands',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['brandman.edu'],
#   'web_pages': ['https://www.brandman.edu/'],
#   'name': 'Brandman University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uscga.edu'],
#   'web_pages': ['http://www.uscga.edu/'],
#   'name': 'United States Coast Guard Academy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['athens.edu'],
#   'web_pages': ['http://www.athens.edu/'],
#   'name': 'Athens State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['scripps.edu'],
#   'web_pages': ['https://scripps.edu/'],
#   'name': 'The Scripps Research Institute',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['easternflorida.edu'],
#   'web_pages': ['http://www.easternflorida.edu/'],
#   'name': 'Eastern Florida State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['wne.edu'],
#   'web_pages': ['http://www1.wne.edu/'],
#   'name': 'Western New England University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['king.edu'],
#   'web_pages': ['https://king.edu/'],
#   'name': 'King University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ggc.edu'],
#   'web_pages': ['https://ggc.edu/'],
#   'name': 'Georgia Gwinnett College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['trident.edu'],
#   'web_pages': ['https://www.trident.edu/'],
#   'name': 'Trident University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alliant.edu'],
#   'web_pages': ['https://www.alliant.edu/'],
#   'name': 'Alliant International University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['mvsu.edu'],
#   'web_pages': ['https://mvsu.edu/'],
#   'name': 'Mississippi Valley State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['roosevelt.edu'],
#   'web_pages': ['https://www.roosevelt.edu/'],
#   'name': 'Roosevelt University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['itt-tech.info', 'itt-tech.edu'],
#   'web_pages': ['http://itt-tech.info/'],
#   'name': 'ITT Technical Institute',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['iecc.edu'],
#   'web_pages': ['https://iecc.edu/'],
#   'name': 'Illinois Eastern Community Colleges',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['park.edu'],
#   'web_pages': ['https://park.edu/'],
#   'name': 'Park University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['mssm.edu'],
#   'web_pages': ['http://icahn.mssm.edu/'],
#   'name': 'Icahn School of Medicine at Mount Sinai',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uvu.edu'],
#   'web_pages': ['https://uvu.edu/'],
#   'name': 'Utah Valley Uniersity',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['wlc.edu'],
#   'web_pages': ['http://www.wlc.edu/'],
#   'name': 'Wisconsin Lutheran College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['rccd.edu'],
#   'web_pages': ['http://www.rccd.edu/'],
#   'name': 'Riverside Community College District',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['wakehealth.edu'],
#   'web_pages': ['http://www.wakehealth.edu/'],
#   'name': 'Wake Forest Baptist Health',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['umb.edu'],
#   'web_pages': ['https://www.umb.edu/'],
#   'name': 'University of Massachusetts Boston',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['floridapoly.edu'],
#   'web_pages': ['https://floridapoly.edu/'],
#   'name': 'Florida Polytechnic University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['wagner.edu'],
#   'web_pages': ['https://wagner.edu/'],
#   'name': 'Wagner College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['wilmu.edu'],
#   'web_pages': ['https://www.wilmu.edu/'],
#   'name': 'Wilmington University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['itu.edu'],
#   'web_pages': ['https://itu.edu/'],
#   'name': 'International Technological University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['yhc.edu'],
#   'web_pages': ['https://www.yhc.edu/'],
#   'name': 'Young Harris College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['findlay.edu'],
#   'web_pages': ['https://www.findlay.edu/'],
#   'name': 'University of Findlay',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['pcom.edu'],
#   'web_pages': ['https://www.pcom.edu/'],
#   'name': 'Philadelphia College of Osteopathic Medicine',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['yosemite.edu'],
#   'web_pages': ['https://www.yosemite.edu/'],
#   'name': 'Yosemite Community College District',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['coastalalabama.edu'],
#   'web_pages': ['http://www.coastalalabama.edu/'],
#   'name': 'Coastal Alabama Community College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['pnw.edu'],
#   'web_pages': ['https://www.pnw.edu/'],
#   'name': 'Purdue University Northwest',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['columbiabasin.edu'],
#   'web_pages': ['http://www.columbiabasin.edu/'],
#   'name': 'Columbia Basin College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['seattlecolleges.edu'],
#   'web_pages': ['https://www.seattlecolleges.edu/'],
#   'name': 'Seattle Colleges',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lipscomb.edu'],
#   'web_pages': ['https://www.lipscomb.edu/'],
#   'name': 'Lipscomb University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tiffin.edu'],
#   'web_pages': ['http://www.tiffin.edu/'],
#   'name': 'Tiffin University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['troy.edu'],
#   'web_pages': ['https://troy.edu/'],
#   'name': 'Troy University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['student.42.us.org'],
#   'web_pages': ['http://www.42.us.org/'],
#   'name': '42 US',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['calbaptist.edu'],
#   'web_pages': ['http://www.calbaptist.edu/'],
#   'name': 'California Baptist University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['stevenson.edu'],
#   'web_pages': ['http://www.stevenson.edu/'],
#   'name': 'Stevenson University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['mbl.edu'],
#   'web_pages': ['http://www.mbl.edu/'],
#   'name': 'Marine Biological Laboratory',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['maryville.edu'],
#   'web_pages': ['http://www.maryville.edu/'],
#   'name': 'Maryville University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aii.edu'],
#   'web_pages': ['http://www.aii.edu/'],
#   'name': 'The Art Institutes',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['umc.edu'],
#   'web_pages': ['http://www.umc.edu/'],
#   'name': 'University of Mississippi Medical Center',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uco.edu'],
#   'web_pages': ['http://www.uco.edu/'],
#   'name': 'University of Central Oklahoma',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['hallmarkuniversity.edu'],
#   'web_pages': ['http://www.hallmarkuniversity.edu/'],
#   'name': 'Hallmark University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['keiseruniversity.edu'],
#   'web_pages': ['http://www.keiseruniversity.edu/'],
#   'name': 'Keiser University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['sjrstate.edu'],
#   'web_pages': ['http://www.sjrstate.edu/'],
#   'name': 'St. Johns River State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['irsc.edu'],
#   'web_pages': ['http://www.irsc.edu/'],
#   'name': 'Indian River State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['barnard.edu'],
#   'web_pages': ['http://www.barnard.edu/'],
#   'name': 'Barnard College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['calsouthern.edu'],
#   'web_pages': ['http://www.calsouthern.edu/'],
#   'name': 'California Southern University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['laverne.edu'],
#   'web_pages': ['http://www.laverne.edu/'],
#   'name': 'University of La Verne',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['washjeff.edu'],
#   'web_pages': ['http://www.washjeff.edu/'],
#   'name': 'Washington &amp; Jefferson College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uopeople.edu'],
#   'web_pages': ['http://www.uopeople.edu/'],
#   'name': 'University of the People',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['touro.edu'],
#   'web_pages': ['http://www.touro.edu/'],
#   'name': 'Touro College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['njcu.edu'],
#   'web_pages': ['http://www.njcu.edu/'],
#   'name': 'New Jersey City University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lander.edu'],
#   'web_pages': ['http://www.lander.edu/'],
#   'name': 'Lander University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['sunymaritime.edu'],
#   'web_pages': ['http://www.sunymaritime.edu/'],
#   'name': 'SUNY Maritime College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lesley.edu'],
#   'web_pages': ['http://www.lesley.edu/'],
#   'name': 'Lesley University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lauruscollege.edu'],
#   'web_pages': ['http://www.lauruscollege.edu/'],
#   'name': 'Laurus College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['np.edu'],
#   'web_pages': ['http://www.np.edu/'],
#   'name': 'National Park College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['oc.edu'],
#   'web_pages': ['http://www.oc.edu/'],
#   'name': 'Oklahoma Christian University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['sdcc.edu'],
#   'web_pages': ['http://www.sdcc.edu/'],
#   'name': 'San Diego Christian College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['sans.edu'],
#   'web_pages': ['http://www.sans.edu/'],
#   'name': 'SANS Technology Institute',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['phsc.edu'],
#   'web_pages': ['http://www.phsc.edu/'],
#   'name': 'Pasco-Hernando State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ncf.edu'],
#   'web_pages': ['http://www.ncf.edu/'],
#   'name': 'New College of Florida',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['gcu.edu'],
#   'web_pages': ['http://www.gcu.edu/'],
#   'name': 'Grand Canyon University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cshl.edu'],
#   'web_pages': ['http://www.cshl.edu/'],
#   'name': 'Cold Spring Harbor Laboratory',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['asurams.edu'],
#   'web_pages': ['http://www.asurams.edu/'],
#   'name': 'Albany State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lasell.edu'],
#   'web_pages': ['http://www.lasell.edu/'],
#   'name': 'Lasell College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['4cd.edu'],
#   'web_pages': ['http://www.4cd.edu/'],
#   'name': 'Contra Costa Community College District',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['msmary.edu'],
#   'web_pages': ['http://www.msmary.edu/'],
#   'name': "Mount St. Mary's University",
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['robertmorris.edu'],
#   'web_pages': ['http://www.robertmorris.edu/'],
#   'name': 'Robert Morris University Illinois',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['nwfsc.edu'],
#   'web_pages': ['http://www.nwfsc.edu/'],
#   'name': 'Northwest Florida State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['wvwc.edu'],
#   'web_pages': ['http://www.wvwc.edu/'],
#   'name': 'West Virginia Wesleyan College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['utica.edu'],
#   'web_pages': ['http://www.utica.edu/'],
#   'name': 'Utica College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ccnn.edu'],
#   'web_pages': ['http://www.ccnn.edu/'],
#   'name': 'Career College of Northern Nevada',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ung.edu'],
#   'web_pages': ['http://www.ung.edu/'],
#   'name': 'University of North Georgia',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['principia.edu'],
#   'web_pages': ['http://www.principia.edu/'],
#   'name': 'The Principia',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['lynn.edu'],
#   'web_pages': ['http://www.lynn.edu/'],
#   'name': 'Lynn University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cccs.edu'],
#   'web_pages': ['http://www.cccs.edu/'],
#   'name': 'Colorado Community College System',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['valenciacollege.edu'],
#   'web_pages': ['http://www.valenciacollege.edu/'],
#   'name': 'Valencia College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['spcollege.edu'],
#   'web_pages': ['http://www.spcollege.edu/'],
#   'name': 'St. Petersburg College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['msbcollege.edu'],
#   'web_pages': ['http://www.msbcollege.edu/'],
#   'name': 'Globe University &amp; Minnesota School of Business',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['everest.edu'],
#   'web_pages': ['http://www.everest.edu/'],
#   'name': 'Everest College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['swri.edu'],
#   'web_pages': ['http://www.swri.edu/'],
#   'name': 'Southwest Research Institute',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['apus.edu'],
#   'web_pages': ['http://www.apus.edu/'],
#   'name': 'American Public University System',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['fullsail.edu'],
#   'web_pages': ['http://www.fullsail.edu/'],
#   'name': 'Full Sail University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['yti.edu'],
#   'web_pages': ['http://www.yti.edu/'],
#   'name': 'YTI Career Institute',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['dliflc.edu'],
#   'web_pages': ['http://www.dliflc.edu/'],
#   'name': 'Defense Language Institute Foreign Language Center',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['columbusstate.edu'],
#   'web_pages': ['http://www.columbusstate.edu/'],
#   'name': 'Columbus State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['moreheadstate.edu'],
#   'web_pages': ['http://www.moreheadstate.edu/'],
#   'name': 'Morehead State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csuglobal.edu'],
#   'web_pages': ['http://www.csuglobal.edu/'],
#   'name': 'Colorado State University - Global Campus',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ndus.edu'],
#   'web_pages': ['http://www.ndus.edu/'],
#   'name': 'North Dakota University System',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uhd.edu'],
#   'web_pages': ['http://www.uhd.edu/'],
#   'name': 'University of Houston-Downtown',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['stratford.edu'],
#   'web_pages': ['http://www.stratford.edu/'],
#   'name': 'Stratford University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cpp.edu'],
#   'web_pages': ['http://www.cpp.edu/'],
#   'name': 'California Polytechnic State University, Pomona',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['baker.edu'],
#   'web_pages': ['http://www.baker.edu/'],
#   'name': 'Baker College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tcnj.edu'],
#   'web_pages': ['http://www.tcnj.edu/'],
#   'name': 'The College of New Jersey',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['acu.edu'],
#   'web_pages': ['http://www.acu.edu/'],
#   'name': 'Abilene Christian University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['adelphi.edu'],
#   'web_pages': ['http://www.adelphi.edu/'],
#   'name': 'Adelphi University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['agnesscott.edu'],
#   'web_pages': ['http://www.agnesscott.edu/'],
#   'name': 'Agnes Scott College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['atc.edu'],
#   'web_pages': ['http://www.atc.edu/'],
#   'name': 'Aiken Technical College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['afit.edu'],
#   'web_pages': ['http://www.afit.edu/'],
#   'name': 'Air Force Institute of Technology',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aamu.edu'],
#   'web_pages': ['http://www.aamu.edu/'],
#   'name': 'Alabama A&M University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alasu.edu'],
#   'web_pages': ['http://www.alasu.edu/'],
#   'name': 'Alabama State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aloma.edu'],
#   'web_pages': ['http://www.alamo.edu/'],
#   'name': 'Alamo Colleges',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['acofi.edu'],
#   'web_pages': ['http://www.acofi.edu/'],
#   'name': 'Albertson College of Idaho',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['albion.edu'],
#   'web_pages': ['http://www.albion.edu/'],
#   'name': 'Albion College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alfred.edu'],
#   'web_pages': ['http://www.alfred.edu/'],
#   'name': 'Alfred University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alleg.edu'],
#   'web_pages': ['http://www.alleg.edu/'],
#   'name': 'Allegheny College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['allencol.edu'],
#   'web_pages': ['http://www.allencol.edu/'],
#   'name': 'Allentown College of Saint Francis de Sales',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alma.edu'],
#   'web_pages': ['http://www.alma.edu/'],
#   'name': 'Alma College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alverno.edu'],
#   'web_pages': ['http://www.alverno.edu/'],
#   'name': 'Alverno College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ambassador.edu'],
#   'web_pages': ['http://www.ambassador.edu/'],
#   'name': 'Ambassador University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['amercoastuniv.edu'],
#   'web_pages': ['http://www.amercoastuniv.edu/'],
#   'name': 'American Coastline University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aic.edu'],
#   'web_pages': ['http://www.aic.edu/'],
#   'name': 'American International College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['american.edu'],
#   'web_pages': ['http://www.american.edu/'],
#   'name': 'American University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['amherst.edu'],
#   'web_pages': ['http://www.amherst.edu/'],
#   'name': 'Amherst College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['andrews.edu'],
#   'web_pages': ['http://www.andrews.edu/'],
#   'name': 'Andrews University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['angelo.edu'],
#   'web_pages': ['http://www.angelo.edu/'],
#   'name': 'Angelo State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aacc.edu'],
#   'web_pages': ['http://www.aacc.edu/'],
#   'name': 'Anne Arundel Community College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['antiochne.edu'],
#   'web_pages': ['http://www.antiochne.edu/'],
#   'name': 'Antioch New England',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['antioch.edu'],
#   'web_pages': ['http://www.antioch.edu/'],
#   'name': 'Antioch University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['antiochla.edu'],
#   'web_pages': ['http://www.antiochla.edu/'],
#   'name': 'Antioch University - Los Angeles',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['seattleantioch.edu'],
#   'web_pages': ['http://www.seattleantioch.edu/'],
#   'name': 'Antioch University - Seattle',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['appstate.edu'],
#   'web_pages': ['http://www.appstate.edu/'],
#   'name': 'Appalachian State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aquinas.edu'],
#   'web_pages': ['http://www.aquinas.edu/'],
#   'name': 'Aquinas College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['arcadia.edu'],
#   'web_pages': ['http://www.arcadia.edu/'],
#   'name': 'Arcadia College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['asu.edu'],
#   'web_pages': ['http://www.asu.edu/'],
#   'name': 'Arizona State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['azwestern.edu'],
#   'web_pages': ['http://www.azwestern.edu/'],
#   'name': 'Arizona Western College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['astate.edu'],
#   'web_pages': ['http://www.astate.edu/'],
#   'name': 'Arkansas State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['atu.edu'],
#   'web_pages': ['http://www.atu.edu/'],
#   'name': 'Arkansas Tech University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['armstrong.edu'],
#   'web_pages': ['http://www.armstrong.edu/'],
#   'name': 'Armstrong State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ashland.edu'],
#   'web_pages': ['http://www.ashland.edu/'],
#   'name': 'Ashland University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['assumption.edu'],
#   'web_pages': ['http://www.assumption.edu/'],
#   'name': 'Assumption College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['auburn.edu'],
#   'web_pages': ['http://www.auburn.edu/'],
#   'name': 'Auburn University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aum.edu'],
#   'web_pages': ['http://www.aum.edu/'],
#   'name': 'Auburn University at Montgomery',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['augsburg.edu'],
#   'web_pages': ['http://www.augsburg.edu/'],
#   'name': 'Augsburg College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['augustana.edu'],
#   'web_pages': ['http://www.augustana.edu/'],
#   'name': 'Augustana College (IL)',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['augie.edu'],
#   'web_pages': ['http://www.augie.edu/'],
#   'name': 'Augustana College (SD)',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['augusta.edu', 'gru.edu'],
#   'web_pages': ['http://www.augusta.edu/', 'http://www.gru.edu/'],
#   'name': 'Augusta University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['aurora.edu'],
#   'web_pages': ['http://www.aurora.edu/'],
#   'name': 'Aurora University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['austincollege.edu'],
#   'web_pages': ['http://www.austincollege.edu/'],
#   'name': 'Austin College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['austincc.edu'],
#   'web_pages': ['http://www.austincc.edu/'],
#   'name': 'Austin Community College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['apsu.edu'],
#   'web_pages': ['http://www.apsu.edu/'],
#   'name': 'Austin Peay State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['averett.edu'],
#   'web_pages': ['http://www.averett.edu/'],
#   'name': 'Averett College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['avila.edu'],
#   'web_pages': ['http://www.avila.edu/'],
#   'name': 'Avila College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['apu.edu'],
#   'web_pages': ['http://www.apu.edu/'],
#   'name': 'Azusa Pacific University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['babson.edu'],
#   'web_pages': ['http://www.babson.edu/'],
#   'name': 'Babson College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bakeru.edu'],
#   'web_pages': ['http://www.bakeru.edu/'],
#   'name': 'Baker University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bsu.edu'],
#   'web_pages': ['http://www.bsu.edu/'],
#   'name': 'Ball State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bbc.edu'],
#   'web_pages': ['http://www.bbc.edu/'],
#   'name': 'Baptist Bible College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bard.edu'],
#   'web_pages': ['http://www.bard.edu/'],
#   'name': 'Bard College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['barry.edu'],
#   'web_pages': ['http://www.barry.edu/'],
#   'name': 'Barry University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bastyr.edu'],
#   'web_pages': ['http://www.bastyr.edu/'],
#   'name': 'Bastyr University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bates.edu'],
#   'web_pages': ['http://www.bates.edu/'],
#   'name': 'Bates College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bcm.edu'],
#   'web_pages': ['http://www.bcm.edu/'],
#   'name': 'Baylor College of Medicine',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['baylor.edu'],
#   'web_pages': ['http://www.baylor.edu/'],
#   'name': 'Baylor University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bellevue.edu'],
#   'web_pages': ['http://www.bellevue.edu/'],
#   'name': 'Bellevue University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['belmont.edu'],
#   'web_pages': ['http://www.belmont.edu/'],
#   'name': 'Belmont University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['beloit.edu'],
#   'web_pages': ['http://www.beloit.edu/'],
#   'name': 'Beloit College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bemidjistate.edu'],
#   'web_pages': ['http://www.bemidjistate.edu/'],
#   'name': 'Bemidji State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['benedictine.edu'],
#   'web_pages': ['http://www.benedictine.edu/'],
#   'name': 'Benedictine College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bennington.edu'],
#   'web_pages': ['http://www.bennington.edu/'],
#   'name': 'Bennington College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bentley.edu'],
#   'web_pages': ['http://www.bentley.edu/'],
#   'name': 'Bentley College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['berea.edu'],
#   'web_pages': ['http://www.berea.edu/'],
#   'name': 'Berea College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['berklee.edu'],
#   'web_pages': ['http://www.berklee.edu/'],
#   'name': 'Berklee College of Music',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bethanywv.edu'],
#   'web_pages': ['http://www.bethanywv.edu/'],
#   'name': 'Bethany College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bethelks.edu'],
#   'web_pages': ['http://www.bethelks.edu/'],
#   'name': 'Bethel College (KS)',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bethel.edu'],
#   'web_pages': ['http://www.bethel.edu/'],
#   'name': 'Bethel University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['biola.edu'],
#   'web_pages': ['http://www.biola.edu/'],
#   'name': 'Biola University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bsc.edu'],
#   'web_pages': ['http://www.bsc.edu/'],
#   'name': 'Birmingham-Southern College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bhsu.edu'],
#   'web_pages': ['http://www.bhsu.edu/'],
#   'name': 'Black Hills State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bloomu.edu'],
#   'web_pages': ['http://www.bloomu.edu/'],
#   'name': 'Bloomsburg University of Pennsylvania',
#   'alpha_two_code': 'US',
#   'state-province': 'Pennsylvania',
#   'country': 'United States'},
#  {'domains': ['bluffton.edu'],
#   'web_pages': ['http://www.bluffton.edu/'],
#   'name': 'Bluffton College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bju.edu'],
#   'web_pages': ['http://www.bju.edu/'],
#   'name': 'Bob Jones University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['boisestate.edu'],
#   'web_pages': ['http://www.boisestate.edu/'],
#   'name': 'Boise State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bc.edu'],
#   'web_pages': ['http://www.bc.edu/'],
#   'name': 'Boston College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bgsp.edu'],
#   'web_pages': ['http://www.bgsp.edu/'],
#   'name': 'Boston Graduate School of Psychoanalysis',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bu.edu'],
#   'web_pages': ['http://www.bu.edu/'],
#   'name': 'Boston University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bowdoin.edu'],
#   'web_pages': ['http://www.bowdoin.edu/'],
#   'name': 'Bowdoin College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bowiestate.edu'],
#   'web_pages': ['http://www.bowiestate.edu/'],
#   'name': 'Bowie State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bgsu.edu'],
#   'web_pages': ['http://www.bgsu.edu/'],
#   'name': 'Bowling Green State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bradley.edu'],
#   'web_pages': ['http://www.bradley.edu/'],
#   'name': 'Bradley University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['brandeis.edu'],
#   'web_pages': ['http://www.brandeis.edu/'],
#   'name': 'Brandeis University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['brenau.edu'],
#   'web_pages': ['http://www.brenau.edu/'],
#   'name': 'Brenau University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['briar-cliff.edu'],
#   'web_pages': ['http://www.briar-cliff.edu/'],
#   'name': 'Briar Cliff College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bridgewater.edu'],
#   'web_pages': ['http://www.bridgewater.edu/'],
#   'name': 'Bridgewater College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['byu.edu'],
#   'web_pages': ['http://www.byu.edu/'],
#   'name': 'Brigham Young University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['byui.edu'],
#   'web_pages': ['http://www.byui.edu/'],
#   'name': 'Brigham Young University - Idaho',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['byuh.edu'],
#   'web_pages': ['http://www.byuh.edu/'],
#   'name': 'Brigham Young University Hawaii',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['broward.edu'],
#   'web_pages': ['http://www.broward.edu/'],
#   'name': 'Broward College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['brown.edu'],
#   'web_pages': ['http://www.brown.edu/'],
#   'name': 'Brown University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bryant.edu'],
#   'web_pages': ['http://www.bryant.edu/'],
#   'name': 'Bryant College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['brynmawr.edu'],
#   'web_pages': ['http://www.brynmawr.edu/college'],
#   'name': 'Bryn Mawr College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bucknell.edu'],
#   'web_pages': ['http://www.bucknell.edu/'],
#   'name': 'Bucknell University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bvu.edu'],
#   'web_pages': ['http://www.bvu.edu/'],
#   'name': 'Buena Vista University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['butler.edu'],
#   'web_pages': ['http://www.butler.edu/'],
#   'name': 'Butler University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['calcoast.edu'],
#   'web_pages': ['http://www.calcoast.edu/'],
#   'name': 'California Coast University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['caltech.edu'],
#   'web_pages': ['http://www.caltech.edu/'],
#   'name': 'California Institute of Technology',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['callutheran.edu'],
#   'web_pages': ['http://www.callutheran.edu/'],
#   'name': 'California Lutheran University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csum.edu'],
#   'web_pages': ['http://www.csum.edu/'],
#   'name': 'California Maritime Academy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cnuas.edu'],
#   'web_pages': ['http://www.cnuas.edu/'],
#   'name': 'California National University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['calpoly.edu'],
#   'web_pages': ['http://www.calpoly.edu/'],
#   'name': 'California Polytechnic State University, San Luis Obispo',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csub.edu', 'csubak.edu'],
#   'web_pages': ['http://www.csub.edu/'],
#   'name': 'California State University, Bakersfield',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csuchico.edu'],
#   'web_pages': ['http://www.csuchico.edu/'],
#   'name': 'California State University, Chico',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csudh.edu'],
#   'web_pages': ['http://www.csudh.edu/'],
#   'name': 'California State University, Dominguez Hills',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csufresno.edu', 'fresnostate.edu'],
#   'web_pages': ['http://www.csufresno.edu/', 'http://www.fresnostate.edu/'],
#   'name': 'California State University, Fresno',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['fullerton.edu'],
#   'web_pages': ['http://www.fullerton.edu/'],
#   'name': 'California State University, Fullerton',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csuhayward.edu'],
#   'web_pages': ['http://www.csuhayward.edu/'],
#   'name': 'California State University, Hayward',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csulb.edu'],
#   'web_pages': ['http://www.csulb.edu/'],
#   'name': 'California State University, Long Beach',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['calstatela.edu'],
#   'web_pages': ['http://www.calstatela.edu/'],
#   'name': 'California State University, Los Angeles',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['monterey.edu'],
#   'web_pages': ['http://www.monterey.edu/'],
#   'name': 'California State University, Monterey Bay',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csun.edu'],
#   'web_pages': ['http://www.csun.edu/'],
#   'name': 'California State University, Northridge',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csus.edu'],
#   'web_pages': ['http://www.csus.edu/'],
#   'name': 'California State University, Sacramento',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csusb.edu'],
#   'web_pages': ['http://www.csusb.edu/'],
#   'name': 'California State University, San Bernardino',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csusm.edu'],
#   'web_pages': ['http://www.csusm.edu/'],
#   'name': 'California State University, San Marcos',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['csustan.edu'],
#   'web_pages': ['http://www.csustan.edu/'],
#   'name': 'California State University, Stanislaus',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['calstate.edu'],
#   'web_pages': ['http://www.calstate.edu/'],
#   'name': 'California State University System',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cup.edu'],
#   'web_pages': ['http://www.cup.edu/'],
#   'name': 'California University of Pennsylvania',
#   'alpha_two_code': 'US',
#   'state-province': 'Pennsylvania',
#   'country': 'United States'},
#  {'domains': ['calvin.edu'],
#   'web_pages': ['http://www.calvin.edu/'],
#   'name': 'Calvin College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['cameron.edu'],
#   'web_pages': ['http://www.cameron.edu/'],
#   'name': 'Cameron University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['campbellsville.edu'],
#   'web_pages': ['http://www.campbellsville.edu/'],
#   'name': 'Campbellsville College',
# ...
#   'country': 'United States'},
#  {'domains': ['tesc.edu', 'tesu.edu'],
#   'web_pages': ['http://www.tesc.edu/', 'http://www.tesu.edu/'],
#   'name': 'Thomas Edison State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tju.edu'],
#   'web_pages': ['http://www.tju.edu/'],
#   'name': 'Thomas Jefferson University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['thomasmore.edu'],
#   'web_pages': ['http://www.thomasmore.edu/'],
#   'name': 'Thomas More College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['thunderbird.edu'],
#   'web_pages': ['http://www.thunderbird.edu/'],
#   'name': 'Thunderbird School of Global Management',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['towson.edu'],
#   'web_pages': ['http://www.towson.edu/'],
#   'name': 'Towson University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['transy.edu'],
#   'web_pages': ['http://www.transy.edu/'],
#   'name': 'Transylvania University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['trenton.edu'],
#   'web_pages': ['http://www.trenton.edu/'],
#   'name': 'Trenton State College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['trine.edu'],
#   'web_pages': ['http://www.trine.edu/'],
#   'name': 'Trine University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['trincoll.edu'],
#   'web_pages': ['http://www.trincoll.edu/'],
#   'name': 'Trinity College (CT)',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['trinitydc.edu'],
#   'web_pages': ['http://www.trinitydc.edu'],
#   'name': 'Trinity College (DC)',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['trinity.edu'],
#   'web_pages': ['http://www.trinity.edu/'],
#   'name': 'Trinity University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tsufl.edu'],
#   'web_pages': ['http://www.tsufl.edu/'],
#   'name': 'Troy State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['truman.edu'],
#   'web_pages': ['http://www.truman.edu/'],
#   'name': 'Truman State University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tucsonu.edu'],
#   'web_pages': ['http://www.tucsonu.edu/'],
#   'name': 'Tucson University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tufts.edu'],
#   'web_pages': ['http://www.tufts.edu/'],
#   'name': 'Tufts University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tulane.edu'],
#   'web_pages': ['http://www.tulane.edu/'],
#   'name': 'Tulane University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tuskegee.edu'],
#   'web_pages': ['http://www.tuskegee.edu/'],
#   'name': 'Tuskegee University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['usuhs.mil'],
#   'web_pages': ['http://www.usuhs.mil/'],
#   'name': 'Uniformed Services University of the Health Sciences',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['union.edu'],
#   'web_pages': ['http://www.union.edu/'],
#   'name': 'Union College',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['tui.edu'],
#   'web_pages': ['http://www.tui.edu/'],
#   'name': 'Union Institute',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uu.edu'],
#   'web_pages': ['http://www.uu.edu/'],
#   'name': 'Union University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['usafa.af.mil', 'usafa.edu'],
#   'web_pages': ['http://www.usafa.af.mil/', 'http://www.usafa.edu/'],
#   'name': 'United States Air Force Academy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['usiu.edu'],
#   'web_pages': ['http://www.usiu.edu/'],
#   'name': 'United States International University',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['usmma.edu'],
#   'web_pages': ['http://www.usmma.edu/'],
#   'name': 'United States Merchant Marine Academy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['usma.edu'],
#   'web_pages': ['http://www.usma.edu/'],
#   'name': 'United States Military Academy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['usna.edu'],
#   'web_pages': ['http://www.usna.edu/'],
#   'name': 'United States Naval Academy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uat.edu'],
#   'web_pages': ['http://www.uat.edu/'],
#   'name': 'University of Advancing Technology',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uakron.edu'],
#   'web_pages': ['http://www.uakron.edu/'],
#   'name': 'University of Akron',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uab.edu'],
#   'web_pages': ['http://www.uab.edu/'],
#   'name': 'University of Alabama at Birmingham',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uah.edu'],
#   'web_pages': ['http://www.uah.edu/'],
#   'name': 'University of Alabama at Huntsville',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ua.edu'],
#   'web_pages': ['http://www.ua.edu/'],
#   'name': 'University of Alabama at Tuscaloosa',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['alaska.edu'],
#   'web_pages': ['http://www.alaska.edu/'],
#   'name': 'University of Alaska',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uaa.alaska.edu'],
#   'web_pages': ['http://www.uaa.alaska.edu/'],
#   'name': 'University of Alaska - Anchorage',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uaf.edu'],
#   'web_pages': ['http://www.uaf.edu'],
#   'name': 'University of Alaska - Fairbanks',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uas.alaska.edu'],
#   'web_pages': ['http://www.uas.alaska.edu/'],
#   'name': 'University of Alaska - Southeast',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['arizona.edu'],
#   'web_pages': ['http://www.arizona.edu/'],
#   'name': 'University of Arizona',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uark.edu'],
#   'web_pages': ['http://www.uark.edu/'],
#   'name': 'University of Arkansas - Fayetteville',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uafs.edu'],
#   'web_pages': ['http://www.uafs.edu/'],
#   'name': 'University of Arkansas - Fort Smith',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uams.edu'],
#   'web_pages': ['http://www.uams.edu/'],
#   'name': 'University of Arkansas for Medical Sciences',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ualr.edu'],
#   'web_pages': ['http://www.ualr.edu/'],
#   'name': 'University of Arkansas - Little Rock',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uamont.edu'],
#   'web_pages': ['http://www.uamont.edu/'],
#   'name': 'University of Arkansas - Monticello',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ubalt.edu'],
#   'web_pages': ['http://www.ubalt.edu/'],
#   'name': 'University of Baltimore',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['bridgeport.edu'],
#   'web_pages': ['http://www.bridgeport.edu/'],
#   'name': 'University of Bridgeport',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['berkeley.edu'],
#   'web_pages': ['http://www.berkeley.edu/'],
#   'name': 'University of California, Berkeley',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucdavis.edu'],
#   'web_pages': ['http://www.ucdavis.edu/'],
#   'name': 'University of California, Davis',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uci.edu'],
#   'web_pages': ['http://www.uci.edu/'],
#   'name': 'University of California, Irvine',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucla.edu'],
#   'web_pages': ['http://www.ucla.edu/'],
#   'name': 'University of California, Los Angeles',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucmerced.edu'],
#   'web_pages': ['http://www.ucmerced.edu/'],
#   'name': 'University of California, Merced',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucop.edu'],
#   'web_pages': ['https://www.ucop.edu/'],
#   'name': 'University of California, Office of the President',
#   'alpha_two_code': 'US',
#   'state-province': 'CA',
#   'country': 'United States'},
#  {'domains': ['ucr.edu'],
#   'web_pages': ['http://www.ucr.edu/'],
#   'name': 'University of California, Riverside',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucsd.edu'],
#   'web_pages': ['http://www.ucsd.edu/'],
#   'name': 'University of California, San Diego',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucsf.edu'],
#   'web_pages': ['http://www.ucsf.edu/'],
#   'name': 'University of California, San Francisco',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucsb.edu'],
#   'web_pages': ['http://www.ucsb.edu/'],
#   'name': 'University of California, Santa Barbara',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucsc.edu'],
#   'web_pages': ['http://www.ucsc.edu/'],
#   'name': 'University of California, Santa Cruz',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uca.edu'],
#   'web_pages': ['http://www.uca.edu/'],
#   'name': 'University of Central Arkansas',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucf.edu'],
#   'web_pages': ['http://www.ucf.edu/'],
#   'name': 'University of Central Florida',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucmo.edu'],
#   'web_pages': ['http://www.ucmo.edu/'],
#   'name': 'University of Central Missouri',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uchastings.edu'],
#   'web_pages': ['http://www.uchastings.edu/'],
#   'name': 'UC Hastings College of the Law',
#   'alpha_two_code': 'US',
#   'state-province': 'CA',
#   'country': 'United States'},
#  {'domains': ['uchaswv.edu'],
#   'web_pages': ['http://www.uchaswv.edu/'],
#   'name': 'University of Charleston',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uchicago.edu'],
#   'web_pages': ['http://www.uchicago.edu/'],
#   'name': 'University of Chicago',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uc.edu'],
#   'web_pages': ['http://www.uc.edu/'],
#   'name': 'University of Cincinnati',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['colorado.edu'],
#   'web_pages': ['http://www.colorado.edu/'],
#   'name': 'University of Colorado at Boulder',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uccs.edu'],
#   'web_pages': ['http://www.uccs.edu/'],
#   'name': 'University of Colorado at Colorado Springs',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ucdenver.edu'],
#   'web_pages': ['http://www.ucdenver.edu/'],
#   'name': 'University of Colorado at Denver',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['hsc.colorado.edu'],
#   'web_pages': ['http://www.hsc.colorado.edu/'],
#   'name': 'University of Colorado Health Sciences Center',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uconn.edu'],
#   'web_pages': ['http://www.uconn.edu/'],
#   'name': 'University of Connecticut',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['udallas.edu'],
#   'web_pages': ['http://www.udallas.edu/'],
#   'name': 'University of Dallas',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['udayton.edu'],
#   'web_pages': ['http://www.udayton.edu/'],
#   'name': 'University of Dayton',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['udel.edu'],
#   'web_pages': ['http://www.udel.edu/'],
#   'name': 'University of Delaware',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['du.edu'],
#   'web_pages': ['http://www.du.edu/'],
#   'name': 'University of Denver',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['udmercy.edu'],
#   'web_pages': ['http://www.udmercy.edu/'],
#   'name': 'University of Detroit Mercy',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['dbq.edu'],
#   'web_pages': ['http://www.dbq.edu/'],
#   'name': 'University of Dubuque',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['evansville.edu'],
#   'web_pages': ['http://www.evansville.edu/'],
#   'name': 'University of Evansville',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ufl.edu'],
#   'web_pages': ['http://www.ufl.edu/'],
#   'name': 'University of Florida',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uga.edu'],
#   'web_pages': ['http://www.uga.edu/'],
#   'name': 'University of Georgia',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['ugf.edu'],
#   'web_pages': ['http://www.ugf.edu/'],
#   'name': 'University of Great Falls',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['uog.edu'],
#   'web_pages': ['http://www.uog.edu/'],
#   'name': 'University of Guam',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['hartford.edu'],
#   'web_pages': ['http://www.hartford.edu/'],
#   'name': 'University of Hartford',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['hilo.hawaii.edu'],
#   'web_pages': ['http://hilo.hawaii.edu/'],
#   'name': 'University of Hawaii at Hilo',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['manoa.hawaii.edu'],
#   'web_pages': ['http://manoa.hawaii.edu/'],
#   'name': 'University of Hawaii at Manoa',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  {'domains': ['hawaii.edu'],
#   'web_pages': ['http://www.hawaii.edu/'],
#   'name': 'University of Hawaii System',
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'country': 'United States'},
#  ...]

# %% [markdown]
# **How to read JSON file in python**
#    - Another approach for reading json file through pandas module. `pd.read_json()`

# %%
#Another approach for reading json file through pandas module.
import pandas as pd
tweet=pd.read_json("college.json")
tweet.head()
# Out:
#             domains                     web_pages  \
# 0    [marywood.edu]     [http://www.marywood.edu]
# 1  [lindenwood.edu]  [http://www.lindenwood.edu/]
# 2    [sullivan.edu]       [https://sullivan.edu/]
# 3        [fscj.edu]       [https://www.fscj.edu/]
# 4      [xavier.edu]     [https://www.xavier.edu/]
#
#                                     name alpha_two_code state-province  \
# 0                    Marywood University             US           None
# 1                  Lindenwood University             US           None
# 2                    Sullivan University             US           None
# 3  Florida State College at Jacksonville             US           None
# 4                      Xavier University             US           None
#
#          country
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States

# %% [markdown]
# ### Regular Expressions
# - A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
# - RegEx can be used to check if a string contains the specified search pattern.
# - When you have imported the re module, you can start using regular expressions

# %%
s1 = 'Python is an excellent language'
s2 = 'I love the Python language. I also use Python to build applications at work!'

# %%
import re
pattern = 'python'
# match only returns a match if regex match is found at the beginning of the string
re.match(pattern, s1)

# %%
# pattern is in lower case hence ignore case flag helps
# in matching same pattern with different cases
re.match(pattern, s1, flags=re.IGNORECASE)
# Out:
# <re.Match object; span=(0, 6), match='Python'>

# %%
# printing matched string and its indices in the original string
m = re.match(pattern, s1, flags=re.IGNORECASE)
print('Found match {} ranging from index {} - {} in the string "{}"'.format(m.group(0), 
                                                                            m.start(), 
                                                                            m.end(), s1))
# Out:
# Found match Python ranging from index 0 - 6 in the string "Python is an excellent language"

# %%
# we use re.search to match word anywhere within the string.
import re
fhand=open('myfile.txt')
for line in fhand:
    line=line.rstrip()
    if re.search('how',line): # Checks the 'Pattern' to be search. Returns True or False
        print(line)
fhand.close()
# Out:
# hello how are you?
# hello there how do you do?

# %%
# Display only those lines which are starting with 'I am'
import re
fhand=open('myfile.txt')
for line in fhand:
    line=line.rstrip()
    if re.search('^I am',line): #here we use search modulr to match the
        print(line)
fhand.close()
# Out:
# I am doing good

# %%
#Demo of findall() method
# Extract domain from a given string
import re
s='A message from csev@umich.edu to cwen@iupui.edu about meeting @2PM'
ls=re.findall('\S+@\S+',s)
print(ls)

# Extract only the domain names
for email in ls:
    x=email.find('@')
    print(email[x+1:])
# Out:
# ['csev@umich.edu', 'cwen@iupui.edu']
# umich.edu
# iupui.edu

# %%
# illustrating pattern substitution using sub and subn methods
re.sub(pattern, 'Java', s2, flags=re.IGNORECASE)
# Out:
# 'I love the Java language. I also use Java to build applications at work!'

# %%
re.subn(pattern, 'Java', s2, flags=re.IGNORECASE)
# Out:
# ('I love the Java language. I also use Java to build applications at work!', 2)

# %% [markdown]
# ### NLTK
# (Natural Language Toolkit) is a suite that contains libraries and programs for statistical language processing. It is one of the most powerful NLP libraries, which contains packages to make machines understand human language and reply to it with an appropriate response.
#
# - if nltk library is not install use pip method to install it.
#
# **!pip install nltk**
#
# after installation use nltk.download to install all the other packages of nltk.
#
#
# ![Capture.PNG](attachment:Capture.PNG)

# %%
import nltk

# %%
#nltk.download()

# %% [markdown]
# ## Text Preprocessing
#
# Since text is the most unstructured form of all the available data, various types of noise are present in it and the data is not readily analyzable without any pre-processing. The entire process of cleaning and standardization of text, making it noise-free and ready for analysis, is known as text preprocessing.
#
#
# ![The text data preprocessing framework.](https://www.kdnuggets.com/wp-content/uploads/text-preprocessing-framework-2.png)
# ### Basic Text Pre-processing of text data
# - Case Conversion
# - Punctuation removal
# - Stopwords removal
# - Spelling correction
# - Tokenization
# - Stemming
# - Lemmatization

# %% [markdown]
# ### Case Conversion
#
# If the text is in the same case, it is easy for a machine to interpret the words because the lower case and upper case are treated differently by the machine. For example, words like Ball and ball are treated differently by machine. So, we need to make the text in the same case and the most preferred case is a lower case to avoid such problems.

# %%
text='Natural language processing (NLP), describes the interaction between human language and computers.'
text
# Out:
# 'Natural language processing (NLP), describes the interaction between human language and computers.'

# %%
#conversion of text into lower case.
text.lower()
# Out:
# 'natural language processing (nlp), describes the interaction between human language and computers.'

# %%
#conversion of text into upper letter.
text.upper()
# Out:
# 'NATURAL LANGUAGE PROCESSING (NLP), DESCRIBES THE INTERACTION BETWEEN HUMAN LANGUAGE AND COMPUTERS.'

# %%
# Load the imdb review dataset 
imdb=pd.read_csv('imdb_sentiment.csv')

# %%
#converting each review into lower to avoid duplication of word in sentence.
imdb['review']=imdb['review'].apply(lambda x :x.lower())
imdb['review']
# Out:
# 0      a very, very, very slow-moving, aimless movie ...
# 1      not sure who was more lost - the flat characte...
# 2      attempting artiness with black & white and cle...
# 3           very little music or anything to speak of.
# 4      the best scene in the movie was when gerardo i...
#                              ...
# 743    i just got bored watching jessice lange take h...
# 744    unfortunately, any virtue in this film's produ...
# 745                     in a word, it is embarrassing.
# 746                                 exceptionally bad!
# 747    all in all its an insult to one's intelligence...
# Name: review, Length: 748, dtype: object

# %% [markdown]
# ### Punctuation Removal
# One of the other text processing techniques is removing punctuations. There are total 32 main punctuations that need to be taken care of. We can directly use the string module with a regular expression to replace any punctuation in text with an empty string.

# %%
#removal of punctuation using regex.
text
# Out:
# 'Natural language processing (NLP), describes the interaction between human language and computers.'

# %%
text=re.sub(r'[^\w\s]','',text) #remove everything except words and space
text
# Out:
# 'Natural language processing NLP describes the interaction between human language and computers'

# %%
imdb['clean']=imdb['review'].apply(lambda x : re.sub(r'[^\w\s]',' ',x))

# %%
imdb['clean']
# Out:
# 0      a very  very  very slow moving  aimless movie ...
# 1      not sure who was more lost   the flat characte...
# 2      attempting artiness with black   white and cle...
# 3           very little music or anything to speak of
# 4      the best scene in the movie was when gerardo i...
#                              ...
# 743    i just got bored watching jessice lange take h...
# 744    unfortunately  any virtue in this film s produ...
# 745                     in a word  it is embarrassing
# 746                                 exceptionally bad
# 747    all in all its an insult to one s intelligence...
# Name: clean, Length: 748, dtype: object

# %%
#remove punctuation using string module
import string
imdb['clean1']=imdb['review'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '' , x))

# %%
imdb['clean1']
# Out:
# 0      a very very very slowmoving aimless movie abou...
# 1      not sure who was more lost  the flat character...
# 2      attempting artiness with black  white and clev...
# 3            very little music or anything to speak of
# 4      the best scene in the movie was when gerardo i...
#                              ...
# 743    i just got bored watching jessice lange take h...
# 744    unfortunately any virtue in this films product...
# 745                       in a word it is embarrassing
# 746                                  exceptionally bad
# 747    all in all its an insult to ones intelligence ...
# Name: clean1, Length: 748, dtype: object

# %% [markdown]
# ### What are stop words?
#
# Stopwords are the words in any language which does not add much meaning to a sentence. They can be safely ignored without sacrificing the meaning of the sentence. For some search engines, these are some of the most common, short function words, such as the, is, at, which, and on. In this case, stop words can cause problems when searching for phrases that include them, particularly in names such as “The Who” or “Take That”.
#
# ### When to remove stop words?
#
# If we have a task of text classification or sentiment analysis then we should remove stop words as they do not provide any information to our model, i.e keeping out unwanted words out of our corpus, but if we have the task of language translation then stopwords are useful, as they have to be translated along with other words.
#
# There is no hard and fast rule on when to remove stop words. But I would suggest removing stop words if our task to be performed is one of Language Classification, Spam Filtering, Caption Generation, Auto-Tag Generation, Sentiment analysis, or something that is related to text classification.
#
# On the other hand, if our task is one of Machine Translation, Question-Answering problems, Text Summarization, Language Modeling, it’s better not to remove the stop words as they are a crucial part of these applications.
#
# ### Stopword Removal

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
print('This are the stopwords',stop)
# Out:
# This are the stopwords ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
text
# Out:
# 'Natural language processing NLP describes the interaction between human language and computers'

# %%
text=' '.join([x for x in text.split() if x not in stop]) #here we are spltting the text and then removing the stop word from list
#and theb join the list to string.
text
# Out:
# 'Natural language processing NLP describes interaction human language computers'

# %%
#removing stop words from reviews.
imdb['clean']=imdb['clean'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
imdb['clean']
# Out:
# 0      slow moving aimless movie distressed drifting ...
# 1      sure lost flat characters audience nearly half...
# 2      attempting artiness black white clever camera ...
# 3                            little music anything speak
# 4      best scene movie gerardo trying find song keep...
#                              ...
# 743        got bored watching jessice lange take clothes
# 744    unfortunately virtue film production work lost...
# 745                                    word embarrassing
# 746                                    exceptionally bad
# 747             insult one intelligence huge waste money
# Name: clean, Length: 748, dtype: object

# %% [markdown]
# - Now we can see that stop words like `"very", "a"` is removed from the review.

# %% [markdown]
# ### Spell checks
#
# Spelling mistakes are common and most of us are used to software indicating if a mistake was made or not. From autocorrect on our phones to red underlining in text editors, spell checking is an essential feature for many different products.
#
# #### If textBlob is not install use pip method to install it.
# **pip install textblob**

# %%
# Many a time some words are spelt wrongly by author either by mistake or due to typing error 
# So corpus of our word increases due to wrong spellings, hence we correct them
# We will use textBlob module.
# If textBlob is not install use pip method to install it.
#pip install textblob
from textblob import TextBlob

# %%
text_='hostipal is far'# here spelling of hospital is worng.

# %% [markdown]
# - The correct() Function
# - The most straightforward way to correct input text is to use the correct() method

# %%
text_=TextBlob(text_).correct() # from textblob we use correct to corrrect the spellings.
text_
# Out:
# TextBlob("hospital is far")

# %%
# same way we can use for reviews
imdb['clean'][:10].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0    slow moving aimless movie distressed drifting ...
# 1    sure lost flat characters audience nearly half...
# 2    attempting artless black white clever camera a...
# 3                          little music anything speak
# 4    best scene movie gerard trying find song keeps...
# 5    rest movie lacks art charm meaning emptiness w...
# 6                                     wasted two hours
# 7    saw movie today thought good effort good messa...
# 8                                      bit predictable
# 9          loved casting jimmy buffets science teacher
# Name: clean, dtype: object

# %% [markdown]
# ## Tokenization
#
# Tokenization is splititng the large chunk of word, sentence,document in to smaller unit (single word or combination of words). Smaller units are known as tokens.
#
#
# ### Why is Tokenization required in NLP?
#
# Before processing a natural language, we need to identify the words that constitute a string of characters. That’s why tokenization is the most basic step to proceed with NLP (text data). This is important because the meaning of the text could easily be interpreted by analyzing the words present in the text.
#
# ### Tokenization using split()
#
# Let’s start with the split() method as it is the most basic one. It returns a list of strings after breaking the given string by the specified separator. By default, split() breaks a string at each space. We can change the separator to anything.

# %%
# Split is the most basic tokenizing technique.here we splited on the whitespaces. It split and return the list of all the words.
Text="""Because of problems with her eyesight, rey the African penguin had issues with swimming. That’s unusual for a penguin,
and presented a big challenge for our aviculture team to help Rey overcome her hesitancy.
Slowly and steadily, we trained her to be comfortable feeding in the water like the rest of the penguin colony.
The aviculturists also trained Rey to accept daily eye drops from them as part of her special health care.
Rey already had good relationships with some staff, and was comfortable with them handling her.
Senior Aviculturist Kim Fukuda says the team built on those bonds to get Rey used to receiving the eye drops.
"She knows the routine," Kim says. "I usually give her the eye drops in one area of the exhibit after all the penguins get
their vitamins. When that happens, she runs over there and waits for me." Rosa, our oldest sea otter, has very limited eyesight,
among other health issues. The sea otter team had already trained Rosa so they could examine her eyes,
and built on that trust to include administering the eye drops she needs."""
Text.split()
# Out:
# ['Because',
#  'of',
#  'problems',
#  'with',
#  'her',
#  'eyesight,',
#  'rey',
#  'the',
#  'African',
#  'penguin',
#  'had',
#  'issues',
#  'with',
#  'swimming.',
#  'That’s',
#  'unusual',
#  'for',
#  'a',
#  'penguin,',
#  'and',
#  'presented',
#  'a',
#  'big',
#  'challenge',
#  'for',
#  'our',
#  'aviculture',
#  'team',
#  'to',
#  'help',
#  'Rey',
#  'overcome',
#  'her',
#  'hesitancy.',
#  'Slowly',
#  'and',
#  'steadily,',
#  'we',
#  'trained',
#  'her',
#  'to',
#  'be',
#  'comfortable',
#  'feeding',
#  'in',
#  'the',
#  'water',
#  'like',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'penguin',
#  'colony.',
#  'The',
#  'aviculturists',
#  'also',
#  'trained',
#  'Rey',
#  'to',
#  'accept',
#  'daily',
#  'eye',
#  'drops',
#  'from',
#  'them',
#  'as',
#  'part',
#  'of',
#  'her',
#  'special',
#  'health',
#  'care.',
#  'Rey',
#  'already',
#  'had',
#  'good',
#  'relationships',
#  'with',
#  'some',
#  'staff,',
#  'and',
#  'was',
#  'comfortable',
#  'with',
#  'them',
#  'handling',
#  'her.',
#  'Senior',
#  'Aviculturist',
#  'Kim',
#  'Fukuda',
#  'says',
#  'the',
#  'team',
#  'built',
#  'on',
#  'those',
#  'bonds',
#  'to',
#  'get',
#  'Rey',
#  'used',
#  'to',
#  'receiving',
#  'the',
#  'eye',
#  'drops.',
#  '"She',
#  'knows',
#  'the',
#  'routine,"',
#  'Kim',
#  'says.',
#  '"I',
#  'usually',
#  'give',
#  'her',
#  'the',
#  'eye',
#  'drops',
#  'in',
#  'one',
#  'area',
#  'of',
#  'the',
#  'exhibit',
#  'after',
#  'all',
#  'the',
#  'penguins',
#  'get',
#  'their',
#  'vitamins.',
#  'When',
#  'that',
#  'happens,',
#  'she',
#  'runs',
#  'over',
#  'there',
#  'and',
#  'waits',
#  'for',
#  'me."',
#  'Rosa,',
#  'our',
#  'oldest',
#  'sea',
#  'otter,',
#  'has',
#  'very',
#  'limited',
#  'eyesight,',
#  'among',
#  'other',
#  'health',
#  'issues.',
#  'The',
#  'sea',
#  'otter',
#  'team',
#  'had',
#  'already',
#  'trained',
#  'Rosa',
#  'so',
#  'they',
#  'could',
#  'examine',
#  'her',
#  'eyes,',
#  'and',
#  'built',
#  'on',
#  'that',
#  'trust',
#  'to',
#  'include',
#  'administering',
#  'the',
#  'eye',
#  'drops',
#  'she',
#  'needs.']

# %% [markdown]
# ### Tokenization using regex.
#
# The re.findall() function finds all the words that match the pattern passed on it and stores it in the list.
# The “\w” represents “any word character” which usually means alphanumeric (letters, numbers) and underscore (_). ‘+’ means any number of times. So [\w’]+ signals that the code should find all the alphanumeric characters until any other character is encountered.

# %%
# we will use re library in Python to work with regular expression.
tokens = re.findall("[\w']+", Text)
tokens
# Out:
# ['Because',
#  'of',
#  'problems',
#  'with',
#  'her',
#  'eyesight',
#  'rey',
#  'the',
#  'African',
#  'penguin',
#  'had',
#  'issues',
#  'with',
#  'swimming',
#  'That',
#  's',
#  'unusual',
#  'for',
#  'a',
#  'penguin',
#  'and',
#  'presented',
#  'a',
#  'big',
#  'challenge',
#  'for',
#  'our',
#  'aviculture',
#  'team',
#  'to',
#  'help',
#  'Rey',
#  'overcome',
#  'her',
#  'hesitancy',
#  'Slowly',
#  'and',
#  'steadily',
#  'we',
#  'trained',
#  'her',
#  'to',
#  'be',
#  'comfortable',
#  'feeding',
#  'in',
#  'the',
#  'water',
#  'like',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'penguin',
#  'colony',
#  'The',
#  'aviculturists',
#  'also',
#  'trained',
#  'Rey',
#  'to',
#  'accept',
#  'daily',
#  'eye',
#  'drops',
#  'from',
#  'them',
#  'as',
#  'part',
#  'of',
#  'her',
#  'special',
#  'health',
#  'care',
#  'Rey',
#  'already',
#  'had',
#  'good',
#  'relationships',
#  'with',
#  'some',
#  'staff',
#  'and',
#  'was',
#  'comfortable',
#  'with',
#  'them',
#  'handling',
#  'her',
#  'Senior',
#  'Aviculturist',
#  'Kim',
#  'Fukuda',
#  'says',
#  'the',
#  'team',
#  'built',
#  'on',
#  'those',
#  'bonds',
#  'to',
#  'get',
#  'Rey',
#  'used',
#  'to',
#  'receiving',
#  'the',
#  'eye',
#  'drops',
#  'She',
#  'knows',
#  'the',
#  'routine',
#  'Kim',
#  'says',
#  'I',
#  'usually',
#  'give',
#  'her',
#  'the',
#  'eye',
#  'drops',
#  'in',
#  'one',
#  'area',
#  'of',
#  'the',
#  'exhibit',
#  'after',
#  'all',
#  'the',
#  'penguins',
#  'get',
#  'their',
#  'vitamins',
#  'When',
#  'that',
#  'happens',
#  'she',
#  'runs',
#  'over',
#  'there',
#  'and',
#  'waits',
#  'for',
#  'me',
#  'Rosa',
#  'our',
#  'oldest',
#  'sea',
#  'otter',
#  'has',
#  'very',
#  'limited',
#  'eyesight',
#  'among',
#  'other',
#  'health',
#  'issues',
#  'The',
#  'sea',
#  'otter',
#  'team',
#  'had',
#  'already',
#  'trained',
#  'Rosa',
#  'so',
#  'they',
#  'could',
#  'examine',
#  'her',
#  'eyes',
#  'and',
#  'built',
#  'on',
#  'that',
#  'trust',
#  'to',
#  'include',
#  'administering',
#  'the',
#  'eye',
#  'drops',
#  'she',
#  'needs']

# %% [markdown]
# - The re.findall() function finds all the words that match the pattern passed on it and stores it in the list.
# -  The “\w” represents “any word character” which usually means alphanumeric (letters, numbers) and underscore (_). ‘+’ means any number of times.

# %% [markdown]
# ### Tokenization using NLTK
#
# NLTK contains a module called tokenize() which further classifies into two sub-categories:
#
# - Word tokenize: We use the word_tokenize() method to split a sentence into tokens or words.
# - Sentence tokenize: We use the sent_tokenize() method to split a document or paragraph into sentences.

# %%
#Tokenize module have further 2 module. word_tokenize, sentence_tokenize.
from nltk.tokenize import word_tokenize
token=word_tokenize(Text)
token
# Out:
# ['Because',
#  'of',
#  'problems',
#  'with',
#  'her',
#  'eyesight',
#  ',',
#  'rey',
#  'the',
#  'African',
#  'penguin',
#  'had',
#  'issues',
#  'with',
#  'swimming',
#  '.',
#  'That',
#  '’',
#  's',
#  'unusual',
#  'for',
#  'a',
#  'penguin',
#  ',',
#  'and',
#  'presented',
#  'a',
#  'big',
#  'challenge',
#  'for',
#  'our',
#  'aviculture',
#  'team',
#  'to',
#  'help',
#  'Rey',
#  'overcome',
#  'her',
#  'hesitancy',
#  '.',
#  'Slowly',
#  'and',
#  'steadily',
#  ',',
#  'we',
#  'trained',
#  'her',
#  'to',
#  'be',
#  'comfortable',
#  'feeding',
#  'in',
#  'the',
#  'water',
#  'like',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'penguin',
#  'colony',
#  '.',
#  'The',
#  'aviculturists',
#  'also',
#  'trained',
#  'Rey',
#  'to',
#  'accept',
#  'daily',
#  'eye',
#  'drops',
#  'from',
#  'them',
#  'as',
#  'part',
#  'of',
#  'her',
#  'special',
#  'health',
#  'care',
#  '.',
#  'Rey',
#  'already',
#  'had',
#  'good',
#  'relationships',
#  'with',
#  'some',
#  'staff',
#  ',',
#  'and',
#  'was',
#  'comfortable',
#  'with',
#  'them',
#  'handling',
#  'her',
#  '.',
#  'Senior',
#  'Aviculturist',
#  'Kim',
#  'Fukuda',
#  'says',
#  'the',
#  'team',
#  'built',
#  'on',
#  'those',
#  'bonds',
#  'to',
#  'get',
#  'Rey',
#  'used',
#  'to',
#  'receiving',
#  'the',
#  'eye',
#  'drops',
#  '.',
#  '``',
#  'She',
#  'knows',
#  'the',
#  'routine',
#  ',',
#  "''",
#  'Kim',
#  'says',
#  '.',
#  '``',
#  'I',
#  'usually',
#  'give',
#  'her',
#  'the',
#  'eye',
#  'drops',
#  'in',
#  'one',
#  'area',
#  'of',
#  'the',
#  'exhibit',
#  'after',
#  'all',
#  'the',
#  'penguins',
#  'get',
#  'their',
#  'vitamins',
#  '.',
#  'When',
#  'that',
#  'happens',
#  ',',
#  'she',
#  'runs',
#  'over',
#  'there',
#  'and',
#  'waits',
#  'for',
#  'me',
#  '.',
#  "''",
#  'Rosa',
#  ',',
#  'our',
#  'oldest',
#  'sea',
#  'otter',
#  ',',
#  'has',
#  'very',
#  'limited',
#  'eyesight',
#  ',',
#  'among',
#  'other',
#  'health',
#  'issues',
#  '.',
#  'The',
#  'sea',
#  'otter',
#  'team',
#  'had',
#  'already',
#  'trained',
#  'Rosa',
#  'so',
#  'they',
#  'could',
#  'examine',
#  'her',
#  'eyes',
#  ',',
#  'and',
#  'built',
#  'on',
#  'that',
#  'trust',
#  'to',
#  'include',
#  'administering',
#  'the',
#  'eye',
#  'drops',
#  'she',
#  'needs',
#  '.']

# %% [markdown]
# - NLTK consider punctuation as tokens. so we can remove the punctuation for further use.

# %% [markdown]
# ### Tokenization using the spaCy library
#
# spaCy is an open-source library for advanced Natural Language Processing (NLP). It supports over 49+ languages and provides state-of-the-art computation speed.
# - Spacy is faster than its other contenders
#
# Installation of Spacy
#
# **pip install -U pip setuptools wheel**
#
# **pip install -U spacy**
#
# **python -m spacy download en_core_web_sm**

# %%
# if spacy is not installed, use pip method to install it
# import library.
from spacy.lang.en import English
# Load English tokenizer
nlp = English()

# %%
my_doc = nlp(Text)
# Create list of word tokens
token_list = []
for token in my_doc:
    token_list.append(token.text)
token_list
# Out:
# ['Because',
#  'of',
#  'problems',
#  'with',
#  'her',
#  'eyesight',
#  ',',
#  'rey',
#  'the',
#  'African',
#  'penguin',
#  'had',
#  'issues',
#  'with',
#  'swimming',
#  '.',
#  'That',
#  '’s',
#  'unusual',
#  'for',
#  'a',
#  'penguin',
#  ',',
#  '\n',
#  'and',
#  'presented',
#  'a',
#  'big',
#  'challenge',
#  'for',
#  'our',
#  'aviculture',
#  'team',
#  'to',
#  'help',
#  'Rey',
#  'overcome',
#  'her',
#  'hesitancy',
#  '.',
#  '\n',
#  'Slowly',
#  'and',
#  'steadily',
#  ',',
#  'we',
#  'trained',
#  'her',
#  'to',
#  'be',
#  'comfortable',
#  'feeding',
#  'in',
#  'the',
#  'water',
#  'like',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'penguin',
#  'colony',
#  '.',
#  '\n',
#  'The',
#  'aviculturists',
#  'also',
#  'trained',
#  'Rey',
#  'to',
#  'accept',
#  'daily',
#  'eye',
#  'drops',
#  'from',
#  'them',
#  'as',
#  'part',
#  'of',
#  'her',
#  'special',
#  'health',
#  'care',
#  '.',
#  '\n',
#  'Rey',
#  'already',
#  'had',
#  'good',
#  'relationships',
#  'with',
#  'some',
#  'staff',
#  ',',
#  'and',
#  'was',
#  'comfortable',
#  'with',
#  'them',
#  'handling',
#  'her',
#  '.',
#  '\n',
#  'Senior',
#  'Aviculturist',
#  'Kim',
#  'Fukuda',
#  'says',
#  'the',
#  'team',
#  'built',
#  'on',
#  'those',
#  'bonds',
#  'to',
#  'get',
#  'Rey',
#  'used',
#  'to',
#  'receiving',
#  'the',
#  'eye',
#  'drops',
#  '.',
#  '\n',
#  '"',
#  'She',
#  'knows',
#  'the',
#  'routine',
#  ',',
#  '"',
#  'Kim',
#  'says',
#  '.',
#  '"',
#  'I',
#  'usually',
#  'give',
#  'her',
#  'the',
#  'eye',
#  'drops',
#  'in',
#  'one',
#  'area',
#  'of',
#  'the',
#  'exhibit',
#  'after',
#  'all',
#  'the',
#  'penguins',
#  'get',
#  '\n',
#  'their',
#  'vitamins',
#  '.',
#  'When',
#  'that',
#  'happens',
#  ',',
#  'she',
#  'runs',
#  'over',
#  'there',
#  'and',
#  'waits',
#  'for',
#  'me',
#  '.',
#  '"',
#  'Rosa',
#  ',',
#  'our',
#  'oldest',
#  'sea',
#  'otter',
#  ',',
#  'has',
#  'very',
#  'limited',
#  'eyesight',
#  ',',
#  '\n',
#  'among',
#  'other',
#  'health',
#  'issues',
#  '.',
#  'The',
#  'sea',
#  'otter',
#  'team',
#  'had',
#  'already',
#  'trained',
#  'Rosa',
#  'so',
#  'they',
#  'could',
#  'examine',
#  'her',
#  'eyes',
#  ',',
#  '\n',
#  'and',
#  'built',
#  'on',
#  'that',
#  'trust',
#  'to',
#  'include',
#  'administering',
#  'the',
#  'eye',
#  'drops',
#  'she',
#  'needs',
#  '.']

# %%
#tokenizing the reviews of imdb datasets.
review=' '.join(imdb['review'])
my_doc = nlp(review)
# Create list of word tokens
token_list = []
for token in my_doc:
    token_list.append(token.text)
token_list
# Out:
# ['a',
#  'very',
#  ',',
#  'very',
#  ',',
#  'very',
#  'slow',
#  '-',
#  'moving',
#  ',',
#  'aimless',
#  'movie',
#  'about',
#  'a',
#  'distressed',
#  ',',
#  'drifting',
#  'young',
#  'man',
#  '.',
#  '  ',
#  'not',
#  'sure',
#  'who',
#  'was',
#  'more',
#  'lost',
#  '-',
#  'the',
#  'flat',
#  'characters',
#  'or',
#  'the',
#  'audience',
#  ',',
#  'nearly',
#  'half',
#  'of',
#  'whom',
#  'walked',
#  'out',
#  '.',
#  '  ',
#  'attempting',
#  'artiness',
#  'with',
#  'black',
#  '&',
#  'white',
#  'and',
#  'clever',
#  'camera',
#  'angles',
#  ',',
#  'the',
#  'movie',
#  'disappointed',
#  '-',
#  'became',
#  'even',
#  'more',
#  'ridiculous',
#  '-',
#  'as',
#  'the',
#  'acting',
#  'was',
#  'poor',
#  'and',
#  'the',
#  'plot',
#  'and',
#  'lines',
#  'almost',
#  'non',
#  '-',
#  'existent',
#  '.',
#  '  ',
#  'very',
#  'little',
#  'music',
#  'or',
#  'anything',
#  'to',
#  'speak',
#  'of',
#  '.',
#  '  ',
#  'the',
#  'best',
#  'scene',
#  'in',
#  'the',
#  'movie',
#  'was',
#  'when',
#  'gerardo',
#  'is',
#  'trying',
#  'to',
#  'find',
#  'a',
#  'song',
#  'that',
#  'keeps',
#  'running',
#  'through',
#  'his',
#  'head',
#  '.',
#  '  ',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'movie',
#  'lacks',
#  'art',
#  ',',
#  'charm',
#  ',',
#  'meaning',
#  '...',
#  'if',
#  'it',
#  "'s",
#  'about',
#  'emptiness',
#  ',',
#  'it',
#  'works',
#  'i',
#  'guess',
#  'because',
#  'it',
#  "'s",
#  'empty',
#  '.',
#  '  ',
#  'wasted',
#  'two',
#  'hours',
#  '.',
#  '  ',
#  'saw',
#  'the',
#  'movie',
#  'today',
#  'and',
#  'thought',
#  'it',
#  'was',
#  'a',
#  'good',
#  'effort',
#  ',',
#  'good',
#  'messages',
#  'for',
#  'kids',
#  '.',
#  '  ',
#  'a',
#  'bit',
#  'predictable',
#  '.',
#  '  ',
#  'loved',
#  'the',
#  'casting',
#  'of',
#  'jimmy',
#  'buffet',
#  'as',
#  'the',
#  'science',
#  'teacher',
#  '.',
#  '  ',
#  'and',
#  'those',
#  'baby',
#  'owls',
#  'were',
#  'adorable',
#  '.',
#  '  ',
#  'the',
#  'movie',
#  'showed',
#  'a',
#  'lot',
#  'of',
#  'florida',
#  'at',
#  'it',
#  "'s",
#  'best',
#  ',',
#  'made',
#  'it',
#  'look',
#  'very',
#  'appealing',
#  '.',
#  '  ',
#  'the',
#  'songs',
#  'were',
#  'the',
#  'best',
#  'and',
#  'the',
#  'muppets',
#  'were',
#  'so',
#  'hilarious',
#  '.',
#  '  ',
#  'it',
#  'was',
#  'so',
#  'cool',
#  '.',
#  '  ',
#  'this',
#  'is',
#  'a',
#  'very',
#  '"',
#  'right',
#  'on',
#  'case',
#  '"',
#  'movie',
#  'that',
#  'delivers',
#  'everything',
#  'almost',
#  'right',
#  'in',
#  'your',
#  'face',
#  '.',
#  '  ',
#  'it',
#  'had',
#  'some',
#  'average',
#  'acting',
#  'from',
#  'the',
#  'main',
#  'person',
#  ',',
#  'and',
#  'it',
#  'was',
#  'a',
#  'low',
#  'budget',
#  'as',
#  'you',
#  'clearly',
#  'can',
#  'see',
#  '.',
#  '  ',
#  'this',
#  'review',
#  'is',
#  'long',
#  'overdue',
#  ',',
#  'since',
#  'i',
#  'consider',
#  'a',
#  'tale',
#  'of',
#  'two',
#  'sisters',
#  'to',
#  'be',
#  'the',
#  'single',
#  'greatest',
#  'film',
#  'ever',
#  'made',
#  '.',
#  '  ',
#  'i',
#  "'ll",
#  'put',
#  'this',
#  'gem',
#  'up',
#  'against',
#  'any',
#  'movie',
#  'in',
#  'terms',
#  'of',
#  'screenplay',
#  ',',
#  'cinematography',
#  ',',
#  'acting',
#  ',',
#  'post',
#  '-',
#  'production',
#  ',',
#  'editing',
#  ',',
#  'directing',
#  ',',
#  'or',
#  'any',
#  'other',
#  'aspect',
#  'of',
#  'film',
#  '-',
#  'making',
#  '.',
#  '  ',
#  'it',
#  "'s",
#  'practically',
#  'perfect',
#  'in',
#  'all',
#  'of',
#  'them',
#  '\x96',
#  'a',
#  'true',
#  'masterpiece',
#  'in',
#  'a',
#  'sea',
#  'of',
#  'faux',
#  '"',
#  'masterpieces',
#  '.',
#  '   ',
#  'the',
#  'structure',
#  'of',
#  'this',
#  'film',
#  'is',
#  'easily',
#  'the',
#  'most',
#  'tightly',
#  'constructed',
#  'in',
#  'the',
#  'history',
#  'of',
#  'cinema',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'i',
#  'can',
#  'think',
#  'of',
#  'no',
#  'other',
#  'film',
#  'where',
#  'something',
#  'vitally',
#  'important',
#  'occurs',
#  'every',
#  'other',
#  'minute',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'in',
#  'other',
#  'words',
#  ',',
#  'the',
#  'content',
#  'level',
#  'of',
#  'this',
#  'film',
#  'is',
#  'enough',
#  'to',
#  'easily',
#  'fill',
#  'a',
#  'dozen',
#  'other',
#  'films',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'how',
#  'can',
#  'anyone',
#  'in',
#  'their',
#  'right',
#  'mind',
#  'ask',
#  'for',
#  'anything',
#  'more',
#  'from',
#  'a',
#  'movie',
#  'than',
#  'this',
#  '?',
#  ' \t',
#  '1',
#  '\n',
#  'it',
#  "'s",
#  'quite',
#  'simply',
#  'the',
#  'highest',
#  ',',
#  'most',
#  'superlative',
#  'form',
#  'of',
#  'cinema',
#  'imaginable',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'yes',
#  ',',
#  'this',
#  'film',
#  'does',
#  'require',
#  'a',
#  'rather',
#  'significant',
#  'amount',
#  'of',
#  'puzzle',
#  '-',
#  'solving',
#  ',',
#  'but',
#  'the',
#  'pieces',
#  'fit',
#  'together',
#  'to',
#  'create',
#  'a',
#  'beautiful',
#  'picture',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'this',
#  'short',
#  'film',
#  'certainly',
#  'pulls',
#  'no',
#  'punches',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'graphics',
#  'is',
#  'far',
#  'from',
#  'the',
#  'best',
#  'part',
#  'of',
#  'the',
#  'game',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'this',
#  'is',
#  'the',
#  'number',
#  'one',
#  'best',
#  'th',
#  'game',
#  'in',
#  'the',
#  'series',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'it',
#  'deserves',
#  'strong',
#  'love',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'it',
#  'is',
#  'an',
#  'insane',
#  'game',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'there',
#  'are',
#  'massive',
#  'levels',
#  ',',
#  'massive',
#  'unlockable',
#  'characters',
#  '...',
#  'it',
#  "'s",
#  'just',
#  'a',
#  'massive',
#  'game',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'waste',
#  'your',
#  'money',
#  'on',
#  'this',
#  'game',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'this',
#  'is',
#  'the',
#  'kind',
#  'of',
#  'money',
#  'that',
#  'is',
#  'wasted',
#  'properly',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'actually',
#  ',',
#  'the',
#  'graphics',
#  'were',
#  'good',
#  'at',
#  'the',
#  'time',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'today',
#  'the',
#  'graphics',
#  'are',
#  'crap',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'as',
#  'they',
#  'say',
#  'in',
#  'canada',
#  ',',
#  'this',
#  'is',
#  'the',
#  'fun',
#  'game',
#  ',',
#  'aye',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'this',
#  'game',
#  'rocks',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'buy',
#  'it',
#  ',',
#  'play',
#  'it',
#  ',',
#  'enjoy',
#  'it',
#  ',',
#  'love',
#  'it',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'it',
#  "'s",
#  'pure',
#  'brilliance',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'this',
#  'was',
#  'a',
#  'flick',
#  'doomed',
#  'from',
#  'its',
#  'conception',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'the',
#  'very',
#  'idea',
#  'of',
#  'it',
#  'was',
#  'lame',
#  '-',
#  'take',
#  'a',
#  'minor',
#  'character',
#  'from',
#  'a',
#  'mediocre',
#  'pg-13',
#  'film',
#  ',',
#  'and',
#  'make',
#  'a',
#  'complete',
#  'non',
#  '-',
#  'sequel',
#  'while',
#  'changing',
#  'its',
#  'tone',
#  'to',
#  'a',
#  'pg',
#  '-',
#  'rated',
#  'family',
#  'movie',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'i',
#  'was',
#  "n't",
#  'the',
#  'least',
#  'bit',
#  'interested',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'not',
#  'only',
#  'did',
#  'it',
#  'only',
#  'confirm',
#  'that',
#  'the',
#  'film',
#  'would',
#  'be',
#  'unfunny',
#  'and',
#  'generic',
#  ',',
#  'but',
#  'it',
#  'also',
#  'managed',
#  'to',
#  'give',
#  'away',
#  'the',
#  'entire',
#  'movie',
#  ';',
#  'and',
#  'i',
#  "'m",
#  'not',
#  'exaggerating',
#  '-',
#  'every',
#  'moment',
#  ',',
#  'every',
#  'plot',
#  'point',
#  ',',
#  'every',
#  'joke',
#  'is',
#  'told',
#  'in',
#  'the',
#  'trailer',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'but',
#  'it',
#  "'s",
#  'just',
#  'not',
#  'funny',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'but',
#  'even',
#  'the',
#  'talented',
#  'carrell',
#  'ca',
#  "n't",
#  'save',
#  'this',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'his',
#  'co',
#  '-',
#  'stars',
#  'do',
#  "n't",
#  'fare',
#  'much',
#  'better',
#  ',',
#  'with',
#  'people',
#  'like',
#  'morgan',
#  'freeman',
#  ',',
#  'jonah',
#  'hill',
#  ',',
#  'and',
#  'ed',
#  'helms',
#  'just',
#  'wasted',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'the',
#  'story',
#  'itself',
#  'is',
#  'just',
#  'predictable',
#  'and',
#  'lazy',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'the',
#  'only',
#  'real',
#  'effects',
#  'work',
#  'is',
#  'the',
#  'presence',
#  'of',
#  'all',
#  'the',
#  'animals',
#  ',',
#  'and',
#  'the',
#  'integration',
#  'of',
#  'those',
#  'into',
#  'the',
#  'scenes',
#  'is',
#  'some',
#  'of',
#  'the',
#  'worst',
#  'and',
#  'most',
#  'obvious',
#  'blue',
#  '/',
#  'green',
#  '-',
#  'screen',
#  'work',
#  'i',
#  "'ve",
#  'ever',
#  'seen',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'but',
#  'whatever',
#  'it',
#  'was',
#  'that',
#  'cost',
#  'them',
#  'so',
#  'much',
#  ',',
#  'it',
#  'did',
#  "n't",
#  'translate',
#  'to',
#  'quality',
#  ',',
#  'that',
#  "'s",
#  'for',
#  'sure',
#  '.',
#  ' \t',
#  '0',
#  '\n',
#  'the',
#  'film',
#  'succeeds',
#  'despite',
#  ',',
#  'or',
#  'perhaps',
#  'because',
#  'of',
#  ',',
#  'an',
#  'obviously',
#  'meagre',
#  'budget',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'i',
#  "'m",
#  'glad',
#  'the',
#  'film',
#  'did',
#  "n't",
#  'go',
#  'for',
#  'the',
#  'most',
#  'obvious',
#  'choice',
#  ',',
#  'as',
#  'a',
#  'lesser',
#  'film',
#  'certainly',
#  'would',
#  'have',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'in',
#  'addition',
#  'to',
#  'having',
#  'one',
#  'of',
#  'the',
#  'most',
#  'lovely',
#  'songs',
#  'ever',
#  'written',
#  ',',
#  'french',
#  'cancan',
#  'also',
#  'boasts',
#  'one',
#  'of',
#  'the',
#  'cutest',
#  'leading',
#  'ladies',
#  'ever',
#  'to',
#  'grace',
#  'the',
#  'screen',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'it',
#  "'s",
#  'hard',
#  'not',
#  'to',
#  'fall',
#  'head',
#  '-',
#  'over',
#  '-',
#  'heels',
#  'in',
#  'love',
#  'with',
#  'that',
#  'girl',
#  '.',
#  ' \t',
#  '1',
#  '\n',
#  'on',
#  'the',
#  'negative',
#  ',',
#  'it',
#  "'s",
#  'insipid',
#  'enough',
#  'to',
#  'cause',
#  'regret',
#  'for',
#  'another',
#  '2',
#  ...]

# %% [markdown]
# ### What is Stemming?
#
# Stemming is an elementary rule-based process for removing inflectional forms from a token and the outputs are the stem of the world.
#
# For example, “laughing”, “laughed“, “laughs”, “laugh” will all become “laugh”, which is their stem, because their inflection form will be removed.
#
# Stemming is not a good normalization process because sometimes stemming can produce words that are not in the dictionary. For example, consider a sentence: “His teams are not winning”
#
# After stemming the tokens that we will get are- “hi”, “team”, “are”, “not”,  “winn”
#
# Notice that the keyword “winn” is not a regular word and “hi” changed the context of the entire sentence.
#
# - **2 types of stemmers:**
#
#     1. **Porter’s Stemmer:**
#     It is one of the most popular stemming methods proposed in 1980. It is based on the idea that the suffixes in the English language are made up of a combination of smaller and simpler suffixes. This stemmer is known for its speed and simplicity. The main applications of Porter Stemmer include data mining and Information retrieval. However, its applications are only limited to English words. Also, the group of stems is mapped on to the same stem and the output stem is not necessarily a meaningful word. The algorithms are fairly lengthy in nature and are known to be the oldest stemmer.
#
#     2. **Snowball stemmer:**
#     When compared to the Porter Stemmer, the Snowball Stemmer can map non-English words too. Since it supports other languages the Snowball Stemmers can be called a multi-lingual stemmer. The Snowball stemmers are also imported from the nltk package. This stemmer is based on a programming language called ‘Snowball’ that processes small strings and is the most widely used stemmer. The Snowball stemmer is way more aggressive than Porter Stemmer and is also referred to as Porter2 Stemmer. Because of the improvements added when compared to the Porter Stemmer, the Snowball stemmer is having greater computational speed.

# %%
#NLTK library used for stemming.
from nltk.stem.snowball import PorterStemmer,SnowballStemmer
#PorterStemmer
port=PorterStemmer()
words=[]
for word in Text.split(' '):
    words.append(port.stem(word))
Text_=' '.join(words)
Text_
# Out:
# 'becaus of problem with her eyesight, rey the african penguin had issu with swimming. that’ unusu for a penguin,\nand present a big challeng for our avicultur team to help rey overcom her hesitancy.\nslowli and steadily, we train her to be comfort feed in the water like the rest of the penguin colony.\nth aviculturist also train rey to accept daili eye drop from them as part of her special health care.\nrey alreadi had good relationship with some staff, and wa comfort with them handl her.\nsenior aviculturist kim fukuda say the team built on those bond to get rey use to receiv the eye drops.\n"sh know the routine," kim says. "I usual give her the eye drop in one area of the exhibit after all the penguin get\ntheir vitamins. when that happens, she run over there and wait for me." rosa, our oldest sea otter, ha veri limit eyesight,\namong other health issues. the sea otter team had alreadi train rosa so they could examin her eyes,\nand built on that trust to includ administ the eye drop she needs.'

# %%
#Using SnowballStemmer
snow=SnowballStemmer('english')
words=[]
for word in Text.split(' '):
    words.append(snow.stem(word))
Text_=' '.join(words)
Text_
# Out:
# 'becaus of problem with her eyesight, rey the african penguin had issu with swimming. that unusu for a penguin,\nand present a big challeng for our avicultur team to help rey overcom her hesitancy.\nslowli and steadily, we train her to be comfort feed in the water like the rest of the penguin colony.\nth aviculturist also train rey to accept daili eye drop from them as part of her special health care.\nrey alreadi had good relationship with some staff, and was comfort with them handl her.\nsenior aviculturist kim fukuda say the team built on those bond to get rey use to receiv the eye drops.\n"sh know the routine," kim says. "i usual give her the eye drop in one area of the exhibit after all the penguin get\ntheir vitamins. when that happens, she run over there and wait for me." rosa, our oldest sea otter, has veri limit eyesight,\namong other health issues. the sea otter team had alreadi train rosa so they could examin her eyes,\nand built on that trust to includ administ the eye drop she needs.'

# %%
#stemming the review from imdb dataset.
imdb['clean']=imdb['clean'].apply(lambda x: " ".join([snow.stem(word) for word in x.split()]))

# %%
imdb['clean']
# Out:
# 0        slow move aimless movi distress drift young man
# 1          sure lost flat charact audienc near half walk
# 2      attempt arti black white clever camera angl mo...
# 3                                littl music anyth speak
# 4      best scene movi gerardo tri find song keep run...
#                              ...
# 743                got bore watch jessic lang take cloth
# 744    unfortun virtu film product work lost regrett ...
# 745                                       word embarrass
# 746                                           except bad
# 747                  insult one intellig huge wast money
# Name: clean, Length: 748, dtype: object

# %% [markdown]
# ### What is Lemmatization?
# Lemmatization, on the other hand, is a systematic step-by-step process for removing inflection forms of a word. It makes use of vocabulary, word structure, part of speech tags, and grammar relations.
#
# The output of lemmatization is the root word called a lemma. For example,
#
# Am, Are, Is >> Be
#
# Running, Ran, Run >> Run
#
# Also, since it is a systematic process while performing lemmatization one can specify the part of the speech tag for the desired term and lemmatization will only be performed if the given word has the proper part of the speech tag. For example, if we try to lemmatize the word running as a verb, it will be converted to run. But if we try to lemmatize the same word running as a noun it won’t be converted.
#
# ![title](https://cdn.analyticsvidhya.com/wp-content/uploads/2021/02/Screenshot-from-2021-02-23-15-07-22.png)

# %%
from nltk import WordNetLemmatizer
lemma=WordNetLemmatizer()
words=[]
for word in Text.split(' '):
    words.append(lemma.lemmatize(word))
Text_=' '.join(words)
Text_
# Out:
# 'Because of problem with her eyesight, rey the African penguin had issue with swimming. That’s unusual for a penguin,\nand presented a big challenge for our aviculture team to help Rey overcome her hesitancy.\nSlowly and steadily, we trained her to be comfortable feeding in the water like the rest of the penguin colony.\nThe aviculturists also trained Rey to accept daily eye drop from them a part of her special health care.\nRey already had good relationship with some staff, and wa comfortable with them handling her.\nSenior Aviculturist Kim Fukuda say the team built on those bond to get Rey used to receiving the eye drops.\n"She know the routine," Kim says. "I usually give her the eye drop in one area of the exhibit after all the penguin get\ntheir vitamins. When that happens, she run over there and wait for me." Rosa, our oldest sea otter, ha very limited eyesight,\namong other health issues. The sea otter team had already trained Rosa so they could examine her eyes,\nand built on that trust to include administering the eye drop she needs.'

# %% [markdown]
# # Parts of Speech Tagging
#
# Source: https://towardsdatascience.com/a-practitioners-guide-to-natural-language-processing-part-i-processing-understanding-text-9f4abfd13e72
#
# ![title](https://cdn.analyticsvidhya.com/wp-content/uploads/2021/02/Screenshot-from-2021-02-23-15-44-27.png)
#
# For any language, syntax and structure usually go hand in hand, where a set of specific rules, conventions, and principles govern the way words are combined into phrases; phrases get combines into clauses; and clauses get combined into sentences.
#
# Knowledge about the structure and syntax of language is helpful in many areas like text processing, annotation, and parsing for further operations such as text classification or summarization.
#
# __Parts of speech (POS)__ are specific lexical categories to which words are assigned, based on their syntactic context and role. Usually, words can fall into one of the following major categories.
#
# + __N(oun)__: This usually denotes words that depict some object or entity, which may be living or nonliving. Some examples would be fox , dog , book , and so on. The POS tag symbol for nouns is N.
#
# + __V(erb)__: Verbs are words that are used to describe certain actions, states, or occurrences. There are a wide variety of further subcategories, such as auxiliary, reflexive, and transitive verbs (and many more). Some typical examples of verbs would be running , jumping , read , and write . The POS tag symbol for verbs is V.
#
# + __Adj(ective)__: Adjectives are words used to describe or qualify other words, typically nouns and noun phrases. The phrase beautiful flower has the noun (N) flower which is described or qualified using the adjective (ADJ) beautiful . The POS tag symbol for adjectives is ADJ .
#
# + __Adv(erb)__: Adverbs usually act as modifiers for other words including nouns, adjectives, verbs, or other adverbs. The phrase very beautiful flower has the adverb (ADV) very , which modifies the adjective (ADJ) beautiful , indicating the degree to which the flower is beautiful. The POS tag symbol for adverbs is ADV.
#
# Besides these four major categories of parts of speech , there are other categories that occur frequently in the English language. These include pronouns, prepositions, interjections, conjunctions, determiners, and many others. Furthermore, each POS tag like the noun (N) can be further subdivided into categories like __singular nouns (NN)__, __singular proper nouns (NNP)__, and __plural nouns (NNS)__.
#
# The process of classifying and labeling POS tags for words called parts of speech tagging or POS tagging .

# %% [markdown]
# ## Guide to POS Tags
#
# The most common part of speech (POS) tag schemes are those developed for the Penn Treebank.
#
# | POS Tag | Description | Example |
# |---------|---------------------------------------|-----------------------------------------|
# | CC | coordinating conjunction | and |
# | CD | cardinal number | 1, third |
# | DT | determiner | the |
# | EX | existential there | there is |
# | FW | foreign word | d’hoevre |
# | IN | preposition/subordinating conjunction | in, of, like |
# | JJ | adjective | big |
# | JJR | adjective, comparative | bigger |
# | JJS | adjective, superlative | biggest |
# | LS | list marker | 1) |
# | MD | modal | could, will |
# | NN | noun, singular or mass | door |
# | NNS | noun plural | doors |
# | NNP | proper noun, singular | John |
# | NNPS | proper noun, plural | Vikings |
# | PDT | predeterminer | both the boys |
# | POS | possessive ending | friend‘s |
# | PRP | personal pronoun | I, he, it |
# | PRP\$ | possessive pronoun | my, his |
# | RB | adverb | however, usually, naturally, here, good |
# | RBR | adverb, comparative | better |
# | RBS | adverb, superlative | best |
# | RP | particle | give up |
# | TO | to | to go, to him |
# | UH | interjection | uhhuhhuhh |
# | VB | verb, base form | take |
# | VBD | verb, past tense | took |
# | VBG | verb, gerund/present participle | taking |
# | VBN | verb, past participle | taken |
# | VBP | verb, sing. present, non-3d | take |
# | VBZ | verb, 3rd person sing. present | takes |
# | WDT | wh-determiner | which |
# | WP | wh-pronoun | who, what |
# | WP\$ | possessive wh-pronoun | whose |
# | WRB | wh-abverb | where, when |
#
# Source: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %% [markdown]
# ### POS Using NLTK

# %%
sentence = 'Mr. Trump became president after winning the political election. Though he lost the support of some republican friends, Trump is friends with President Putin'
sentence
# Out:
# 'Mr. Trump became president after winning the political election. Though he lost the support of some republican friends, Trump is friends with President Putin'

# %%
#importing nltk library.
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Tokenize each word using word_tokenize using nltk module thne find the pos tag for each word.
nltk_pos_tagged = nltk.pos_tag(word_tokenize(sentence))
nltk_pos_tagged
# Out:
# [('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('became', 'VBD'),
#  ('president', 'NN'),
#  ('after', 'IN'),
#  ('winning', 'VBG'),
#  ('the', 'DT'),
#  ('political', 'JJ'),
#  ('election', 'NN'),
#  ('.', '.'),
#  ('Though', 'IN'),
#  ('he', 'PRP'),
#  ('lost', 'VBD'),
#  ('the', 'DT'),
#  ('support', 'NN'),
#  ('of', 'IN'),
#  ('some', 'DT'),
#  ('republican', 'JJ'),
#  ('friends', 'NNS'),
#  (',', ','),
#  ('Trump', 'NNP'),
#  ('is', 'VBZ'),
#  ('friends', 'NNS'),
#  ('with', 'IN'),
#  ('President', 'NNP'),
#  ('Putin', 'NNP')]

# %%
import pandas as pd
#creating dataframe for word and its tag.
POS_df=pd.DataFrame(nltk_pos_tagged, 
             columns=['Word', 'POS tag'])
POS_df
# Out:
#           Word POS tag
# 0          Mr.     NNP
# 1        Trump     NNP
# 2       became     VBD
# 3    president      NN
# 4        after      IN
# 5      winning     VBG
# 6          the      DT
# 7    political      JJ
# 8     election      NN
# 9            .       .
# 10      Though      IN
# 11          he     PRP
# 12        lost     VBD
# 13         the      DT
# 14     support      NN
# 15          of      IN
# 16        some      DT
# 17  republican      JJ
# 18     friends     NNS
# 19           ,       ,
# 20       Trump     NNP
# 21          is     VBZ
# 22     friends     NNS
# 23        with      IN
# 24   President     NNP
# 25       Putin     NNP

# %% [markdown]
# ### POS Using Spacy

# %%
import spacy #loading spacy

nlp = spacy.load('en_core_web_sm') # english module.

sentence_nlp = nlp(sentence)
spacy_pos_tagged = [(word, word.tag_, word.pos_) for word in sentence_nlp]
spacy_pos_tagged
# Out:
# [(Mr., 'NNP', 'PROPN'),
#  (Trump, 'NNP', 'PROPN'),
#  (became, 'VBD', 'VERB'),
#  (president, 'NN', 'NOUN'),
#  (after, 'IN', 'ADP'),
#  (winning, 'VBG', 'VERB'),
#  (the, 'DT', 'DET'),
#  (political, 'JJ', 'ADJ'),
#  (election, 'NN', 'NOUN'),
#  (., '.', 'PUNCT'),
#  (Though, 'IN', 'SCONJ'),
#  (he, 'PRP', 'PRON'),
#  (lost, 'VBD', 'VERB'),
#  (the, 'DT', 'DET'),
#  (support, 'NN', 'NOUN'),
#  (of, 'IN', 'ADP'),
#  (some, 'DT', 'DET'),
#  (republican, 'JJ', 'ADJ'),
#  (friends, 'NNS', 'NOUN'),
#  (,, ',', 'PUNCT'),
#  (Trump, 'NNP', 'PROPN'),
#  (is, 'VBZ', 'AUX'),
#  (friends, 'NNS', 'NOUN'),
#  (with, 'IN', 'ADP'),
#  (President, 'NNP', 'PROPN'),
#  (Putin, 'NNP', 'PROPN')]

# %%
spacy_POS_DF=pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS Tag', 'Tag Type'])
spacy_POS_DF.head(10)
# Out:
#         Word POS Tag Tag Type
# 0        Mr.     NNP    PROPN
# 1      Trump     NNP    PROPN
# 2     became     VBD     VERB
# 3  president      NN     NOUN
# 4      after      IN      ADP
# 5    winning     VBG     VERB
# 6        the      DT      DET
# 7  political      JJ      ADJ
# 8   election      NN     NOUN
# 9          .       .    PUNCT

# %% [markdown]
# # Named Entity Recognition
#
# In any text document, there are particular terms that represent specific entities that are more informative and have a unique context. These entities are known as named entities , which more specifically refer to terms that represent real-world objects like people, places, organizations, and so on, which are often denoted by proper names.
#
# __Named entity recognition (NER)__ , also known as entity chunking/extraction , is a popular technique used in information extraction to identify and segment the named entities and classify or categorize them under various predefined classes.
#
# There are out of the box NER taggers available through popular libraries like __`nltk`__ and __`spacy`__. Each library follows a different approach to solve the problem.

# %% [markdown]
# ### NER Using Spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
text_nlp = nlp(sentence)

# %%
# print named entities in article
ner_tagged = [(word.text, word.ent_type_) for word in text_nlp]
print(ner_tagged)
# Out:
# [('Mr.', ''), ('Trump', 'PERSON'), ('became', ''), ('president', ''), ('after', ''), ('winning', ''), ('the', ''), ('political', ''), ('election', ''), ('.', ''), ('Though', ''), ('he', ''), ('lost', ''), ('the', ''), ('support', ''), ('of', ''), ('some', ''), ('republican', 'NORP'), ('friends', ''), (',', ''), ('Trump', 'ORG'), ('is', ''), ('friends', ''), ('with', ''), ('President', ''), ('Putin', 'PERSON')]

# %%
from spacy import displacy #module to visulaize name entities.

# visualize named entities
displacy.render(text_nlp, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  became president after winning the political election. Though he lost the support of some
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     republican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  friends,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is friends with President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>

# %%
# words where entities mentioned.
named_entities = []
temp_entity_name = ''
temp_named_entity = None
for term, tag in ner_tagged:
    if tag:
        temp_entity_name = ' '.join([temp_entity_name, term]).strip()
        temp_named_entity = (temp_entity_name, tag)
    else:
        if temp_named_entity:
            named_entities.append(temp_named_entity)
            temp_entity_name = ''
            temp_named_entity = None

# %%
named_entities
# Out:
# [('Trump', 'PERSON'), ('republican', 'NORP'), ('Trump', 'ORG')]

# %%
#NER on IMDB reviews.
sent1=' '.join(imdb['review'])
# print named entities in article
text_nlp = nlp(sent1)
ner_tagged = [(word.text, word.ent_type_) for word in text_nlp]

# %%
# words where entities mentioned.
named_entities = []
temp_entity_name = ''
temp_named_entity = None
for term, tag in ner_tagged:
    if tag:
        temp_entity_name = ' '.join([temp_entity_name, term]).strip()
        temp_named_entity = (temp_entity_name, tag)
    else:
        if temp_named_entity:
            named_entities.append(temp_named_entity)
            temp_entity_name = ''
            temp_named_entity = None
named_entities
# Out:
# [('nearly half', 'CARDINAL'),
#  ('two hours', 'TIME'),
#  ('today', 'DATE'),
#  ('two', 'CARDINAL'),
#  ('dozen', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('today', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('another 2 hours', 'TIME'),
#  ('0', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('9', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('2 hours', 'TIME'),
#  ('1', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('10 to in years', 'DATE'),
#  ('10', 'CARDINAL'),
#  ('tonight', 'TIME'),
#  ('an hour and a half', 'TIME'),
#  ('the end of the night', 'DATE'),
#  ('10/10', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('last night', 'TIME'),
#  ('an hour and half', 'CARDINAL'),
#  ('thousand', 'CARDINAL'),
#  ('a few minutes', 'TIME'),
#  ('five dollars', 'MONEY'),
#  ('7.50', 'MONEY'),
#  ('a good two hours', 'TIME'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('the 80s', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1 one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('pi**ed', 'GPE'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('three', 'CARDINAL'),
#  ('1 three', 'CARDINAL'),
#  ('three', 'CARDINAL'),
#  ('three', 'CARDINAL'),
#  ('those many years', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('25 years earlier', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('5 - year', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('5 years old', 'DATE'),
#  ('10 feet', 'QUANTITY'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('1 to 8 years old', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('four', 'CARDINAL'),
#  ('jack', 'PERSON'),
#  ('90 minutes', 'TIME'),
#  ('about 70000', 'CARDINAL'),
#  ('90 minutes', 'TIME'),
#  ('90 minutes', 'TIME'),
#  ('one', 'CARDINAL'),
#  ('second', 'ORDINAL'),
#  ('the day', 'DATE'),
#  ('today', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('95 %', 'PERCENT'),
#  ('today', 'DATE'),
#  ('1980', 'DATE'),
#  ('one second', 'TIME'),
#  ('1/10', 'CARDINAL'),
#  ('0/10', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('the last 15 minutes', 'TIME'),
#  ('8/10', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('tomorrow', 'DATE'),
#  ('about 30 minutes', 'TIME'),
#  ('12 years ago', 'DATE'),
#  ('every minute', 'TIME'),
#  ('10', 'CARDINAL'),
#  ('1 - 10', 'CARDINAL'),
#  ('2006', 'DATE'),
#  ('ten minutes', 'TIME'),
#  ('second', 'ORDINAL'),
#  ('about half', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('several season', 'DATE'),
#  ('0/10', 'CARDINAL'),
#  ('20th century', 'DATE'),
#  ('1948', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('second', 'ORDINAL'),
#  ('earlier that year', 'DATE'),
#  ('1928', 'DATE'),
#  ('about 25 years', 'DATE'),
#  ('80', 'DATE'),
#  ('years', 'DATE'),
#  ('one minute', 'TIME'),
#  ('the next minute', 'TIME'),
#  ('1947', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('1986', 'DATE'),
#  ('1995', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('first', 'ORDINAL'),
#  ('90', 'CARDINAL'),
#  ('90', 'CARDINAL'),
#  ('a fifteen year old', 'DATE'),
#  ('a fifteen year old', 'DATE'),
#  ('3', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('wartime years', 'DATE'),
#  ('10', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('10/10', 'CARDINAL'),
#  ('1971', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('california', 'GPE'),
#  ('late night', 'TIME'),
#  ('second', 'ORDINAL'),
#  ('first', 'ORDINAL'),
#  ('nine', 'CARDINAL'),
#  ('ten', 'CARDINAL'),
#  ('one second', 'TIME'),
#  ('1973', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('10/10', 'CARDINAL'),
#  ('american', 'NORP'),
#  ('one', 'CARDINAL'),
#  ('the 70s', 'DATE'),
#  ('18th century', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('20', 'CARDINAL'),
#  ('40 years', 'DATE'),
#  ('1949', 'DATE'),
#  ('the last 50 years', 'DATE'),
#  ('that year', 'DATE'),
#  ('20 years', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1 1 hour 54 minutes', 'TIME'),
#  ('0', 'CARDINAL'),
#  ('a bad two hour', 'TIME'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('latter - day', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('recent years', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('8.15pm', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('season five', 'DATE'),
#  ('two', 'CARDINAL'),
#  ('90', 'CARDINAL'),
#  ('80', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('about two', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('recent years', 'DATE'),
#  ('9/10', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('maybe?--', 'PERSON'),
#  ('the night', 'TIME'),
#  ('first', 'ORDINAL'),
#  ('eighth', 'ORDINAL'),
#  ('1998', 'DATE'),
#  ('two sundays ago', 'DATE'),
#  ('march 20th , 2005', 'DATE')]

# %%
from spacy import displacy #module to visulaize name entities.

# visualize named entities
displacy.render(text_nlp, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">a very, very, very slow-moving, aimless movie about a distressed, drifting young man.   not sure who was more lost - the flat characters or the audience,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of whom walked out.   attempting artiness with black &amp; white and clever camera angles, the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.   very little music or anything to speak of.   the best scene in the movie was when gerardo is trying to find a song that keeps running through his head.   the rest of the movie lacks art, charm, meaning... if it's about emptiness, it works i guess because it's empty.   wasted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .   saw the movie
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and thought it was a good effort, good messages for kids.   a bit predictable.   loved the casting of jimmy buffet as the science teacher.   and those baby owls were adorable.   the movie showed a lot of florida at it's best, made it look very appealing.   the songs were the best and the muppets were so hilarious.   it was so cool.   this is a very &quot;right on case&quot; movie that delivers everything almost right in your face.   it had some average acting from the main person, and it was a low budget as you clearly can see.   this review is long overdue, since i consider a tale of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  sisters to be the single greatest film ever made.   i'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.   it's practically perfect in all of them  a true masterpiece in a sea of faux &quot;masterpieces.    the structure of this film is easily the most tightly constructed in the history of cinema.  	1</br>i can think of no other film where something vitally important occurs every other minute.  	1</br>in other words, the content level of this film is enough to easily fill a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dozen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other films.  	1</br>how can anyone in their right mind ask for anything more from a movie than this?  	1</br>it's quite simply the highest, most superlative form of cinema imaginable.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>yes, this film does require a rather significant amount of puzzle-solving, but the pieces fit together to create a beautiful picture.  	1</br>this short film certainly pulls no punches.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>graphics is far from the best part of the game.  	0</br>this is the number
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  best th game in the series.  	1</br>it deserves strong love.  	1</br>it is an insane game.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>there are massive levels, massive unlockable characters... it's just a massive game.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>waste your money on this game.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>this is the kind of money that is wasted properly.  	1</br>actually, the graphics were good at the time.  	1</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the graphics are crap.  	0</br>as they say in canada, this is the fun game, aye.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>this game rocks.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>buy it, play it, enjoy it, love it.  	1</br>it's pure brilliance.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>this was a flick doomed from its conception.  	0</br>the very idea of it was lame - take a minor character from a mediocre pg-13 film, and make a complete non-sequel while changing its tone to a pg-rated family movie.  	0</br>i wasn't the least bit interested.  	0</br>not only did it only confirm that the film would be unfunny and generic, but it also managed to give away the entire movie; and i'm not exaggerating - every moment, every plot point, every joke is told in the trailer.  	0</br>but it's just not funny.  	0</br>but even the talented ca

# %% [markdown]
# Spacy offers fast NER tagger based on a number of techniques. The exact algorithm hasn't been talked about in much detail but the documentation marks it as <font color=blue> "The exact algorithm is a pastiche of well-known methods, and is not currently described in any single publication " </font>
#
# The entities identified by spacy NER tagger are as shown in the following table \(details here: [spacy_documentation](https://spacy.io/api/annotation#named-entities)\)
#
# ![](https://github.com/dipanjanS/nlp_workshop_odsc19/blob/master/Module03%20-%20Text%20Understanding/Resources/spacy_ner.png?raw=1)

# %% [markdown]
# ### How is NER used?
# NER is suited to any situation in which a high-level overview of a large quantity of text is helpful. With NER, you can, at a glance, understand the subject or theme of a body of text and quickly group texts based on their relevancy or similarity.
# Some notable NER use cases include:
#
# **Human resources**
# Speed up the hiring process by summarizing applicants’ CVs; improve internal workflows by categorizing employee complaints and questions
#
# **Customer support**
# Improve response times by categorizing user requests, complaints and questions and filtering by priority keywords
#
# **Search and recommendation engines**
# Improve the speed and relevance of search results and recommendations by summarizing descriptive text, reviews, and discussions
# Booking.com is a notable success story here
#
# **Content classification**
# Surface content more easily and gain insights into trends by identifying the subjects and themes of blog posts and news articles
#
# **Health care**
# Improve patient care standards and reduce workloads by extracting essential information from lab reports
# Roche is doing this with pathology and radiology reports
#
# **Academia**
# Enable students and researchers to find relevant material faster by summarizing papers and archive material and highlighting key terms, topics, and themes
# The EU’s digital platform for cultural heritage, Europeana, is using NER to make historical newspapers searchable
#
# Wherever there are large quantities of text, NER can make life easier.

# %% [markdown]
# <h1 align = 'center'> NLTK vs SpaCy <h1>

# %% [markdown]
# ##### NLTK
#
# This suite of libraries and applications from the University of Pennsylvania has gained significant traction in Python-based sentiment analysis systems since its conception in 2001. However, its accumulated clutter and educational remit can prove an impediment to enterprise-level development.
#
# The NLTK platform provides accessible interfaces to more than fifty corpora and lexical sources mapped to machine learning algorithms, as well as a robust choice of parsers and utilities.
#
# Besides its provision for sentiment analysis, the NLTK algorithms include named entity recognition, tokenizing, part-of-speech (POS), and topic segmentation. NLTK also boasts a good selection of third-party extensions, as well as the most wide-ranging language support of any of the libraries listed here.
#
# On the other hand, this versatility can also be overwhelming. The sheer variety of some of its tool categories (it has nine stemming libraries as opposed to SpaCy's single stemmer, for instance) can make the framework look like an unfocused grab-bag of NLP archive material from the last fifteen years. This could add a layer of complexity to our project ideation and logistical planning.
#
# The positive side of this is that no competitor to NLTK can boast such a comprehensive and useful base of documentation, as well as secondary literature and online resources. Free ongoing support is provided by a lively Google Group.
#
# Although NLTK offers Unicode support for multiple languages, setting up non-English workflows is sometimes a more involved process than with other comparable Python libraries. NLTK's out-of-the-box non-English support relies on tertiary mechanisms such as translation layers, language-specific datasets, and models that leverage lexicons or morphemes.
#
# NLTK does not provide neural network models or integrated word vectors, and its string-based processing workflow is arguably behind the times and out of synch with Python's OOP model. NLTK's sentence tokenization is also rudimentary compared to newer competitors.
#
# If we're training up or onboarding staff that has existing NLTK experience, this very popular set of Python NLP libraries might be the obvious choice; but it comes with a burden of redundancy and complexity that could prove hard to navigate for a new team.
#
#
# ##### SpaCy
#
# With the claim of 'industrial-strength natural language processing', the SpaCy Python library is appealing for sentiment analysis projects that need to remain performant at scale, or which can benefit from a highly object-oriented programming approach.
#
# SpaCy is a multi-platform environment that runs on Cython, a superset of Python that enables the development of fast-executing C-based frameworks for Python. Consequently, SpaCy is the fastest-running solution at the moment according to research by Jinho D. Choi et.al.
#
# Unlike NLTK, SpaCy is focused on industrial usage and maintains a minimal effective toolset, with updates superseding previous versions and tools, in contrast to NLTK. SpaCy's prebuilt models address essential NLP sectors such as named entity recognition, part-of-speech (POS) tagging and classification.
#
# In contrast to its older rival, SpaCy tokenizes parsed text at both the sentence and word levels on an OOP model. It also offers integrated word vectors, Stanford NER and syntactic parsing (including chunking). Enabling sentiment analysis with SpaCy would involve devising your own framework, though; SpaCy has no native functionality for this purpose.
#
# However, capable as SpaCy’s models are, we're stuck with their structure. It’s therefore essential to ensure in advance that your long-term goals won’t go out-of-bounds at a later date and become incompatible with this sparse design philosophy.
#
# While SpaCy has an overall speed advantage over its stablemates, its sentence tokenization can run slower than NLTK under certain configurations, which might be a consideration with large-scale pipelines.
#
# Although it demands Unicode input, SpaCy's multi-language support is a work in progress, with models currently available for German, Greek, English, Spanish, French, Italian, Dutch and Portuguese.
#
# With its deliberately lean feature set, SpaCy (as the project website admits) is not an environment suitable for testing different neural network architectures, and is not a good starting point to explore bleeding-edge developments in NLP. SpaCy remains more committed to a consistent platform experience that is focused on the core objectives of its users.
#
# SpaCy is resource-intensive, and requires a 64-bit Python stack as well as higher memory requirements per instance (in the order of 2 or 3 gigabytes) than some of its rivals.
#
# If your project fits within the deliberate limitations of the SpaCy framework, this may be the most 'production-ready', scalable and high-performing environment currently available for sentiment analysis development. If you're willing to integrate external sentiment analysis modules into its core services, SpaCy could offer unrivaled speed benefits.
#
# If you're willing to integrate external sentiment analysis modules into its core services, SpaCy could offer unrivaled speed benefits

# %% [markdown]
# ### What is an API?
# An API is a set of programming code that enables data transmission between one software product and another. It also contains the terms of this data exchange.
#
# ![title](https://content.altexsoft.com/media/2019/06/https-lh6-googleusercontent-com-_nyclktg8po_wx5-.png)
#
# Application programming interfaces consist of two components:
#
# - Technical specification describing the data exchange options between solutions with the specification done in the form of a request for processing and data delivery protocols
# - Software interface written to the specification that represents it.
#
# ### Types of APIs
# **APIs by availability aka release policies**
#
# In terms of release policies, APIs can be private, partner, and public.
#
# ![title](https://content.altexsoft.com/media/2019/06/https-lh6-googleusercontent-com-gwdr_ml7gwkq7sex.png)
#
# **Private APIs.** These application software interfaces are designed for improving solutions and services within an organization. In-house developers or contractors may use these APIs to integrate a company’s IT systems or applications, build new systems or customer-facing apps leveraging existing systems. Even if apps are publicly available, the interface itself remains available only for those working directly with the API publisher. The private strategy allows a company to fully control the API usage.
#
# **Partner APIs.** Partner APIs are openly promoted but shared with business partners who have signed an agreement with the publisher. The common use case for partner APIs is software integration between two parties. A company that grants partners with access to data or capability benefits from extra revenue streams. At the same time, it can monitor how the exposed digital assets are used, ensure whether third-party solutions using their APIs provide decent user experience, and maintain corporate identity in their apps.
#
# **Public APIs.** Also known as developer-facing or external, these APIs are available for any third-party developers. A public API program allows for increasing brand awareness and receiving an additional source of income when properly executed.
#
# ### What is the Twitter API?
# Twitter APIis a set of programmatic endpoints that can be used to learn from and engage with the conversation on Twitter.
#
# This API allows you to find and retrieve, engage with, or create a variety of different resources including the following:
# - Tweets
# - Users
# - Direct Messages
# - Lists
# - Trends
# - Media
# - Places
#
# Here we will use the Twitter RESTful API to access data about both Twitter users and what they are tweeting about.
#
# ### How to start using Twitter api?
#
# To get started, you’ll need to do the following things:
#
# - Set up a Twitter account if you don’t have one already.
# - Using your Twitter account, you will need to apply for Developer Access and then create an application that will generate the API credentials that you will use to access Twitter from Python.
# - Import the tweepy package.
#
# To know how get API credential you can also follow this link: [Link](https://www.youtube.com/watch?v=vlvtqp44xoQ&t=204s)
#
# ### What Is Tweepy?
# Tweepy is an open source Python package that gives you a very convenient way to access the Twitter API with Python. Tweepy includes a set of classes and methods that represent Twitter’s models and API endpoints, and it transparently handles various implementation details, such as:
#
# - Data encoding and decoding
# - HTTP requests
# - Results pagination
# - OAuth authentication
# - Rate limits
# - Streams
#
# To install tweepy use:
# **pip install tweepy**
#
# ### Twitter API in python.
# Once every thing setup we start with importing important libraries in python.

# %%
import os
import pandas as pd
import tweepy as tw

# %% [markdown]
# To access the Twitter API, you will need 4 things from the your Twitter App page. These keys are located in your Twitter app settings in the Keys and Access Tokens tab.
#
# - consumer key
# - consumer seceret key
# - access token key
# - access token secret key

# %%
#First we will need define your keys,
# consumer_key= 'yourworkhere'
# consumer_secret= 'yourworkhere'
# access_token= 'yourworkhere'
# access_token_secret= 'yourworkhere'

# %%
#First we will need define your keys,
consumer_key= 'H05jWnthRWmTgOdxWOhuOSsqt'
consumer_secret= 'uiwYC3rRW2L0Gb3u8a5XkhxbtFkp8ipy7dccmIRwfNfhZN6FXC'
access_token= '726729960275189760-eBgimtjY4mDM7k23RHni9PKuo8fkJKR'
access_token_secret= 'MwrK7pNyHaIae6t4KCajthzDhvkLEt5gwTkV35dtbzIvD'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# #### Search Twitter for Tweets
# Now you are ready to search Twitter for recent tweets! Start by finding recent tweets that use the #bank hashtag. You will use the `.Cursor` method to get an object containing tweets containing the hashtag #bank.
#
# To create this query, you will define the:
#
# - Search term - in this case **#bank**
# - the start date of your search
#
# Remember that the Twitter API only allows you to access the past few weeks of tweets, so you cannot dig into the history too far.

# %%
# Define the search term and the date_since date as variables
search_words = "#FederalBank"
date_since = "2021-06-01"

# %% [markdown]
# We will use `.Cursor()` to search twitter for tweets containing the search term #bank. You can restrict the number of tweets returned by specifying a number in the .items() method. .items(5) will return 5 of the most recent tweets.

# %%
# Collect tweets
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)
tweets

# %% [markdown]
# `.Cursor()` returns an object that you can iterate or loop over to access the data collected. Each item in the iterator has various attributes that you can access to get information about each tweet including:
#
# 1.the text of the tweet
#
# 2.who sent the tweet
#
# 3.the date the tweet was sent

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)
tweets
# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @TreasureHunt_TH: #FederalBank
# The bank has posted good result in a tougher condition. The operational &amp; financial matrix has improved a…
# Bank Nifty tops near 390 pts amid Q1 advances and deposits data; Federal Bank, SBI, ICICI Bank, HDFC Bank, IndusInd… https://t.co/15oZzNBNjE
# #Federalbank One only has to take a look at the bank's AR for FY21 to gauge its industry leading transformation awa… https://t.co/PrAPklqIJM
# #FederalBank can give a good move above 88, SL below 85. https://t.co/6rxADplVln
# #federalbnk as discussed over weekend #hporb #federalbank https://t.co/5FjvPc4RIE

# %% [markdown]
# #### To Keep or Remove Retweets
#
# A retweet is when someone shares someone else’s tweet. It is similar to sharing in Facebook. Sometimes you may want to remove retweets as they contain duplicate content that might skew our analysis if we are only looking at word frequency. Other times, you may want to keep retweets.
#
# Below you ignore all retweets by adding -filter:retweets to your query. The Twitter API documentation has information on other ways to customize your queries.

# %%
new_search = search_words + " -filter:retweets"
new_search
# Out:
# '#FederalBank -filter:retweets'

# %%
tweets = tw.Cursor(api.search,
                       q=new_search,
                       lang="en",
                       since=date_since).items(5)

[tweet.text for tweet in tweets]
# Out:
# ['Bank Nifty tops near 390 pts amid Q1 advances and deposits data; Federal Bank, SBI, ICICI Bank, HDFC Bank, IndusInd… https://t.co/15oZzNBNjE',
#  "#Federalbank One only has to take a look at the bank's AR for FY21 to gauge its industry leading transformation awa… https://t.co/PrAPklqIJM",
#  '#FederalBank can give a good move above 88, SL below 85. https://t.co/6rxADplVln',
#  '#federalbnk as discussed over weekend #hporb #federalbank https://t.co/5FjvPc4RIE',
#  'Federal Bank reports Rs132,770cr of gross advances in Q1, deposits logs single-digit growth; Stock climbs over 1%… https://t.co/luR91FE3iS']

# %% [markdown]
# ### Who is Tweeting About Bank?
# we can access a wealth of information associated with each tweet. Below is an example of accessing the users who are sending the tweets related to #bank and their locations. Note that user locations are manually entered into Twitter by the user. Thus, you will see a lot of variation in the format of this value.
#
# `tweet.user.screen_name` provides the user’s twitter handle associated with each tweet.
#
# `tweet.user.location` provides the user’s provided location.

# %%
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           since=date_since).items(5)

users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs
# Out:
# [['IIFLMarkets', 'Mumbai, India'],
#  ['purushgem', ''],
#  ['Traderknight007', ''],
#  ['usb_3Dot0', ''],
#  ['IIFLMarkets', 'Mumbai, India']]

# %% [markdown]
# ### Create a Pandas Dataframe From A List of Tweet Data.
# One we have a list of items that you wish to work with, we can create a pandas dataframe that contains that data.

# %%
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           since=date_since).items(1000)

users_locs = [[tweet.user.screen_name, tweet.user.location,tweet.text] for tweet in tweets]
users_locs
# Out:
# [['IIFLMarkets',
#   'Mumbai, India',
#   'Bank Nifty tops near 390 pts amid Q1 advances and deposits data; Federal Bank, SBI, ICICI Bank, HDFC Bank, IndusInd… https://t.co/15oZzNBNjE'],
#  ['purushgem',
#   '',
#   "#Federalbank One only has to take a look at the bank's AR for FY21 to gauge its industry leading transformation awa… https://t.co/PrAPklqIJM"],
#  ['Traderknight007',
#   '',
#   '#FederalBank can give a good move above 88, SL below 85. https://t.co/6rxADplVln'],
#  ['usb_3Dot0',
#   '',
#   '#federalbnk as discussed over weekend #hporb #federalbank https://t.co/5FjvPc4RIE'],
#  ['IIFLMarkets',
#   'Mumbai, India',
#   'Federal Bank reports Rs132,770cr of gross advances in Q1, deposits logs single-digit growth; Stock climbs over 1%… https://t.co/luR91FE3iS'],
#  ['PJs_PJs',
#   '',
#   'Ex Div:#ASMTechnologies #JSWSteel #Mindtree\nF&amp;O ban:#NALCO #PNB\n-ve res:#NagarjunaFertilisers\n-ve Q1 upd:… https://t.co/JRp53iD3f9'],
#  ['maduraitrading',
#   'INDIA',
#   '#FederalBank | The bank’s total deposits in Q1FY22 fell 1.88 percent QoQ to Rs 1,69,393 crore, while gross advances… https://t.co/9RK4OnJAww'],
#  ['AEHarshada',
#   'Mumbai, India',
#   '#FederalBank #Q1FY22Update \n\nDeposits at Rs169393cr, up 9.3%YOY &amp; down 1.89%QOQ\nAdvances at Rs132770cr, up 7.56%YOY… https://t.co/squlafURDC'],
#  ['PratikSingh_',
#   'Mumbai, India',
#   '@FederalBankHelp Konsa prepaid card be? Admin Saab konsa nasha kiye ho?\nNo refund is required! Bank sending such fr… https://t.co/Et4PHSMaiL'],
#  ['PratikSingh_',
#   'Mumbai, India',
#   '@mona_sensible @FederalBankLtd What is this @FederalBankLtd?\n#FederalBank Even my family members received this mess… https://t.co/Cb6Ydp4SKW'],
#  ['mona_sensible',
#   'Kolkata, India',
#   '#Federalbank what is this scam ???\n#scam \nSo many people have received similar msg https://t.co/QOnBcXpL9d'],
#  ['MariusA36726634', '', '#ethereum upgrade to #FederalBank coin😉☺️'],
#  ['kkv1112',
#   '',
#   'Charts of some of banking stocks: #RBLBank #AxisBank #DCBBank #FederalBank https://t.co/jbM7zqpPzM'],
#  ['BusinessNewsPo1',
#   '',
#   "#NiftyBank Jumps 125.90 Points (0.36%) to lose at 34809.90, Today's High 34894.45, Today's Low - 34632.60\nLosers… https://t.co/0N6FQw3gZ3"],
#  ['PJs_PJs',
#   '',
#   'Pledge rel:#Chambal #Emami #Kalpataru #MaxFinancial\nBulk buy:#SterlingWilson #IIFLFinance\nEx Div:#AdaniEnterprises… https://t.co/LkUsKY0Ght'],
#  ['BusinessNewsPo1',
#   '',
#   "#NiftyBank Declines 238.10 Points (0.68%) to close at 34772.20, Today's High - 35214.90, Today's Low - 34730.45… https://t.co/TpcdubwTV9"],
#  ['Greenover23',
#   'India',
#   '#trading #investing #StocksToWatch #federalbank\n\nHad entered this trade. Exited with 7k loss, thx to SL in place.… https://t.co/w7HVQBPJE3'],
#  ['BusinessNewsPo1',
#   '',
#   '#KotakMahindra Down 1.57%\n#ICICIBank Loses 1.57%\n#AxisBank Slips 1.37%\n#RBLBank Down 1.33%\n#SBI Loses 1.23%… https://t.co/YBvlNs2f3z'],
#  ['ChrisiFarah',
#   'Irvine, CA',
#   "Here is #Bitcoin #BTC $GBTC above last week's High pay attention to channel Break out #Ethereum #ETH doing catch up… https://t.co/sSGkAEc0yD"],
#  ['Greenover23',
#   'India',
#   '#trading #StocksToWatch #investing #FederalBank #charts \n\nCandle spurt seen above the shoulder.\nTomorrow crucial da… https://t.co/5CxQ5P0GaU'],
#  ['vishantpai',
#   'Mumbai and Daman',
#   'Multi-time frame, Relative and Price analysis all in one.\n\n#FederalBank https://t.co/fMN6bsSN6V'],
#  ['Greenover23',
#   'India',
#   '#FEDERALBANK #StocksToWatch #trading #investing #Charts \n\nInverse Head &amp; Shoulders\nAll TAs showing Strong uptrend\nS… https://t.co/n6Bctf3dVy'],
#  ['krishnblue',
#   'Kolkata, India',
#   '#FEDERALBANK(87.35)~ Looks good on charts. On verge of BO. \n\nVery good FnO data. Massive longs got added. Huge OI s… https://t.co/ao8nqC1Cso'],
#  ['vijay_box69',
#   '',
#   '#Federalbank\n\nShort term pick \nAll details mentioned on chart,\nEnter with proper risk and money management.… https://t.co/MUkQxdCFtk'],
#  ['BusinessNewsPo1',
#   '',
#   "#NiftyBank Marginally Down 5.20 Points (0.01%) to close at 35359.45, Today's High -35576.95, Today's Low - 35236.45… https://t.co/rKzZES0I92"],
#  ['busyrabbit_',
#   '',
#   'Thank You Bansal Ji for #FEDERALBANK done intraday/btst with couple of lots and it worked out very well!🤩 Just that… https://t.co/J5WcHQVxms'],
#  ['bossgrady',
#   'USA (Dimension C-137)',
#   '"Alexa, does Donald Trump own the Federal Reserve?"\n\n"Yes. Federal Reserve System is owned by Donald Trump."\n\nTry i… https://t.co/2Gr2NPS0U4'],
#  ['YESInvestor',
#   'Virginia.Beach, VA, USA',
#   '#PRECIOUS- #Gold subdued as #investors evaluate #FederalBank policy view  https://t.co/LJ9pn3jOQZ #MorningGoldReport #Silver'],
#  ['Greenover23',
#   'India',
#   '#trading #investing #StocksToWatch #federalbank\n\nUp 2%\nRSI &gt; 60\nCMP &gt; VWAP, EMAs\nInverse H&amp;S\n@RajarshitaS… https://t.co/jWeWEhJHyd'],
#  ['Stockproteam',
#   'Gurgaon, India',
#   'LOOK At STOCKPRO RESEARCH\n\n#APOLLOTYRES\n#FEDERALBANK\n#NMDC\nAnd #NationalAluminium\n\nBANG On https://t.co/BpNdN18qnH'],
#  ['BWPeopleIn',
#   'New Delhi, India',
#   'Jobs: Federal Bank Gives 400-Odd Part-Time Jobs In Kerala\n\nRead more at:\nhttps://t.co/Eq4P0PONgj\n\n@BWBusinessworld… https://t.co/INqeaZuKoi'],
#  ['FinancialXpress',
#   'New Delhi, India',
#   "This Rakesh Jhunjhunwala share may rally 28%; brokerages say 'buy' Federal Bank stock \n#RakeshJhunjhunwala… https://t.co/3MCO0GFqai"],
#  ['purushgem',
#   '',
#   '#Federalbank Given the kind of digitization of the bank, it deserves to command valuation as a fintech.']]

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location",'Tweet'])
tweet_text
# Out:
#                user                 location  \
# 0       IIFLMarkets            Mumbai, India
# 1         purushgem
# 2   Traderknight007
# 3         usb_3Dot0
# 4       IIFLMarkets            Mumbai, India
# 5           PJs_PJs
# 6    maduraitrading                    INDIA
# 7        AEHarshada            Mumbai, India
# 8      PratikSingh_            Mumbai, India
# 9      PratikSingh_            Mumbai, India
# 10    mona_sensible           Kolkata, India
# 11  MariusA36726634
# 12          kkv1112
# 13  BusinessNewsPo1
# 14          PJs_PJs
# 15  BusinessNewsPo1
# 16      Greenover23                    India
# 17  BusinessNewsPo1
# 18      ChrisiFarah               Irvine, CA
# 19      Greenover23                    India
# 20       vishantpai         Mumbai and Daman
# 21      Greenover23                    India
# 22       krishnblue           Kolkata, India
# 23      vijay_box69
# 24  BusinessNewsPo1
# 25      busyrabbit_
# 26        bossgrady    USA (Dimension C-137)
# 27      YESInvestor  Virginia.Beach, VA, USA
# 28      Greenover23                    India
# 29     Stockproteam           Gurgaon, India
# 30       BWPeopleIn         New Delhi, India
# 31  FinancialXpress         New Delhi, India
# 32        purushgem
#
#                                                 Tweet
# 0   Bank Nifty tops near 390 pts amid Q1 advances ...
# 1   #Federalbank One only has to take a look at th...
# 2   #FederalBank can give a good move above 88, SL...
# 3   #federalbnk as discussed over weekend #hporb #...
# 4   Federal Bank reports Rs132,770cr of gross adva...
# 5   Ex Div:#ASMTechnologies #JSWSteel #Mindtree\nF...
# 6   #FederalBank | The bank’s total deposits in Q1...
# 7   #FederalBank #Q1FY22Update \n\nDeposits at Rs1...
# 8   @FederalBankHelp Konsa prepaid card be? Admin ...
# 9   @mona_sensible @FederalBankLtd What is this @F...
# 10  #Federalbank what is this scam ???\n#scam \nSo...
# 11          #ethereum upgrade to #FederalBank coin😉☺️
# 12  Charts of some of banking stocks: #RBLBank #Ax...
# 13  #NiftyBank Jumps 125.90 Points (0.36%) to lose...
# 14  Pledge rel:#Chambal #Emami #Kalpataru #MaxFina...
# 15  #NiftyBank Declines 238.10 Points (0.68%) to c...
# 16  #trading #investing #StocksToWatch #federalban...
# 17  #KotakMahindra Down 1.57%\n#ICICIBank Loses 1....
# 18  Here is #Bitcoin #BTC $GBTC above last week's ...
# 19  #trading #StocksToWatch #investing #FederalBan...
# 20  Multi-time frame, Relative and Price analysis ...
# 21  #FEDERALBANK #StocksToWatch #trading #investin...
# 22  #FEDERALBANK(87.35)~ Looks good on charts. On ...
# 23  #Federalbank\n\nShort term pick \nAll details ...
# 24  #NiftyBank Marginally Down 5.20 Points (0.01%)...
# 25  Thank You Bansal Ji for #FEDERALBANK done intr...
# 26  "Alexa, does Donald Trump own the Federal Rese...
# 27  #PRECIOUS- #Gold subdued as #investors evaluat...
# 28  #trading #investing #StocksToWatch #federalban...
# 29  LOOK At STOCKPRO RESEARCH\n\n#APOLLOTYRES\n#FE...
# 30  Jobs: Federal Bank Gives 400-Odd Part-Time Job...
# 31  This Rakesh Jhunjhunwala share may rally 28%; ...
# 32  #Federalbank Given the kind of digitization of...

# %%
#save the file in local drive.
tweet_text.to_csv('Tweet.csv',index=False)

# %% [markdown]
# ### GoogleNews
# Google News is a news aggregator service developed by Google. It presents a continuous flow of links to articles organized from thousands of publishers and magazines.
#
# GoogleNews 1.5.8- Python Module for Extracting Google News.
#
# **pip install GoogleNews**

# %%
# Intializing the googlenews object
from GoogleNews import GoogleNews
googlenews = GoogleNews()

# %%
#choose language
googlenews = GoogleNews(lang='en')

# %%
#choose period (period and custom day range should not set together)

# %%
# declare a getnews object 
googlenews.get_news('Federal Bank')

# %%
googlenews.results()
# Out:
# [{'title': 'Federal Bank to raise Rs 916 cr in equity capital from IFC, affiliates',
#   'desc': 'amp',
#   'date': '17 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEIaCZBTuarhOTtnB7cXckGEqGQgEKhAIACoHCAowsLXdCjCm3dEBMOThpAM?uo=CAUiiwFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9maW5hbmNlL2ZlZGVyYWwtYmFuay10by1yYWlzZS1ycy05MTYtY3ItaW4tZXF1aXR5LWNhcGl0YWwtZnJvbS1pZmMtYWZmaWxpYXRlcy0xMjEwNjE3MDAzMDdfMS5odG1s0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/g52ixI0JOveh2EQxFZ6lLpzrBvNf7_mSSLX7Mz5QBZTWGYLKG2uPz1j7j_UO_K159UUH4oJHyIFcUPqDqA=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Bank Nifty tops near 390 pts amid Q1 advances and deposits data; Federal Bank, SBI, ICICI Bank, HDFC Bank, IndusInd drive',
#   'desc': 'amp',
#   'date': '14 hours ago',
#   'datetime': datetime.datetime(2021, 7, 5, 4, 3, 15, 919901),
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/da_dTw0vaEwEmDtPNAICitgp8henzMfcxYH29KX3_bHzGSW7Rm114iJMtyxe1KKRdSX_0-HgAhxlGmMYcMnkwvtZ-tBGEKebAxP62-w34bWRypzlo3anEnSBHXikpSkp2qaFtqshtKg1T2JXyra4Jd4G74Qiq1sH=-p-df-h100-w100',
#   'media': None,
#   'site': 'Indiainfoline'},
#  {'title': 'From partnering with fintech startups to helping dairy farmers, how Federal Bank is transforming into a digita',
#   'desc': 'amp',
#   'date': '5 days ago',
#   'datetime': datetime.datetime(2021, 6, 30, 18, 3, 15, 920899),
#   'link': 'news.google.com/./articles/CAIiEIhrKucLj-2teuCuyWcud-gqGQgEKhAIACoHCAow6-iECzC_7YEDMIfQhAY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/wI9uPZqNsI3_3fGKhLVnfIaRwrmHbgmxb656gIMYgb48ZDDCa4tKhxOzw1MzJgidQsmnXC0K6g4-4kgKBR8=-p-df-h100-w100',
#   'media': None,
#   'site': 'YourStory'},
#  {'title': 'Covid-19 impact: Federal Bank provides about 400 part-time jobs in Kerala',
#   'desc': 'amp',
#   'date': '26 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEFvHHep-NR1Rfnlc62gVhH4qGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUikwFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvY292aWQtMTktaW1wYWN0LWZlZGVyYWwtYmFuay1wcm92aWRlcy1hYm91dC00MDAtcGFydC10aW1lLWpvYnMtaW4ta2VyYWxhL2FydGljbGUzNDk4NTE3MC5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/Kdmp7Zj5N4Q4nc7epyoBXSmmjSIx_NB49cOgnPlHVpwq95ofcDQeoDGinsWWZTMIde_4W072D8KJYVfHoti7QFGm6x9A4JTIwJBPVTAoFbg4eeYfAf7E1exnv68hZ4ewmXjCjVVwgQBs1nO79F0yq5v8lDIIORJOZK2B7UOjrW6rEhveflb4r3niO4lmH395i7Mw=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Buy Federal Bank, target price Rs 110: Motilal Oswal',
#   'desc': 'amp',
#   'date': '7 days ago',
#   'datetime': datetime.datetime(2021, 6, 28, 18, 3, 15, 922898),
#   'link': 'news.google.com/./articles/CAIiEDC2Ca4kY23JOvZBylf_5-8qGQgEKhAIACoHCAow2pqGCzD954MDMJzyigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/jYBF7q7WVQL0-NRcavHE0UEn4uO-MkNcmxZUEmuqtpylo_LkdXG_Lho4hUYmq4eJScyO7y24zoXP3Xp-jGE=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Stocks to watch: Power Grid, SBI, Tata Steel, CESC, Federal Bank, Wipro',
#   'desc': 'amp',
#   'date': '17 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiENwH1odfqI2tz0HAF42NwUcqGQgEKhAIACoHCAowsLXdCjCm3dEBMOThpAM?uo=CAUihwFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9tYXJrZXRzL3N0b2Nrcy10by13YXRjaC1wb3dlci1ncmlkLXNiaS10YXRhLXN0ZWVsLWNlc2MtZmVkZXJhbC1iYW5rLXdpcHJvLTEyMTA2MTcwMDE3M18xLmh0bWzSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/bOlm5wDaRNB3gXD0iruImLCPktDyNv3NppJzFOwgYW5u45om4N6SWy6IcqzTa2loLxhJ1NmYQecsRwY8Vpw=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Escorts, PVR, Federal Bank among top 13 picks of Angel Broking for up to 31% upside',
#   'desc': 'amp',
#   'date': '12 Jun',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/XMZTnv8ycir_k05ESf3hoEHA4q0ewJrdEm15leCsDQZSZtUSCOKIubikkncBFd0R3YOgDfPLj7ADd6eFvqIywJBxEyX1z7jMKxSULPe5-lKa49XDvh2qtF2ioPZIYk_0xX9wHZl3snsg2O4vd-eZwYGY_C1vBv79mO4=-p-df-h100-w100',
#   'media': None,
#   'site': 'Moneycontrol.com'},
#  {'title': 'Federal Bank enlists Infosys for Oracle CX implementation',
#   'desc': 'amp',
#   'date': '14 Jun',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/zU_0Z7RGqEqH-qh157DlpZKxqrrxqrwDHA2WJZ5ZUGLH2LTRibiWvKV303_8na_5GPBjZCwrIRoAkB3aK-Q-q5cgYS4Mps1Q4ZjVvPuQEIhk5QYI5htgi1v3pxbm8hn_37mwTExcMaVVNaRMjzQST8OWWnirYojrs-biiDBMn3AX8KBvf6nIqrwONRZKnp4SPJRJMfbasYcy0fLTOEMV5rEACasi2OL13_cW=-p-df-h100-w100',
#   'media': None,
#   'site': 'Consultancy.in'},
#  {'title': 'Federal Bank donates 10,000 COVID-19 vaccine carriers to Kerala',
#   'desc': 'Federal Bank donates 10,000 COVID-19 vaccine carriers to Kerala',
#   'date': '23 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiECpnWnYA1tpyW_gqyed3K24qGQgEKhAIACoHCAowlbCPCzCrzaIDMLL1zQY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/F9TX63CMQpC8rtFwJTwQpFZGNhtl1bDcfoVffFMj7tMHNps74oRr5ujZGvyXAysYjHqRoLWrgUMk_uwnBQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'Moneycontrol'},
#  {'title': 'Jobs: Federal Bank Gives 400-Odd Part-Time Jobs In Kerala',
#   'desc': 'amp',
#   'date': '28 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CBMidGh0dHA6Ly9id3Blb3BsZS5idXNpbmVzc3dvcmxkLmluL2FydGljbGUvSm9icy1GZWRlcmFsLUJhbmstR2l2ZXMtNDAwLU9kZC1QYXJ0LVRpbWUtSm9icy1Jbi1LZXJhbGEtLzI4LTA2LTIwMjEtMzk0NTM30gEA?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/6SG6ug15ZYI_fR5SOkI8tFGepOaiWucldbfEByc1aqjDEDO-GLwVMkLpvqHiHToj0TxPB5vKz15hO6yBOvsUpk-6yXOHiOgAJ4GgHFeM0T8xWcoDqEuC-ofaGwCFI3H-bZ2L7E-15jxWhTRp9CKRamqFWR6DTQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'BW Businessworld'},
#  {'title': "This Rakesh Jhunjhunwala portfolio stock gives breakout. 'Buy,' say experts",
#   'desc': 'amp',
#   'date': '28 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEPqAEMuoIKU8OcXrEEjkYKEqFggEKg4IACoGCAowxLQ_MNevCDD45Co?uo=CAUijQFodHRwczovL3d3dy5saXZlbWludC5jb20vbWFya2V0L3N0b2NrLW1hcmtldC1uZXdzL3RoaXMtcmFrZXNoLWpodW5qaHVud2FsYS1wb3J0Zm9saW8tc3RvY2stZ2l2ZXMtYnJlYWtvdXQtYnV5LXNheS1leHBlcnRzLTExNjI0ODUwMzQ4MzUyLmh0bWzSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/KlcID3JYK8s82pfjfkNFDP1taGyDWCdOQ4TxQcDVYkzzn7DdKGzC3xppfab40T3r9_0eq14viWycwu_tbH4=-p-df-h100-w100',
#   'media': None,
#   'site': 'Mint'},
#  {'title': "Federal Bank CEO: Focus on reaching India's underbanked and underserved with neo-banking partnerships and purpose of ‘inclusive finance’",
#   'desc': 'amp',
#   'date': '18 Jun',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/Jg4qXXT7fsXO8M9XYYiWHOYaMwxrOFANGLCP4a2YZPAzB0HICL8eWfw9H90z8-hwJPj2QnNaDyfpDYQf0NHySIqgQRFGFkdvCW8J3mki3AjOJPWYy34cnXgZ4spH7FMg1Dx5YvIYArcynWypnyDYJdQJ_EbM9j-1=-p-df-h100-w100',
#   'media': None,
#   'site': 'Indiainfoline'},
#  {'title': 'Get ready for a Covid-free India as Network18 and Federal Bank drop the motivational Sanjeevani Anthem ‘#TikaLagayaKya’',
#   'desc': 'amp',
#   'date': '23 Jun',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/BYBDs4EXri8auvQhAReCGrRFrUigYr4c4HYxqf66ttL6th1Eb7qwOLQ_MsBrk9n2CbavjTwYDTvSmJ0GW_lyxEFZXjdGFzKqo_Awtqfi_FDWRzZD-4JCsiJwOi4WTIUHzbIX0l52l4Aa=-p-df-h100-w100',
#   'media': None,
#   'site': 'India Education Diary'},
#  {'title': 'Stocks to buy in July 2021: Nifty Dec target upgraded to 17,400; fall in volatility indicates strong bull run',
#   'desc': 'amp',
#   'date': '5 hours ago',
#   'datetime': datetime.datetime(2021, 7, 5, 13, 3, 15, 929925),
#   'link': 'news.google.com/./articles/CAIiEJcJoEYi9Asv5HnaDQuBKSwqGQgEKhAIACoHCAow55veCjDzvdUBMOLc5gU?uo=CAUimwFodHRwczovL3d3dy5maW5hbmNpYWxleHByZXNzLmNvbS9tYXJrZXQvc3RvY2tzLXRvLWJ1eS1pbi1qdWx5LTIwMjEtbmlmdHktZGVjLXRhcmdldC11cGdyYWRlZC10by0xNzQwMC1mYWxsLWluLXZvbGF0aWxpdHktaW5kaWNhdGVzLXN0cm9uZy1idWxsLXJ1bi8yMjg0MTIxL9IBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/i7zyJvIFi08kBlbGxsk1FAexvfYs_mKnjKlHBWDF29SrvyAk-o6-JrDlnicytnZGfmDrPoJFzfYwN6sRBuk=-p-df-h100-w100',
#   'media': None,
#   'site': 'The Financial Express'},
#  {'title': 'Stocks in the news: Nazara, Power Grid, CESC, DRL, PNB Housing, RCom and Federal Bank',
#   'desc': 'amp',
#   'date': '17 Jun',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/ArKwbFL7DXrZGdyElYeBQ20jjDw8c1FBbHABO2ogAl6xlCn5C1fBEu7Q7m1xg_UIpgs74_IgyUuURICarx2h4x3mrL63dtzrlHn6-Ss8fr2mGDfZHOYn4kJKXAVrpCBeiiAp1Kdx9Qezn6oOILDZcbEvUf7fVt3C2AaTjFL84hQLQfdlUoiLLZn6Gr4jee1OC3IKtHXphPAQWRB5IRTfEpDl5zH7SnP_CPKv-Q9rMPB-jhcOX9r2oV3l6AOSvw=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Profile | Shyam Srinivasan, who adores ‘Rahul Dravid’, is ready for his new innings',
#   'desc': 'Profile | Shyam Srinivasan, who adores ‘Rahul Dravid’, is ready for his new innings',
#   'date': '9 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEM4TVONLcZ7z9FE4Inlg4UMqGQgEKhAIACoHCAowlbCPCzCrzaIDMOjUrgY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/o11krNfnIs76T_RbJ7aIz4LYc8FDAMNF8GvvNFVNs0K4FjA9p6vPOSybIapZJL8Se80pc6f_pfiffkpnfFM=-p-df-h100-w100',
#   'media': None,
#   'site': 'Moneycontrol'},
#  {'title': 'First Federal Bank of Kansas City Joins with Narmi to Deliver World Class Digital Banking and Account Opening Experience',
#   'desc': 'amp',
#   'date': '8 Jun',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/E0sOBXhBzilA1OfF4Rn_8rDL_1QZeVexADX_l_Ue5xFK9cUku5--Q5_5e6vgC9qGZInV8_2oap2fjDOECzNuWCx_DssH7yx7-6DLWCBP4vgmsrvW6oVY-jiQlfxu=-p-df-h100-w100',
#   'media': None,
#   'site': 'PRNewswire'},
#  {'title': "US Federal Bank's 'surprise hawkish' interest rates forecast sends Wall Street and ASX into red",
#   'desc': 'Federal Reserve Chairman Jerome Powell says the US may raise rates sooner than expected.',
#   'date': '17 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEDMiDgA_zcaF3JqcE_f0mGUqFggEKg4IACoGCAow3vI9MPeaCDDM2g4?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/GyZNvwNmlcfPCnMnmlXhLG2Jwcvi6EN91cf1jvLfic5UWHIf4xybvuXL6byKt8pwNSQ8p--IsZxWsPJL2LY=-p-df-h100-w100',
#   'media': None,
#   'site': 'ABC News'},
#  {'title': 'Stocks in Focus on June 17: Dodla Dairy, Krishna Institute, CESC, Welspun Enterprises to Federal Bank; here...',
#   'desc': 'amp',
#   'date': '17 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEAZHsJezsxsG6nDU20WMnF8qGQgEKhAIACoHCAow5bCNCzD8tp8DMP3RpwY?uo=CAUitQFodHRwczovL3d3dy56ZWViaXouY29tL21hcmtldC1uZXdzL25ld3Mtc3RvY2tzLWluLWZvY3VzLW9uLWp1bmUtMTctZG9kbGEtZGFpcnkta3Jpc2huYS1pbnN0aXR1dGUtY2VzYy13ZWxzcHVuLWVudGVycHJpc2VzLXRvLWZlZGVyYWwtYmFuay1oZXJlLWFyZS10aGUtNS1uZXdzbWFrZXJzLW9mLXRoZS1kYXktMTU4NzU20gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/DvtIN7-ZlixDB3y5GlMXpS_j3gJaODkGP_yAV0SWmghGByCQRSxPXXBZ4P2TcmgslHilmOB48ju6Cu16eQc=-p-df-h100-w100',
#   'media': None,
#   'site': 'Zee Business'},
#  {'title': 'Gold loans — a win-win for banks, customers',
#   'desc': 'amp',
#   'date': '19 hours ago',
#   'datetime': datetime.datetime(2021, 7, 4, 23, 3, 15, 933884),
#   'link': 'news.google.com/./articles/CAIiECptPT65hJZbpp0YhddbeAoqGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUic2h0dHBzOi8vd3d3LnRoZWhpbmR1YnVzaW5lc3NsaW5lLmNvbS9tb25leS1hbmQtYmFua2luZy9nb2xkLWxvYW5zLWEtd2luLXdpbi1mb3ItYmFua3MtY3VzdG9tZXJzL2FydGljbGUzNTEzNzc2My5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/9WqW0ZR8yl9DUHuD5YGFVWs9CCKGycs1QQX128nf62TNJoOEuP1ozIqLYLTkoaLz7Q4DdMFiWVZkyqOedQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Network18 and Federal Bank launch ‘#TikaLagayaKya’, the Sanjeevani anthem urging people to get vaccinated:',
#   'desc': 'amp',
#   'date': '23 Jun',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/Lq6NmANGdWoMF4BepO9CIamfzl2JDM5edcNbno4z6PKDtlFvIpLFz0jDWis2_BancL8FqGRx9ISZvxb7ENB-W2TiGs9a-_jTeRjTRoMmwdDfa9XEqI8gpCFR5pcR9_HGpII83DJ0F6SB_ylDr38AdOqbB3x4rznZBPubADJcxUBT7yNSHPAdA8WDZQoPC1dOQQ_jIv3pDBs1C1aFhlqn1uort3XRFqKtTsqxu7eG9KyUj83d6BMHg6eU37SdrpqMCrkywKKa7e1UZA=-p-df-h100-w100',
#   'media': None,
#   'site': 'RadioandMusic.com'},
#  {'title': 'Rakesh Jhunjhunwala birthday today: Rs 5,000 investment to now Rs 34,000 cr; journey from ‘bear’ to ‘big bull’',
#   'desc': 'amp',
#   'date': '9 hours ago',
#   'datetime': datetime.datetime(2021, 7, 5, 9, 3, 15, 935884),
#   'link': 'news.google.com/./articles/CAIiEPB29Kcgzq7cfN6x1oemRSoqGQgEKhAIACoHCAow55veCjDzvdUBMOLc5gU?uo=CAUilgFodHRwczovL3d3dy5maW5hbmNpYWxleHByZXNzLmNvbS9tYXJrZXQvcmFrZXNoLWpodW5qaHVud2FsYS1iaXJ0aGRheS1mcm9tLXJzLTUwMDAtaW52ZXN0bWVudC10by1ub3ctcnMtMzQwMDAtY3Itam91cm5leS1mcm9tLWJlYXItdG8tYmlnLWJ1bGwvMjI4MzM0Mi_SAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/6AKwNYA5yLnOA7ossf5fj30ScsB79zl_aNhx3qdRahLOaaLY6rONtkpTSlgSqcvu9buOaGOg1Kdb_DwmNg=-p-df-h100-w100',
#   'media': None,
#   'site': 'The Financial Express'},
#  {'title': 'Check which lenders offer best interest rates on new car loans',
#   'desc': 'amp',
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2021, 7, 3, 18, 3, 15, 936895),
#   'link': 'news.google.com/./articles/CAIiEJJvrWVH6ZKWk2CSorDfvaEqFggEKg4IACoGCAowxLQ_MNevCDCzoh8?uo=CAUiggFodHRwczovL3d3dy5saXZlbWludC5jb20vbW9uZXkvcGVyc29uYWwtZmluYW5jZS9jaGVjay13aGljaC1sZW5kZXJzLW9mZmVyLWJlc3QtaW50ZXJlc3QtcmF0ZXMtb24tbmV3LWNhci1sb2Fucy0xMTYyNTIxOTQ3NTEyNy5odG1s0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/quAChNKZwwg8jaeOYKiKDKVPqUR0spBT1i1akmcbF-b0cPsL0do3_U178tn3KFT25-yaesefRJbnTE8ZOg=-p-df-h100-w100',
#   'media': None,
#   'site': 'Mint'},
#  {'title': "TC Federal Bank celebrates Dr. Clanton's 22 years of service",
#   'desc': 'amp',
#   'date': '5 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CBMinAFodHRwczovL3d3dy50aW1lc2VudGVycHJpc2UuY29tL25ld3MvbG9jYWxfbmV3cy90Yy1mZWRlcmFsLWJhbmstY2VsZWJyYXRlcy1kci1jbGFudG9ucy0yMi15ZWFycy1vZi1zZXJ2aWNlL2FydGljbGVfMWJjMmE3ZTMtZGM3Yi01ZDM5LThiZDYtNDM3YjQyMmI4NTBjLmh0bWzSAQA?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/JBMZLWequcgwJVLu9XLk4YpNeYISvdUb2Qva-byXFfeguzlnkc973Inqi43eyCZOYrxpcsNDC3QNNHj4WJEYhnT_t0fa12UlEyrkbsx0YNFKzkmxQ160ejib1tuQybX636h-KXJhQNiDAq4Oh4KB8yx-pjn92BwqMr4v6nHfj4ojSf-7FVI9OGaTXXvm3kNyHm1SpWBgz_YcxH_nwJCpZEReMiSS-gwKZ9fmqwuk4Fj1eIeQUi5kM7tCDX7JbxPeSPzYTD31nbDT2Y92WCAZEq4=-p-df-h100-w100',
#   'media': None,
#   'site': 'Times-Enterprise'},
#  {'title': 'CNBC-TV18’s top stocks to watch out for on July 5',
#   'desc': 'amp',
#   'date': '10 hours ago',
#   'datetime': datetime.datetime(2021, 7, 5, 8, 3, 15, 937927),
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/_G23xdG61o8GnkKRvakqba9uUoIjxdTQLE-D7PxYV_NiPMPxGlV2BqdNvvjdUxjyP6WzABmCoNBEVJBKYiZsuKj5495af_wjUNrezQM5g6IUmsnByB4Eo5pVVHO967YofyWawqVXgH_OvWMkumhuGXPHhDop=-p-df-h100-w100',
#   'media': None,
#   'site': 'CNBCTV18'},
#  {'title': 'Privatising Banks, Diminishing Rights: Does a Receding State Mean Receding Banking Services for the Poor?',
#   'desc': 'amp',
#   'date': '5 hours ago',
#   'datetime': datetime.datetime(2021, 7, 5, 13, 3, 15, 938932),
#   'link': 'news.google.com/./articles/CAIiEKjZS-Orxl8LQ6pGCXHrHY0qGQgEKhAIACoHCAowicuJCzCIs5sDMJKo3QY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/6fWIcwM_kCfYwUzbcOopXRw6rTpoc7O3_hykU8tfM3rfRYCPxjOFqPrH8-HrpmMPJ9IAz_kWyraPnHABDQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'NewsClick'},
#  {'title': 'Dead CEO of Bridgeport’s failed Washington Federal Bank for Savings John Gembara worried over his safety, sis…',
#   'desc': 'Marek Matczuk walks out of the Dirksen Federal Courthouse March 4 after being charged with embezzling millions of dollars from Washington Federal Bank for Savings. | Ashlee Rezin Garcia / Sun-Times',
#   'date': '11 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEJgunRx8qNMZiFGMSiP_JF0qGQgEKhAIACoHCAowsbfwCjCm2LoCMMC_4wU?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/ytUA_GQ7FIa929vYyl7FzsB5iPwCqkwtTxcmUr3VFXcr_fhgfqHGWlgsJ3CQ9DJIKpCDsExHkxG2AsppWzs=-p-df-h100-w100',
#   'media': None,
#   'site': 'Chicago Sun-Times'},
#  {'title': '3 Banking Stocks To Buy Today By Angel Broking',
#   'desc': 'amp',
#   'date': '15 Jun',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh5.googleusercontent.com/proxy/hcTRBVHOYP_2opkFAwcvzoe0BQdmYYL5FS7LQB4DNnw90_ZPgS8lSVYVA1zySbmLK0m5p1HoT6u23_qbX7iHerRZSd1kI-O0WtOTghPYMdgK6kAM7pCHXkzcTgVJwaiC2YfhX2pkBr5qwm1R=-p-df-h100-w100',
#   'media': None,
#   'site': 'Goodreturns'},
#  {'title': "Where are 1992 stock market scam accused Harshad Mehta's wife Jyoti, son Atur Mehta and brother Ashwin Mehta",
#   'desc': 'amp',
#   'date': '5 days ago',
#   'datetime': datetime.datetime(2021, 6, 30, 18, 3, 15, 942886),
#   'link': 'news.google.com/./articles/CAIiEB2mVspPT5eXmQSEEn_wgU4qGQgEKhAIACoHCAow-d2NCzDriqADMNGGqQY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/FX3C4oU0wpGTQjLrRwapmim0W2_pNu40xfMwmtoFJVwbVEY90dyaCoTNHb72tpMHi1BIuyXzco9yDmYGvas=-p-df-h100-w100',
#   'media': None,
#   'site': 'DNA India'},
#  {'title': 'Federal Bank gets board nod for Rs 148 cr rights issue subscription',
#   'desc': 'amp',
#   'date': '18 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEMl2fDNzidjKR9S2j3b9GWYqGQgEKhAIACoHCAowsLXdCjCm3dEBMNS-swY?uo=CAUiiQFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9maW5hbmNlL2ZlZGVyYWwtYmFuay1nZXRzLWJvYXJkLW5vZC1mb3ItcnMtMTQ4LWNyLXJpZ2h0cy1pc3N1ZS1zdWJzY3JpcHRpb24tMTIxMDUxODAwNzAyXzEuaHRtbNIBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/INLuY-LPCZx-4jsSU9sv0UZQBkWYG2cazj8W6_75yx7a7BgPNLRuJge5XQD3jIk6hqYw9Lo7VaktKdg-eQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Federal Bank to launch credit cards in next few months',
#   'desc': 'amp',
#   'date': '1 Mar',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEDUsAdjTljjZe9dKVglotj4qGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUigQFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvZmVkZXJhbC1iYW5rLXRvLWxhdW5jaC1jcmVkaXQtY2FyZHMtaW4tbmV4dC1mZXctbW9udGhzL2FydGljbGUzMzk2MDc2NC5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/2O5JbutOkcGoEguTvzfo4erFUUgctE3XvgnkWkwghfKueBEWoNnD5e2aQP5SnjGOLzAnN1cdkZpMQYvQnh-DMzDYDM6ekiQjQd_lNTgyW2YCvEtfx2i7iFaiT88QYxkJB9dUNSj9MS5KzypNVvuEIjp1CJpIYarznXGf2O4QmhcWJY1UGe_xp-nXNuOPNeLK0NeyaMEGPYb9dpi0FKHyEg=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Federal Bank’s Q4 update reflects a tough year, but deposits cheer',
#   'desc': 'amp',
#   'date': '6 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEJbcmo29nCuKXE-oATTkYEgqFggEKg4IACoGCAowxLQ_MNevCDD45Co?uo=CAUiiwFodHRwczovL3d3dy5saXZlbWludC5jb20vbWFya2V0L21hcmstdG8tbWFya2V0L2ZlZGVyYWwtYmFuay1zLXE0LXVwZGF0ZS1tZWV0cy1leHBlY3RhdGlvbnMtYnV0LXNlY29uZC1jb3ZpZC13YXZlLWEtcmlzay0xMTYxNzYwMjMxNTU2MS5odG1s0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/85MzFAgXKbyL0BKbaqEEe8sMzczktqdfVadnFw1o5aIRi8rgygARe2ls-ZKrof-VvFubZgdLXWUywD6jeRw=-p-df-h100-w100',
#   'media': None,
#   'site': 'Mint'},
#  {'title': 'Federal Bank Q4 net profit rises 58.6% to ₹478 crore; NII up 17% YoY',
#   'desc': 'amp',
#   'date': '18 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEJb7TdT-eIwZZ6L6whwo7WIqFggEKg4IACoGCAowxLQ_MNevCDCkoh8?uo=CAUiigFodHRwczovL3d3dy5saXZlbWludC5jb20vY29tcGFuaWVzL2NvbXBhbnktcmVzdWx0cy9mZWRlcmFsLWJhbmstcTQtbmV0LXByb2ZpdC1yaXNlcy01OC02LXRvLXJzLTQ3OC1jcm9yZS1uaWktdXAtMTcteW95LTExNjIxMjM0MjY4Nzk3Lmh0bWzSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/AYl9OKQaifCasM4dWp5sX37l-oq1u_rK3dIQ7lT5h4QADpFxd6CbVr1F57VKGD_rR11lGIAczZmq6LqgrYE=-p-df-h100-w100',
#   'media': None,
#   'site': 'Mint'},
#  {'title': 'Interview | Federal Bank’s credit card should be launched soon: Nilufer Mullanfiroze',
#   'desc': 'amp',
#   'date': '16 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEFWELBrGkorqlLqhQMBFIE4qGQgEKhAIACoHCAow55veCjDzvdUBMIPh5gU?uo=CAUicGh0dHBzOi8vd3d3LmZpbmFuY2lhbGV4cHJlc3MuY29tL2luZHVzdHJ5L2JhbmtpbmctZmluYW5jZS90aGUtYmFua3MtY3JlZGl0LWNhcmQtc2hvdWxkLWJlLWxhdW5jaGVkLXNvb24vMjIzMzk4MS_SAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/y5qtYfYtFUZnpPTBblZDFcBs-5VXX8XS9NTDa5fFo9ZbN3iS7nCdyMGWLxdqh_lbQQEHdujnl-X4aR4bb1Y=-p-df-h100-w100',
#   'media': None,
#   'site': 'The Financial Express'},
#  {'title': 'Will US inflation indeed be transient?',
#   'desc': 'amp',
#   'date': '21 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEJrRPHhZDnMj7gOuDvV_BPYqGQgEKhAIACoHCAow2pqGCzD954MDMJzyigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/94fz3G_3GRMcis0Hb8_L2vLqga45LRo1JxrjHWxZkqN2PpPVJ5gmUn1w6B013mFVQ3r1ckiyz-hNi5SFwQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'IDFC First, RBL or Federal Bank could be the next multibagger: Dipan Mehta',
#   'desc': 'amp',
#   'date': '29 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEAXn0Hi_LjmsDnNGFrNF1jMqGQgEKhAIACoHCAow2pqGCzD954MDMMLNigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/gs6PZ8YBtiSkz8-Ju29PDAcxnhjjSUz3lR9aSMefT7oLaJNZygRmTwXvuL7HarFIzAbQdtCKOyTxzlAhJK7Y=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Federal Bank launches ‘FedFirst’ savings account scheme for children',
#   'desc': 'amp',
#   'date': '4 Feb',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEC63IhkAZvZoowhi5YBB4ewqGQgEKhAIACoHCAownZiCCzDY7_4CMKvDzAY?uo=CAUijQFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvZmVkZXJhbC1iYW5rLWxhdW5jaGVzLWZlZGZpcnN0LXNhdmluZ3MtYWNjb3VudC1zY2hlbWUtZm9yLWNoaWxkcmVuL2FydGljbGUzMzc1MDc1NC5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/Kge-0kNe4jT0DSBEyLOUEdY0TqjjpywKEeWesPbVvLnfHESV03GxwaVjXS766JV1yHzl9xS6JZ6BwnuFgw=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Latest News and Updates: Karnataka further relaxes Covid-19 lockdown norms',
#   'desc': 'amp',
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2021, 7, 3, 18, 3, 15, 948897),
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh5.googleusercontent.com/proxy/u2afe93PG1xr00EER2f17iWMyFl-guOcKrpaKImeiUW5aJDJI_2Tl4bGd9c5B0jNkJz8Ls-SjzgHpsTauNQAEksbng4X9I9f-9i_AriltaqTwgFH6A1p1dwCkJSPJMBoyDJe8hgMjkPP1Fw2thJ-0m592ksnndaz-GVzRnI13bQT6XSymCZHCDftZvpLGTzLDra2Ja0U-7hvTpB11WHnog=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Institution builder: Federal Banks Srinivasan is BS Banker of the Year',
#   'desc': 'amp',
#   'date': '18 Feb',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEI7Oy-Kdo3U3WsJ8zXVHCmUqGQgEKhAIACoHCAowsLXdCjCm3dEBMMPjpAM?uo=CAUijAFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9maW5hbmNlL2luc3RpdHV0aW9uLWJ1aWxkZXItZmVkZXJhbC1iYW5rLXMtc3Jpbml2YXNhbi1pcy1icy1iYW5rZXItb2YtdGhlLXllYXItMTIxMDIxMzAwMDg1XzEuaHRtbNIBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/tkLOWn8AMNyLpurtqFcq702fnnygdzBzDhB06TMYZ8_NHXKHYsHppTlDECW5iPvzp2vKhvG4_NgI2kpD9Pc=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Fintech startup DigiSparsh raises seed funding from Silicon Valley based-fund GoAhead Ventures',
#   'desc': 'amp',
#   'date': '22 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEJINU9zihqb_e4wUqL1l-mYqGQgEKhAIACoHCAown_uQCzCXsKUDMI6FtgY?uo=CAUihwFodHRwczovL3d3dy5mcmVlcHJlc3Nqb3VybmFsLmluL2J1c2luZXNzL2ZpbnRlY2gtc3RhcnR1cC1kaWdpc3BhcnNoLXJhaXNlcy1zZWVkLWZ1bmRpbmctZnJvbS1zaWxpY29uLXZhbGxleS1iYXNlZC1mdW5kLWdvYWhlYWQtdmVudHVyZXPSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/qxiUwXOl1jqpOw8_Hw0E9uK5i92ooyH8zDoqTagKAPthfC3LcyGBGMRaZA-zZY0o2N49juNVwtqJtQ1GVk4S=-p-df-h100-w100',
#   'media': None,
#   'site': 'Free Press Journal'},
#  {'title': 'Market HIGHLIGHTS: Sensex falls 391 pts from day’s high, Nifty ends at 15,814; FM announces relief measures',
#   'desc': 'amp',
#   'date': '28 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEJaqFEBbTfYD__jLqTXRpdgqGQgEKhAIACoHCAow55veCjDzvdUBMIPh5gU?uo=&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/rRaBGTAmp3uwyFeiJMAOBKejpjb88Jb2Xb_VkM8UzRpv7qNf4x6N6CR4eCPdjbISfdBGUodgIulPvEsgYEI=-p-df-h100-w100',
#   'media': None,
#   'site': 'The Financial Express'},
#  {'title': 'Vembanad Lake protector Rajappan complains of Rs 5.08 lakh swindle by sister',
#   'desc': 'amp',
#   'date': '19 Jun',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiENSWd6wpT9bxbkhwIh-x2x8qGAgEKg8IACoHCAowop2lATDj4RowpbvJBQ?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/F-Flr-0gNNXHCwove-ce7qXeCboXME8cNv2ZY8Fco4lyiXcc6X3ymBU6OVjqtGaRFE4RcVhZa32CR4y1aYW8aeZyM2Wh1NuvfQ8TGTqewi4Z5iBSgDhFBj6S7HMfYJN6JRzSSteQSt4KNB4L-ZxGdcAaCLXUv2xCmLhtQdZLWWqywzuRpHgu=-p-df-h100-w100',
#   'media': None,
#   'site': 'The New Indian Express'},
#  {'title': 'Stock Market Highlights: Sensex falls 178 points, Nifty ends below 15,700 as metals, banks, drag; midcaps unde',
#   'desc': 'amp',
#   'date': '17 Jun',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/rGjQSp9zOpS8fy6fojH_4fYU6T4ObGWGpZVI6VxNnYvgw6XaFBZapqGwN-00ke9YdPBVVJr_p82LjFAVSdOwusSjIGEe7iDkbNSr3UmWbFTVyLd4NKKw3LOkM78UIYTkV4ftkeE4DgYEZljzmkMMNqEC8rc6CQ1HMU2uXLqhpxFPBcgFYnBx6Da1ydtzWiY2nx2gmMbbLU1CeT7eyr8hYw=-p-df-h100-w100',
#   'media': None,
#   'site': 'CNBCTV18'},
#  {'title': "Explosive Start Kicks Off 'Best Ever' Celebration | Local News | greenevillesun.com",
#   'desc': 'amp',
#   'date': '33 minutes ago',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CBMikAFodHRwczovL3d3dy5ncmVlbmV2aWxsZXN1bi5jb20vbmV3cy9sb2NhbF9uZXdzL2V4cGxvc2l2ZS1zdGFydC1raWNrcy1vZmYtYmVzdC1ldmVyLWNlbGVicmF0aW9uL2FydGljbGVfNWU0ZmM4NmYtMWE4Ny01MjM2LWExZmQtNDU3OGZjMzZlYTZiLmh0bWzSAQA?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/dNj9Ld09GsbMRPokbTnhP5sqFjYZMRpEckejA2JpH7Uv0u6GnMskWt6xdYTJVCWC-YqGozdPeXC68b7WJzZccTKrq-1xrPLvYHhoIiAVKKvh-bm8EgJYgM0tRlBu0vGFdHUdrnZ-7W4UKv_lpnQtXsiVySSPV0czS9ZR5mT_6-bmUDFRbb881Z-VVTrsCf6LFrAklAwZ4WdUEu6SqnKfT009dd1hbiKYEs08Ds5R8iSvOkiTZIhKBKQOSWyugao=-p-df-h100-w100',
#   'media': None,
#   'site': 'Greeneville Sun'},
#  {'title': 'Neobank Fi partners with Federal Bank to open instant savings account',
#   'desc': 'amp',
#   'date': '27 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEKdfF1H0dpiSh0OFIjv7IfYqGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUikAFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvbmVvYmFuay1maS1wYXJ0bmVycy13aXRoLWZlZGVyYWwtYmFuay10by1vcGVuLWluc3RhbnQtc2F2aW5ncy1hY2NvdW50L2FydGljbGUzNDQyMDgxMi5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/QLQu9b8UehhJAeieksgkgJ0nq8ulc74Ke8hx6pkCik3rnIXaF2rb4hdJZG2ZlqmFcpFCUNKwGCEcuNXVSPQ=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'It has been a good year for Federal Bank given the challenges: Shyam Srinivasan',
#   'desc': 'amp',
#   'date': '17 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEDcSAswUmc6S3lP6cDbxueMqGQgEKhAIACoHCAow2pqGCzD954MDMMLNigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/OvGaqe05-mwNiq2mhKXKlmHeLdQt1VvIAzRkSjbsLzgGCZgH5AOUmHH8l1ry8FLOHT3shZEbXvQkab95oTb9=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Exclusive | Federal Bank open to buy out an MFI, aims 15-16% growth next fiscal year, says MD and CEO...',
#   'desc': 'Exclusive | Federal Bank open to buy out an MFI, aims 15-16% growth next fiscal year, says MD and CEO Shyam Srinivasan',
#   'date': '19 Mar',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEKv4I1I6ZnjUfMoqkQx23XcqGQgEKhAIACoHCAowlbCPCzCrzaIDMOjUrgY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/XNLLrfa9hfFTl67ePYUaJt_4Mv9dtxkrzTUcgb89aFMOuoffGKyxIjhaGYapM-j8tVvhJ1aAr1OhpSlNAUk=-p-df-h100-w100',
#   'media': None,
#   'site': 'Moneycontrol'},
#  {'title': 'Go for Federal Bank, IDFC First and RBL with a long-term view: Sudip Bandyopadhyay',
#   'desc': 'amp',
#   'date': '19 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEMOOp0fG7pSBACxRXXDIb00qGQgEKhAIACoHCAow2pqGCzD954MDMMLNigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/KFmIYoIN3gMsbwccQieTmyoGlc23zfHB5Yhh8fry26fym8Q2P7mWClchwlQJ6WoV1ysAP_VaZrrWOzcaoJ-f=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Federal Bank aims mid-teen growth in credit for fiscal 2022',
#   'desc': 'amp',
#   'date': '23 Feb',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEFdrtGmBffWEBmLg3GljulAqGQgEKhAIACoHCAowsLXdCjCm3dEBMNS-swY?uo=CAUigwFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9jb21wYW5pZXMvZmVkZXJhbC1iYW5rLWFpbXMtbWlkLXRlZW4tZ3Jvd3RoLWluLWNyZWRpdC1mb3ItZmlzY2FsLTIwMjItMTIxMDIyMzAwODU3XzEuaHRtbNIBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/SGHJb-fS59FrnPOm0TCnrOAkWhufShBNV-honjB90QneS_R-SBFAaLBWxDBPnG5vyylCQgbIcYNDpETHLCY=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Federal Bank’s gross advances rise 6% YoY in Q3',
#   'desc': 'amp',
#   'date': '5 Jan',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEDr1cQiHDXYcQrTcxo-3b8MqGQgEKhAIACoHCAow55veCjDzvdUBMIPh5gU?uo=CAUicGh0dHBzOi8vd3d3LmZpbmFuY2lhbGV4cHJlc3MuY29tL2luZHVzdHJ5L2JhbmtpbmctZmluYW5jZS9mZWRlcmFsLWJhbmtzLWdyb3NzLWFkdmFuY2VzLXJpc2UtNi15b3ktaW4tcTMvMjE2NDE5Ny_SAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/DRGjljYh_PmQ89wwTzL2CMzTtdr6H6cngawatt3TpLgMPO3PxzInA2u6wv1AkiaUylAUhU3bXsD_riJps64=-p-df-h100-w100',
#   'media': None,
#   'site': 'The Financial Express'},
#  {'title': 'Federal Bank Q3 profit falls 8% at ₹404 crore',
#   'desc': 'amp',
#   'date': '20 Jan',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEME21-0MJau4jVKkkYXjztIqGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUidmh0dHBzOi8vd3d3LnRoZWhpbmR1YnVzaW5lc3NsaW5lLmNvbS9tb25leS1hbmQtYmFua2luZy9mZWRlcmFsLWJhbmstcTMtcHJvZml0LWZhbGxzLTgtYXQtNDA0LWNyb3JlL2FydGljbGUzMzYxNzQ2MS5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/NkFewPeWaw72mTz8wiqhN3hmt44T7RytYcXbCMqGTrLLqhtXfD-lb5xb16dfMS78XdW2sXtdI_GghMUszF4=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Federal Bank: Ripe for re-rating despite guidance in run-rate of slippages',
#   'desc': 'amp',
#   'date': '18-Dec-2020',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEE-hobSQ5Puo79276UsJEDsqGQgEKhAIACoHCAowsLXdCjCm3dEBMNS-swY?uo=CAUikQFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9jb21wYW5pZXMvZmVkZXJhbC1iYW5rLXJpcGUtZm9yLXJlLXJhdGluZy1kZXNwaXRlLWd1aWRhbmNlLWluLXJ1bi1yYXRlLW9mLXNsaXBwYWdlcy0xMjAxMjE4MDEwNzZfMS5odG1s0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh5.googleusercontent.com/proxy/BgBnTd8tJJ6JXyvuyrwmV6g5vNbLF5qyU-WLTaGzA3q9VyUGEOFBbLMy0KKuOfF_ypzO2o5zI9Kl1KHu91pXoP1SFPTLeZUotbmLrbR0EY9pRWbV-titRLkpbGGJ4P_LbF1YfxN7BmYSUYuwAXqzmgK2vZUlAnIcdCpff_-RzpSOZLpQnLDQuPFNHfVhB6bRZ9mnHAa40BZhOGb6TV-5UZeMAhBMwZ2z7xxyQMVwbII48wq8URsKoIFBVyLtgDItA4lic0gmxuM=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'All You Need To Know Going Into Trade On July 1',
#   'desc': 'amp',
#   'date': '4 days ago',
#   'datetime': datetime.datetime(2021, 7, 1, 18, 3, 15, 958883),
#   'link': 'news.google.com/./articles/CAIiEBbELnGVYq1ZnHktt0czuoAqGQgEKhAIACoHCAowqvSQCzD0nKUDMPSf6AY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/zpwhSUlnfgj2ZNJo1TdYA5VJhuPXV4Q8ul8zgnPSnaR-UwD2TsPKYj6AQ87MFabEiSybs1LKdDSaaGnTlnM=-p-df-h100-w100',
#   'media': None,
#   'site': 'BloombergQuint'},
#  {'title': 'Federal Bank acknowledges uncertainties despite drop in provisions',
#   'desc': 'amp',
#   'date': '17 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEGao8DbsvYapDTVvRtTTMKwqGQgEKhAIACoHCAow2pqGCzD954MDMJzyigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/AM4kc6X1jeMl32jXubRWcGUP1ZI6DlIth7Ru9JxQQWF2HmR0caWAUKpVA7Mekmxz3R1T6UZ0Uqoq4tFlJNTF=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Federal Bank’s deposits grow 13% in Q4',
#   'desc': 'amp',
#   'date': '6 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEH9in4xnylcHNlZhW-2EHkoqGQgEKhAIACoHCAow55veCjDzvdUBMIPh5gU?uo=CAUiZ2h0dHBzOi8vd3d3LmZpbmFuY2lhbGV4cHJlc3MuY29tL2luZHVzdHJ5L2JhbmtpbmctZmluYW5jZS9mZWRlcmFsLWJhbmtzLWRlcG9zaXRzLWdyb3ctMTMtaW4tcTQvMjIyNzU0MC_SAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/Gkg7kC6GW2tlYsgkTAre48jan9nNfiPuvX0TdIJcZFv06B-TtRJFYa2_KP-Btv-jcQfPvDnBHGvwNFXMWF0=-p-df-h100-w100',
#   'media': None,
#   'site': 'The Financial Express'},
#  {'title': 'Federal Bank appoints Venkatraman Venkateswaran as CFO; Stock ends 2% up',
#   'desc': 'amp',
#   'date': '17 May',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/NaPIk4Ltu0HhNYXyfLtquAeCRfAVg5rd2wyeo-UNgo3D3C_AIB-60piNP5kgBIo_DQOoRQW6Ko58gbiYgAmzhsAJ0IfsQnmg3EJd3RqRMTO_ZoW7ED34N_efY1G6tLjeFHjUMlvcbrBg5XuiZ-ve3HEa790PZso=-p-df-h100-w100',
#   'media': None,
#   'site': 'Indiainfoline'},
#  {'title': 'Federal Bank Q4 up 58.4% at Rs521.24cr on sharply lower loan loss provisioning',
#   'desc': 'amp',
#   'date': '17 May',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/Jg4qXXT7fsXO8M9XYYiWHOYaMwxrOFANGLCP4a2YZPAzB0HICL8eWfw9H90z8-hwJPj2QnNaDyfpDYQf0NHySIqgQRFGFkdvCW8J3mki3AjOJPWYy34cnXgZ4spH7FMg1Dx5YvIYArcynWypnyDYJdQJ_EbM9j-1=-p-df-h100-w100',
#   'media': None,
#   'site': 'Indiainfoline'},
#  {'title': "Network 18 & Federal Bank's Initiative Sanjeevani Launched, Sonu Sood Asks People to Get Vaccinated",
#   'desc': "Network 18 & Federal Bank's Initiative Sanjeevani Launched, Sonu Sood Appeals People to Get Vaccinated",
#   'date': '7 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEIm8pZ98lRURg0MxIoYThVgqGQgEKhAIACoHCAow5qqNCzD4q58DMPbXpwY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/afRQOU6yavfjGkjow8fSMuE7mGO5xIR1CQgWFLj2Y-6mracFXXKaldddUeHF6Wp76l9Khx8I7H3Idwxsng=-p-df-h100-w100',
#   'media': None,
#   'site': 'News18'},
#  {'title': "Broker's call: Federal Bank (Buy)",
#   'desc': 'amp',
#   'date': '19 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEAJbxERcPdRPQK4BbhlnZRIqGQgEKhAIACoHCAownZiCCzDY7_4CMNPw8gU?uo=CAUibGh0dHBzOi8vd3d3LnRoZWhpbmR1YnVzaW5lc3NsaW5lLmNvbS9tYXJrZXRzL3N0b2NrLW1hcmtldHMvYnJva2Vycy1jYWxsLWZlZGVyYWwtYmFuay1idXkvYXJ0aWNsZTM0NTg5MTU2LmVjZdIBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/STo_aXAmRr-cty6JEYNUQWQ1YWniBTS1iGHzbK5TZUHSsk9joftaCbh808wsdYZPAP1bRDIkWg0Aocb8Am0wfx9ta4zYovmok9qks5-ychDqcSD1c1-S3ymeuexw8Q=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Neobank Fi launched in partnership with Federal Bank',
#   'desc': 'amp',
#   'date': '22 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CBMiRWh0dHBzOi8vd3d3LmRxaW5kaWEuY29tL25lb2JhbmstZmktbGF1bmNoZWQtcGFydG5lcnNoaXAtZmVkZXJhbC1iYW5rL9IBSWh0dHBzOi8vd3d3LmRxaW5kaWEuY29tL25lb2JhbmstZmktbGF1bmNoZWQtcGFydG5lcnNoaXAtZmVkZXJhbC1iYW5rL2FtcC8?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/pilvKlZ_BCTDpB-Yp_XdEUS8OApJozXzQVLyJHCZVk5aIchQqYswB5ao-vxfHexBF0LCeblr9DP6G5oCFVzQgvR8h2pr4O_lSVsop-dFzKWB2FsGT_ml1gp2oBbS=-p-df-h100-w100',
#   'media': None,
#   'site': 'DATAQUEST'},
#  {'title': 'Stocks in the news: L&T, Airtel, Federal Bank, SBI, YES Bank and Cipla',
#   'desc': 'amp',
#   'date': '17 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEFrJkJKIK4yuHB8Q3m1hw1cqGQgEKhAIACoHCAow2pqGCzD954MDMJzyigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/hi0s7lDicIsN5_23IBEoQLc7tZvqIn0GmWMbgxINbYC8lt_4VEpE4Uyz5N7Lf4C96zvz02tnmxKSC9ivV6M=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'Federal Bank’s stress stands contained but 2nd wave a risk',
#   'desc': 'amp',
#   'date': '18 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEMHqb0KMAd9VuSqCfuTeDUMqFggEKg4IACoGCAowxLQ_MNevCDD45Co?uo=CAUifWh0dHBzOi8vd3d3LmxpdmVtaW50LmNvbS9tYXJrZXQvbWFyay10by1tYXJrZXQvZmVkZXJhbC1iYW5rLXMtc3RyZXNzLXN0YW5kcy1jb250YWluZWQtYnV0LTJuZC13YXZlLWEtcmlzay0xMTYyMTI2OTY3MDMwMy5odG1s0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/ryz_1c5QbP0TjNSsUCSTWCGqU2OVA-UvOJlltyO6H88VMzWt0lDCcPWUvcuQ6SR0oPyQqnNUHFwYDOLsbDyc=-p-df-h100-w100',
#   'media': None,
#   'site': 'Mint'},
#  {'title': 'Buy Federal Bank, target price Rs 80: Motilal Oswal',
#   'desc': 'amp',
#   'date': '4 Jan',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/taYiFhxPL1xqZ_UFnc1ganhLu5JG6VYplsp1626njWluJrAsQC0OePdkgisJOYjbVcWo-IF0XKQYGXjyCmyOZdJEktkahe_UlQICc2xJrP2Y96LyhsK5wMaDQ3MXJGeP7eQTRpQtE7dHqbbMHMYGXbjyoib0OxdlvFgsDrIK7CuvVl4alkMgJJnfWpUZ=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': "Loans can be recast, but debt will be classified as NPA: Federal Bank's Warrier",
#   'desc': 'amp',
#   'date': '3 Mar',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh5.googleusercontent.com/proxy/uQrKrZbpIIWGpYekjwR3n_b2Ma6MJhHwSZ91mN_yzOajGwpJdL7LxAGxHhD-k3DzMmM96-i97iPZak2wFCfE-e7LwC_eO85mVC9Axas2Ys5qXy-XoiO74kppmlii4gUkqUXVhMSyu_9_e3F2R8MmnMXC0rWJ81ZzNNriMW6pBIhed-M2p5qbBclWeVFPupE8Y-yyc_d8CyU=-p-df-h100-w100',
#   'media': None,
#   'site': 'Livemint'},
#  {'title': 'Stocks in news: PNB, InterGlobe Aviation, Tata Steel, Federal Bank and more',
#   'desc': 'amp',
#   'date': '11 May',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/pgZ3urVPQRhlDM9te_yInrJDxTTYbGtwV8lWnOvkE7Uycp98V03ysXlThzaPeLVBM6UmfNN_Hq7tjGZ9vmgUkvem62DdI9E37PFTPwOAHMFaO54jFOVlYX99Phm3E10hZ7jlXApUNgKPBt-OME61wvp3HsAEFej20ykpLQb_kA2-iJEgk_eRrB-ZlDqu1NEUHKKoml28BPB6O8XQCDNlmg=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Today'},
#  {'title': 'Federal Bank Q3 results: Restructured book half of estimates, signals no big jolt for system',
#   'desc': 'amp',
#   'date': '20 Jan',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEB-xVd4uSYztyq__tI345U0qGQgEKhAIACoHCAow2pqGCzD954MDMJzyigY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/DDN4_7TK2VAQhYQUXRfVVQfKj23ZBJOVRhP74gJWkLbe6_UERSJHsuASAJk2_BQ7mALVAwncdX9mAUnF6cc=-p-df-h100-w100',
#   'media': None,
#   'site': 'Economic Times'},
#  {'title': 'DCB Bank, RBL Bank, Federal Bank likely to hunt for next CEOs after RBI caps terms for MDs, CEOs at pvt banks',
#   'desc': 'amp',
#   'date': '28 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEGBBiOv4GvBhF3f3i-jh3KIqGQgEKhAIACoHCAowr6n9CjCr4PQCMI781QM?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/e8jNYe7w-QPCtlgd5OdRQO03CPhlSc_YM3uJ7aW8OWDKQY3EM9kcG10OP5Hie4A_2z0lh3YLkNTYAFuI9Wc=-p-df-h100-w100',
#   'media': None,
#   'site': 'Times Now'},
#  {'title': 'Federal Bank, Mashreq Bank of UAE ink pact, to offer money transfer',
#   'desc': 'amp',
#   'date': '10 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEGueEy-LW_mODGierpqWKJsqGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUijAFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvZmVkZXJhbC1iYW5rLW1hc2hyZXEtYmFuay1vZi11YWUtaW5rLXBhY3QtdG8tb2ZmZXItbW9uZXktdHJhbnNmZXIvYXJ0aWNsZTM0NTI3MjI1LmVjZdIBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/kX4RS0QQc0rgXd2DWvnaAoI3AzwzSAgUescEqP0NOsT2srKbQWDBVAGYbH3awrQ6R1RGQjyEMos9a64oUe06=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Are All Short Stories O. Henry Stories?',
#   'desc': 'Photograph courtesy Swann Auction Galleries',
#   'date': '7 days ago',
#   'datetime': datetime.datetime(2021, 6, 28, 18, 3, 15, 968883),
#   'link': 'news.google.com/./articles/CAIiEDe0bY3hND_hBMPoBv70dwUqGQgEKhAIACoHCAowjMqjCjCJhZwBMN-rzwY?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/5mgATSNnXp8E2ygBfHI8dBXxR_UXWi6OIOyz_hpZ26y2HuVwGvm0FD2aZC7DiTvBIKdTgMv2roSWm0YHTcTu=-p-df-h100-w100',
#   'media': None,
#   'site': 'The New Yorker'},
#  {'title': 'Federal Bank Q2: Total deposits up 12 per cent, gross advances rise 6 per cent yoy',
#   'desc': 'amp',
#   'date': '04-Oct-2020',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiENWAkCr4YvxLQYCk0YDXMvUqGQgEKhAIACoHCAownZiCCzDY7_4CMJPw8gU?uo=CAUimwFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvZmVkZXJhbC1iYW5rLXEyLXRvdGFsLWRlcG9zaXRzLXVwLTEyLXBlci1jZW50LWdyb3NzLWFkdmFuY2VzLXJpc2UtNi1wZXItY2VudC15b3kvYXJ0aWNsZTMyNzY0OTYyLmVjZdIBAA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/f1-v6LieNH3hOntCWUYiecumk57w1OAttmVjdz8mNLwFsA1fAJz7gu_F0JIfr2Rvi5-EboxdStLQPNBwIxs=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': "Sanjeevani – A Shot of Life: Network18 and Federal Bank's drive to raise awareness about COVID-19 vaccination-India News",
#   'desc': "Sanjeevani – A Shot of Life: Network18 and Federal Bank's drive to raise awareness about COVID-19 vaccination",
#   'date': '7 Apr',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEEuvAqHkjmP1rbCOnrT5OL4qGAgEKg8IACoHCAow5v6PATDrwA8wleW5Bg?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/-BIYF-UQBhDy1lqiIbMO6sCT1OtmyEWCs3t9oFJOTw_mAV2LMKoU_6APG_mNqtTWyONCaYGYPus1dD975S3z=-p-df-h100-w100',
#   'media': None,
#   'site': 'Firstpost'},
#  {'title': 'Indian-American Naureen Hassan appointed first VP, COO of New York Federal Bank',
#   'desc': 'amp',
#   'date': '6 Mar',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh4.googleusercontent.com/proxy/Mi78BKYpft07-rfkPI6yqwdKoItfMTthohPP2Vh-zLqkFN1qNGiYO-femj6WlX79tdCvnQlPMBxrhOFB-wTpprT5JhcP1jpFNsjqxcypkfELHNOWqZzN6wD-nSYqA0dp4dzdSk3Ab9_8rc6zwFcu1_aXVOcZAgTNvDL8fw2eTMLsJOCTx3QrmjLHMJm7qkE=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Today'},
#  {'title': 'Financial discipline has been visible even in the relatively stressed segments, says Federal Bank chief',
#   'desc': 'amp',
#   'date': '24-Nov-2020',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEDPwwM_-ee6pFDkgWyztjUAqGQgEKhAIACoHCAownZiCCzDY7_4CMKnDzAY?uo=CAUisQFodHRwczovL3d3dy50aGVoaW5kdWJ1c2luZXNzbGluZS5jb20vbW9uZXktYW5kLWJhbmtpbmcvZmluYW5jaWFsLWRpc2NpcGxpbmUtaGFzLWJlZW4tdmlzaWJsZS1ldmVuLWluLXRoZS1yZWxhdGl2ZWx5LXN0cmVzc2VkLXNlZ21lbnRzLXNheXMtZmVkZXJhbC1iYW5rLWNoaWVmL2FydGljbGUzMzE2OTgzOC5lY2XSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/m2P37kQQMaXoqxaOvKQEgTklghLy_uYSPawmkOfVwa5_plISuOaWIuc_s_wqzCNDWPF2aWKY9UNvbyLbad4=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'},
#  {'title': 'Federal Bank Q2 PAT down 26.2% at Rs 308 cr on higher provisions',
#   'desc': 'amp',
#   'date': '17-Oct-2020',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEE8sLGVSM3vImwzX4ylD-hcqGQgEKhAIACoHCAowsLXdCjCm3dEBMMPjpAM?uo=CAUihQFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9maW5hbmNlL2ZlZGVyYWwtYmFuay1xMi1wYXQtZG93bi0yNi0yLWF0LXJzLTMwOC1jci1vbi1oaWdoZXItcHJvdmlzaW9ucy0xMjAxMDE2MDA1MzZfMS5odG1s0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/O_ETNID4_CBrgzyKWBrgCGQ5630sMgbDE63sS1uVefSYH5ZScHLeW6Eocmthem_RVNV9VU-iazkj0lLrHg=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Stocks to watch: Bajaj Finance, Federal Bank, Tata Comm, Garden Reach',
#   'desc': 'amp',
#   'date': '20 Jan',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEOoHkbjJ3aX44Nl8RbGooa8qGQgEKhAIACoHCAowsLXdCjCm3dEBMOThpAM?uo=CAUihwFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9tYXJrZXRzL3N0b2Nrcy10by13YXRjaC1iYWphai1maW5hbmNlLWZlZGVyYWwtYmFuay1nYXJkZW4tcmVhY2gtdGF0YS1jb21tLTEyMTAxMjAwMDE1MV8xLmh0bWzSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/ft2QQLFohTClCCXPjy0u2P5cq0T7Glxcn_6V_h4Q05EVmx1ySuE8RTwVJColIZmy1pFBepqrAWb42vmQGp0=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Federal Bank appoints Damodaran as Chief Risk Officer',
#   'desc': 'amp',
#   'date': '20 Apr',
#   'datetime': None,
#   'link': 'news.google.com/.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/Jg4qXXT7fsXO8M9XYYiWHOYaMwxrOFANGLCP4a2YZPAzB0HICL8eWfw9H90z8-hwJPj2QnNaDyfpDYQf0NHySIqgQRFGFkdvCW8J3mki3AjOJPWYy34cnXgZ4spH7FMg1Dx5YvIYArcynWypnyDYJdQJ_EbM9j-1=-p-df-h100-w100',
#   'media': None,
#   'site': 'Indiainfoline'},
#  {'title': 'Gold loans power up Federal Bank’s Q3, but stress seems under control',
#   'desc': 'amp',
#   'date': '21 Jan',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEP4ETbW1_6UTZoi-fg8gOBwqFggEKg4IACoGCAowxLQ_MNevCDD45Co?uo=CAUihwFodHRwczovL3d3dy5saXZlbWludC5jb20vbWFya2V0L21hcmstdG8tbWFya2V0L2dvbGQtbG9hbnMtcG93ZXItdXAtZmVkZXJhbC1iYW5rLXMtcTMtYnV0LXN0cmVzcy1zZWVtcy11bmRlci1jb250cm9sLTExNjExMTQyMDQ0NDY2Lmh0bWzSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/EYQ12hQR8C7J-dvSvmi7ueLfEMpRHWhp6ykF8ZErzLkvq-q000J7EpfFj4KGfW9D3pll2NDbd1MjJZAofkFzb0OwnBe07-nWYO_1v0YeTHBTk64Jj1vB_sQd7qt0O1yGtthkKyOcbRKf8IOsu8tInHhn0AA1LH5Qi4FSv7ljAA=-p-df-h100-w100',
#   'media': None,
#   'site': 'Mint'},
#  {'title': 'Stock alert! Strong Q4 performance makes Morgan Stanley and CITI bullish on Federal Bank - Check target pri...',
#   'desc': 'amp',
#   'date': '18 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiELOta_uUlxBUUPfFA9jRc_MqGQgEKhAIACoHCAow5bCNCzD8tp8DMP3RpwY?uo=CAUimQFodHRwczovL3d3dy56ZWViaXouY29tL21hcmtldC1uZXdzL25ld3Mtc3RvY2stYWxlcnQtc3Ryb25nLXE0LXBlcmZvcm1hbmNlLW1ha2VzLW1vcmdhbi1zdGFubGV5LWFuZC1jaXRpLWJ1bGxpc2gtb24tZmVkZXJhbC1iYW5rLWNoZWNrLXRhcmdldC1wcmljZS0xNTY4OTDSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/wL8Xht459fjP_yqyYZ30sg62DdLjZ6BcDnPiZCt46ZrnttdQkrJ7oFFK10AYaa8qdgMWAlSwNy6yF_XETlY=-p-df-h100-w100',
#   'media': None,
#   'site': 'Zee Business'},
#  {'title': 'How City Union Bank, Federal Bank have sustained investor interest',
#   'desc': 'amp',
#   'date': '14-Oct-2020',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiENid_yz4SJfKPAqCxqU9OXUqGQgEKhAIACoHCAowsLXdCjCm3dEBMNS-swY?uo=CAUihwFodHRwczovL3d3dy5idXNpbmVzcy1zdGFuZGFyZC5jb20vYXJ0aWNsZS9maW5hbmNlL2hvdy1jaXR5LXVuaW9uLWJhbmstZmVkZXJhbC1iYW5rLWhhdmUtc3VzdGFpbmVkLWludmVzdG9yLWludGVyZXN0LTEyMDEwMTMwMTIyN18xLmh0bWzSAQA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/Q6JZfkhoSYOgdvOFTuDYiV4Tl9b1xzd87HsShvXY0IoGzC-nc_T358OUYFPLVlEwqDGzI7uNzn8rI5L2AKc=-p-df-h100-w100',
#   'media': None,
#   'site': 'Business Standard'},
#  {'title': 'Awesome Oscillator suggests buying opportunity in Federal Bank for target up to Rs 79',
#   'desc': 'amp',
#   'date': '15-Nov-2020',
#   'datetime': None,
#   'link': 'news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh6.googleusercontent.com/proxy/RLmKeU_CR6gJKNQ-DvlsTNFA7o0fSCprIhejLa1VdjeLjsYJfcoczvwz3_AzoodUFvZBZc0OvZULmX5liuF30BCSLTBfdg2VvXEPRXpZF6TBwv0OwmelKUJaV-SW9Gs1fM7QPJEo_yNKvG_M-Q_tMWbfe6dcAEECrRMO0IWlTSNSGR0_m4hyb3e4=-p-df-h100-w100',
#   'media': None,
#   'site': 'Moneycontrol.com'},
#  {'title': '‘Ageas may up stake in Federal Life to 74%’',
#   'desc': 'amp',
#   'date': '6 May',
#   'datetime': None,
#   'link': 'news.google.com/./articles/CAIiEACoHPQ8xmob2hmScCFG37sqGQgEKhAIACoHCAownZiCCzDY7_4CMK7s8gU?uo=CAUia2h0dHBzOi8vd3d3LnRoZWhpbmR1YnVzaW5lc3NsaW5lLmNvbS9jb21wYW5pZXMvYWdlYXMtbWF5LXVwLXN0YWtlLWluLWZlZGVyYWwtbGlmZS10by03NC9hcnRpY2xlMzQ1MDA2MTIuZWNl0gEA&hl=en-IN&gl=IN&ceid=IN%3Aen',
#   'img': 'https://lh3.googleusercontent.com/zjIvGxr0T2h6oExRimBnp-KKZs8tnGFX6xONBFu0f4IcmluExW3UDW9KEQJaI94WhwNRC3_FMqldXZadSyc=-p-df-h100-w100',
#   'media': None,
#   'site': 'BusinessLine'}]

# %%
df=pd.DataFrame(googlenews.results())

# %%
df
# Out:
#                                                 title desc          date  \
# 0   Federal Bank to raise Rs 916 cr in equity capi...  amp        17 Jun
# 1   Bank Nifty tops near 390 pts amid Q1 advances ...  amp  14 hours ago
# 2   From partnering with fintech startups to helpi...  amp    5 days ago
# 3   Covid-19 impact: Federal Bank provides about 4...  amp        26 Jun
# 4   Buy Federal Bank, target price Rs 110: Motilal...  amp    7 days ago
# ..                                                ...  ...           ...
# 76  Gold loans power up Federal Bank’s Q3, but str...  amp        21 Jan
# 77  Stock alert! Strong Q4 performance makes Morga...  amp        18 May
# 78  How City Union Bank, Federal Bank have sustain...  amp   14-Oct-2020
# 79  Awesome Oscillator suggests buying opportunity...  amp   15-Nov-2020
# 80        ‘Ageas may up stake in Federal Life to 74%’  amp         6 May
#
#                      datetime  \
# 0                         NaT
# 1  2021-07-05 04:03:15.919901
# 2  2021-06-30 18:03:15.920899
# 3                         NaT
# 4  2021-06-28 18:03:15.922898
# ..                        ...
# 76                        NaT
# 77                        NaT
# 78                        NaT
# 79                        NaT
# 80                        NaT
#
#                                                  link  \
# 0   news.google.com/./articles/CAIiEIaCZBTuarhOTtn...
# 1   news.google.com/./articles/CBMizQFodHRwczovL3d...
# 2   news.google.com/./articles/CAIiEIhrKucLj-2teuC...
# 3   news.google.com/./articles/CAIiEFvHHep-NR1Rfnl...
# 4   news.google.com/./articles/CAIiEDC2Ca4kY23JOvZ...
# ..                                                ...
# 76  news.google.com/./articles/CAIiEP4ETbW1_6UTZoi...
# 77  news.google.com/./articles/CAIiELOta_uUlxBUUPf...
# 78  news.google.com/./articles/CAIiENid_yz4SJfKPAq...
# 79  news.google.com/./articles/CBMilQFodHRwczovL3d...
# 80  news.google.com/./articles/CAIiEACoHPQ8xmob2hm...
#
#                                                   img media               site
# 0   https://lh3.googleusercontent.com/g52ixI0JOveh...  None  Business Standard
# 1   https://lh4.googleusercontent.com/proxy/da_dTw...  None      Indiainfoline
# 2   https://lh3.googleusercontent.com/wI9uPZqNsI3_...  None          YourStory
# 3   https://lh6.googleusercontent.com/proxy/Kdmp7Z...  None       BusinessLine
# 4   https://lh3.googleusercontent.com/jYBF7q7WVQL0...  None     Economic Times
# ..                                                ...   ...                ...
# 76  https://lh6.googleusercontent.com/proxy/EYQ12h...  None               Mint
# 77  https://lh3.googleusercontent.com/wL8Xht459fjP...  None       Zee Business
# 78  https://lh3.googleusercontent.com/Q6JZfkhoSYOg...  None  Business Standard
# 79  https://lh6.googleusercontent.com/proxy/RLmKeU...  None   Moneycontrol.com
# 80  https://lh3.googleusercontent.com/zjIvGxr0T2h6...  None       BusinessLine
#
# [81 rows x 8 columns]

# %%
#Searching the news about federal bank.
googlenews=GoogleNews(start='05/01/2021',end='05/31/2020') #googlenews object
googlenews.search('Federal Bank India') #searchword
for i in range(1,20): #looping over and getting the news till 20 pages.
    googlenews.getpage(i)
    result=googlenews.result()
    df1=pd.DataFrame(result)

# %%
df1
# Out:
#                                                  title               media  \
# 0    Federal Bank introduces Pre-Booking Appointmen...                BFSI
# 1    Federal Bank Q2 PAT down 26.2% at Rs 308 cr on...   Business Standard
# 2    Buy Federal Bank, target price Rs 80: Motilal ...  The Economic Times
# 3    Federal Bank Q2: Total deposits up 12 per cent...       Business Line
# 4    Federal Bank to launch credit cards in next fe...       Business Line
# ..                                                 ...                 ...
# 195  Home Federal Bank and FHLB Dallas Provide $750...       Business Wire
# 196  Federal Bank Regulators Issue Rule Supporting ...
# 197  India’s banks are racing to lend against a $1....                Mint
# 198  HDFC Mutual Fund's Bank ETF NFO explained in 1...                Mint
# 199  3-way Partnership: LuLu Exchange, Federal Bank...         CryptoNewsZ
#
#             date datetime                                               desc  \
# 0    18-Jun-2020     None  Federal Bank introduces Pre-Booking Appointmen...
# 1    17-Oct-2020     None  Private sector lender Federal Bank on Friday r...
# 2    04-Jan-2021     None  Federal Bank Ltd., incorporated in the year 19...
# 3    04-Oct-2020     None  According to provisional numbers reported by F...
# 4    01-Mar-2021     None  Federal Bank is set to launch credit cards in ...
# ..           ...      ...                                                ...
# 195  04-Feb-2021     None  Home Federal Bank and FHLB Dallas have awarded...
# 196  24-Mar-2021     None  On March 9, federal bank regulatory agencies a...
# 197  30-Jul-2020     None  and Federal Bank Ltd. are expanding the loans ...
# 198  10-Aug-2020     None  9) The 12 stocks in the index include- HDFC Ba...
# 199  12-Feb-2021     None  LuLu International Exchange, a financial servi...
#
#                                                   link  \
# 0    https://bfsi.eletsonline.com/federal-bank-intr...
# 1    https://www.business-standard.com/article/fina...
# 2    https://economictimes.indiatimes.com/markets/s...
# 3    https://www.thehindubusinessline.com/money-and...
# 4    https://www.thehindubusinessline.com/money-and...
# ..                                                 ...
# 195  https://www.businesswire.com/news/home/2021020...
# 196  https://www.jdsupra.com/legalnews/federal-bank...
# 197  https://www.livemint.com/industry/banking/indi...
# 198  https://www.livemint.com/mutual-fund/mf-news/h...
# 199  https://www.cryptonewsz.com/3-way-partnership-...
#
#                                                    img
# 0    ......
# 1    ......
# 2    ......
# 3    ......
# 4    ......
# ..                                                 ...
# 195  ......
# 196  ......
# 197  ......
# 198  ......
# 199  ......
#
# [200 rows x 7 columns]

# %% [markdown]
# <h1><center>END</center></h1>
